# %% [markdown]
# # Problem Statement: Web Scraping Product Information from WhatsMobile
#
# **Background:**
#
# WhatsMobile is an e-commerce platform where users can search for and purchase various products. It contains a vast catalog of products with details such as product names, prices, sellers, and additional specifications. To gather data for analysis or other purposes, it can be valuable to extract specific product information from Flipkart's website programmatically.
#
# **Objective:**
#
# The objective of this project is to create a Python script that performs web scraping on WhatsMobilert's website to extract essential information about Samsung mobile phone and store it for further analysis or use.

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Define the URL to scrape data

# %%
URL = f"https://www.whatmobile.com.pk/Samsung_Mobiles_Prices"

# %% [markdown]
# ### Setting user-agent headers

# %%
HEADERS = {"User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36'}

# %% [markdown]
# ### Send an HTTP GET request to the URL

# %%
response = requests.get(URL,headers=HEADERS)

# %% [markdown]
# ### Print the HTTP response object

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Get the content of the HTTP response

# %%
response.content
# Out:
# b'<html lang="en-US" prefix="og: http://ogp.me/ns#">\n<head>\n       <link rel="canonical" href="https://www.whatmobile.com.pk/Samsung_Mobiles_Prices">\n       <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.whatmobile.com.pk/Samsung_Mobiles_Prices">\n<!-- Google Tag Manager -->\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-NVDVQQ\');</script>\n<!-- End Google Tag Manager -->\n    <link rel="manifest" href="/manifest.json">\n    <title>Samsung mobiles - Samsung mobile prices in Pakistan 2024 - WhatMobile</title>\n    <meta name="description"\n          content="Latest Samsung Mobile Phones Prices in Pakistan 2024 (Islamabad, Lahore &amp; Karachi) - Price and Specifications of new smartphones. Compare Price list & features. Buy 3G, 4G, dual sim mobile phone at best price in Pakistan."/>\n    <meta name="Keywords"\n          CONTENT="Samsung mobiles, Samsung mobile Prices, Samsung mobile Phone Prices, Samsung mobile Phones, pakistan, What, mobile, what mobile, phone, prices, zone, mobile phone">\n    <meta name="sitecode" content="PK"/>\n    <meta name="last-modified" content="2024-12-09"/>\n    <meta property="fb:admins" content="WhatMobile"/>\n    <meta property="og:title"\n          content="Samsung Mobiles &#8211; Samsung Mobile Phones Prices 2024 - WhatMobile">\n    <meta property="og:description"\n          content="Latest Samsung Mobile Phones Prices in Pakistan (Islamabad, Lahore &amp; Karachi) - Price and Specifications of new smartphones with advance technology and design. Buy 3G, 4G, dual sim mobile phone at best price in Pakistan."/>\n    <meta property="fb:app_id" content="1451235568231998"/>\n    <meta property="og:site_name" content="WhatMobile"/>\n    <meta property="og:type" content="website"/>\n\n    <meta property="og:url" content="https://www.whatmobile.com.pk/Samsung_Mobiles_Prices"/>\n\n\n    <script type=\'text/javascript\'>\n        var googletag = googletag || {};\n        googletag.cmd = googletag.cmd || [];\n        (function () {\n            var gads = document.createElement(\'script\');\n            gads.async = true;\n            gads.type = \'text/javascript\';\n            var useSSL = \'https:\' == document.location.protocol;\n            gads.src = (useSSL ? \'https:\' : \'http:\') +\n                \'//www.googletagservices.com/tag/js/gpt.js\';\n            var node = document.getElementsByTagName(\'script\')[0];\n            node.parentNode.insertBefore(gads, node);\n        })();\n    </script>\n\n    <script type=\'text/javascript\'>\n        googletag.cmd.push(function () {\n            googletag.defineSlot(\'/1013266/Category_300x250_Right\', [300, 250], \'div-gpt-ad-1386929247463-0\').addService(googletag.pubads());\n            googletag.defineSlot(\'/1013266/Category160x600\', [160, 600], \'div-gpt-ad-1382717875007-0\').addService(googletag.pubads());\n            googletag.defineSlot(\'/1013266/Category_300x250_Left\', [300, 250], \'div-gpt-ad-1382589263041-0\').addService(googletag.pubads());\n            googletag.pubads().enableSingleRequest();\n            googletag.enableServices();\n        });\n    </script>\n  \n\n    <link href="style.css" rel="stylesheet" type="text/css"/>\n    <link href="css/bootstrap.css" rel="stylesheet" type="text/css"/>\n\n    <style type="text/css">\n        <!--\n        .style1 {\n            color: #FF0000;\n            font-family: Verdana, Arial, Helvetica, sans-serif;\n            font-weight: bold;\n            font-size: 12px;\n        }\n\n        body {\n            margin-left: 1px;\n            margin-top: 0px;\n            margin-right: 0px;\n            margin-bottom: 0px;\n        }\n\n         ...

# %% [markdown]
# ### Parse the HTML content of the response using BeautifulSoup

# %%
soup = BeautifulSoup(response.content,"html.parser")

# %%
soup
# Out:
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <link href="https://www.whatmobile.com.pk/Samsung_Mobiles_Prices" rel="canonical"/>
# <link href="https://m.whatmobile.com.pk/Samsung_Mobiles_Prices" media="only screen and (max-width: 640px)" rel="alternate"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NVDVQQ');</script>
# <!-- End Google Tag Manager -->
# <link href="/manifest.json" rel="manifest"/>
# <title>Samsung mobiles - Samsung mobile prices in Pakistan 2024 - WhatMobile</title>
# <meta content="Latest Samsung Mobile Phones Prices in Pakistan 2024 (Islamabad, Lahore &amp; Karachi) - Price and Specifications of new smartphones. Compare Price list &amp; features. Buy 3G, 4G, dual sim mobile phone at best price in Pakistan." name="description"/>
# <meta content="Samsung mobiles, Samsung mobile Prices, Samsung mobile Phone Prices, Samsung mobile Phones, pakistan, What, mobile, what mobile, phone, prices, zone, mobile phone" name="Keywords"/>
# <meta content="PK" name="sitecode">
# <meta content="2024-12-09" name="last-modified"/>
# <meta content="WhatMobile" property="fb:admins"/>
# <meta content="Samsung Mobiles – Samsung Mobile Phones Prices 2024 - WhatMobile" property="og:title"/>
# <meta content="Latest Samsung Mobile Phones Prices in Pakistan (Islamabad, Lahore &amp; Karachi) - Price and Specifications of new smartphones with advance technology and design. Buy 3G, 4G, dual sim mobile phone at best price in Pakistan." property="og:description">
# <meta content="1451235568231998" property="fb:app_id"/>
# <meta content="WhatMobile" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.whatmobile.com.pk/Samsung_Mobiles_Prices" property="og:url"/>
# <script type="text/javascript">
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         (function () {
#             var gads = document.createElement('script');
#             gads.async = true;
#             gads.type = 'text/javascript';
#             var useSSL = 'https:' == document.location.protocol;
#             gads.src = (useSSL ? 'https:' : 'http:') +
#                 '//www.googletagservices.com/tag/js/gpt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#     </script>
# <script type="text/javascript">
#         googletag.cmd.push(function () {
#             googletag.defineSlot('/1013266/Category_300x250_Right', [300, 250], 'div-gpt-ad-1386929247463-0').addService(googletag.pubads());
#             googletag.defineSlot('/1013266/Category160x600', [160, 600], 'div-gpt-ad-1382717875007-0').addService(googletag.pubads());
#             googletag.defineSlot('/1013266/Category_300x250_Left', [300, 250], 'div-gpt-ad-1382589263041-0').addService(googletag.pubads());
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#         });
#     </script>
# <link href="style.css" rel="stylesheet" type="text/css">
# <link href="css/bootstrap.css" rel="stylesheet" type="text/css">
# <style type="text/css">
#         <!--
#         .style1 {
#             color: #FF0000;
#             font-family: Verdana, Arial, Helvetica, sans-serif;
#             font-weight: bold;
#             font-size: 12px;
#         }
#
#         body {
#             margin-left: 1px;
#             margin-top: 0px;
#             margin-right: 0px;
#             margin-bottom: 0px;
#         }
#
#         -->
#
#         hr {
#             margin-top: 10px;
#             margin-bottom: 10px;
#             display: block;
#             clear: both;
#         }
#
#         .mobiles {
#             margin-top: 22px;
#         }
#
#         .mobiles .item {
#             width: calc(100% / 6);
#             min-height: 165px;
#             text-align: center;
#             display: inline-block;
#             float: left;
#             padding: 3px;
#         }
#
#         .mobiles .item img {
#             display: block;
#             margin: auto;
#         }
#
#         .mobiles .ad-item {
#             display: inline-block;
#         }
#     </style>
# </link></link></meta></meta></head>
# <body>
# <div style="width:1000px;margin: auto;">
# <div style="width: 100%">
# <link href="css/search.css" rel="stylesheet" type="text/css">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVDVQQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div style="width:1000px;">
# <div itemscope="" itemtype="http://schema.org/Organization">
# <meta content="What Mobile" itemprop="name"/>
# <meta content="https://www.whatmobile.com.pk/" itemprop="url"/>
# <meta content="https://m.whatmobile.com.pk/" itemprop="sameAs"/>
# <meta content="https://www.facebook.com/whatmobile.com.pk/" itemprop="sameAs"/>
# </div>
# <div itemscope="" itemtype="http://schema.org/WebSite">
# <meta content="WhatMobile" itemprop="name"/>
# <meta content="https://www.whatmobile.com.pk/" itemprop="url"/>
# </div>
# <div style="width:998px">
# <div style="width:764px; float:left">
# <img alt="Mobile Prices" border="0" height="137" src="images/header-Left-new2.gif" usemap="#Map" width="764"/>
# <map id="Map" name="Map">
# <area coords="63,116,169,137" href="//www.whatmobile.com.pk" shape="rect"/>
# <area coords="187,115,291,135" href="//www.whatmobile.com.pk/reviews/" shape="rect"/>
# <area coords="306,116,411,148" href="news.php" shape="rect"/>
# <area coords="550,111,655,143" href="outlets.php" shape="rect"/>
# <area coords="427,112,536,135" href="feedback.php" shape="rect"/>
# <!--  <area shape="rect" coords="427,113,536,136" href="feedback.php" />
#                <area shape="rect" coords="550,115,659,135" href="outlets.php" /> -->
# </map>
# </div>
# <div class="main-search" style="width:234px; height:137px; float:left; position:relative;
#         background-image: url('images/header-RightSearch128888.gif'); background-size: 101% 100%;">
# <div style="width:100%;position:absolute; top:25%;">
# <div class="Heading1" id="search">
# <form action="/search.php" autocomplete="off" method="get">
# <input id="searchInput" name="q" placeholder="Search" style="width:90%; height:26px" type="text"/>
# <input style="position: absolute; left: -9999px; width: 1px; height: 1px;" tabindex="-1" type="submit">
# <div class="search-buttons">
# <a href="#" id="go">Go</a>
# <a href="advanceSearch.php">Advanced</a>
# </div>
# </input></form>
# <div class="search-result" style="width:110%">
# <div id="livesearch"></div>
# </div>
# </div>
# <!-- <form method="get" action="/search.php" target="_top">
#
#                     <div style="margin-bottom: 5px">
#                         <br />
#                         <input type="hidden" name="domains" value="www.whatmobile.com.pk"/>
#                         <label for="sbi" style="display: none">Enter your search terms</label>
#                         <input type="text" name="q" size="22" maxlength="255" value="" id="sbi"/>
#                     </div>
#                     <div>
#                         <div style="width:100%; margin-bottom: 5px">
#                             <input type="radio" name="sitesearch" value="" id="ss0"/>
#                             <label for="ss0" title="Search the Web"><font size="-1" color="#ffffff">Web</font></label>
#                             &nbsp;
#                             <input type="radio" name="sitesearch" value="www.whatmobile.com.pk" checked id="ss1"/>
#                             <label for="ss1" title="Search www.whatmobile.com.pk"><font size="-1" color="#ffffff">WhatMobile</font></label>
#                         </div>
#
#                         <label for="sbb" style="display: none">Submit search form</label>
#                         <input name="sa" type="submit" class="btn" id="sbb" value="Google Search"/>
#                     </div>
#                 </form> -->
# </div>
# </div>
# </div>
# <div>
# <div style="width:820px; float:left"> </div>
# <div style="width:180px; float:left">
# <div style="width:104px; background-image: url('images/roundrect12004351.gif')">
# <div class="lnk" style="text-align: center; padding-top: 2px; padding-bottom: 4px">
# <span style="color:#333399">Today's Prices</span>
# </div>
# </div>
# </div>
# </div>
# <div>
# <marquee bgcolor="#D9DBDF" height="23" onmouseout="javascript:start()" onmouseover="javascript:stop()" scrollamount="2" scrolldelay="50" width="1000">
# <div style="width:100%; padding: 1px; white-space: nowrap">
# </div>
# </marquee>
# </div>
# </div> </link></div>
# <div id="container" style="width:100%;margin-top: 20px">
# <div style="width:165px;float:left">
# <style type="text/css">
#
#
#
#     <!--
#
#
#
#     .border {
#
#
#
#         border: 1px solid #D9DBDF;
#
#
#
#     }
#
#
#
#     -->
#     .upper {
#         background-image: url("images/upper.gif");
#     }
#
#     .verticalMenu ul {
#         list-style-type: none;
#         margin: 0;
#         padding-top:1px;
#         padding-bottom: 1px;
#         padding-left: 10px;
#         padding-right: 9px;
#         background-image: url("images/shape16424016.gif");
#     }
#
#     .verticalMenu ul li {
#         text-align: left;
#         margin-top:2px;
#         margin-bottom: 2px;
#     }
#
#     .verticalMenu ul li.center {
#         text-align: center;
#     }
#
#     .verticalMenu ul li.heading {
#         display: block;
#         height:23px;
#         line-height: 23px;
#         text-align: center;
#         background-image: url("images/roundrect14918782.gif");
#         background-repeat: no-repeat;
#         background-position: center;
#     }
#
#     .verticalMenu ul li span {
#         vertical-align: middle;
#     }
#
#     .news {
#         font-family: Verdana, Arial, Helvetica, sans-serif;
#         padding: 0;
#         margin-bottom: 12px;
#     }
#     .news img {
#         width: 100%;
#     }
#     .news a {
#         text-decoration: none;
#         color: 808080;
#     }
#     .news h1 {
#         font-size: 0.7rem;
#     }
#
# </style>
# <div class="verticalMenu" style="width:152px">
# <div>
# <img alt="price list options start" class="noBorder" height="19" src="images/upper.gif" width="152"/>
# </div>
# <ul>
# <li class="center">
# <a class="lnk" href="StolenMobile.php" title="Block stolen mobile phones"><u>Block Stolen Mobile </u></a>
# </li>
# <li class="center">
# <a class="lnk" href="VideoReviews.php" title="Mobile phone Video Reviews"><u>Video Reviews</u></a>
# </li>
# <li class="heading Menue">
# <span>Search by Network</span>
# </li>
# <li>
# <a class="lnk" href="Price-List-Of-All-4G_Mobile-Phones" title="4G mobile phones with prices">4G Mobile Prices</a>
# </li>
# <li>
# <a class="lnk" href="Price-List-Of-All-5G_Mobile-Phones" title="5G mobile phones with prices">5G Mobiles </a><img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li class="heading Menue">
# <span>Search by Brand</span>
# </li>
# <li>
# <a class="lnk" href="Samsung_Mobiles_Prices" title="Samsung mobile phones">Samsung mobile</a>
# </li>
# <li>
# <a class="lnk" href="Huawei_Mobiles_Prices" title="Huawei mobile phones">Huawei mobile</a>
# </li>
# <li>
# <a class="lnk" href="Vivo_Mobiles_Prices" title="Vivo mobile phones">Vivo</a>
# </li>
# <li>
# <a class="lnk" href="Honor_Mobiles_Prices" title="Honor mobile phones">Honor mobile</a>
# </li>
# <li><a class="lnk" href="Oppo_Mobiles_Prices" title="OPPO mobile phones">Oppo Mobile</a>
# </li>
# <li><a class="lnk" href="Realme_Mobiles_Prices" title="Realme mobile phones">Realme Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Nokia_Mobiles_Prices" title="Nokia mobile phones">Nokia mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="Xiaomi_Mobiles_Prices" title="Xiaomi mobile phones">Xiaomi Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Infinix_Mobiles_Prices" title="Infinix mobile phones">Infinix Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Apple_Mobiles_Prices" title="Apple iphones">Apple iphone prices</a>
# </li>
# <li>
# <a class="lnk" href="Tecno_Mobiles_Prices" title="Tecno mobile phones">Tecno Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Zte_Mobiles_Prices" title="ZTE mobile phones">ZTE Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Sparx_Mobiles_Prices" title="Sparx mobile phones">Sparx Mobile</a><img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Dcode_Mobiles_Prices" title="Dcode mobile phones">Dcode</a><img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Qmobile_Mobiles_Prices" title="QMobile mobile phones">QMobile</a>
# </li>
# <li>
# <a class="lnk" href="Lenovo_Mobiles_Prices" title="Lenovo mobile phones">Lenovo Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Sony_Mobiles_Prices" title="Sony mobile phones">Sony mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="LG_Mobiles_Prices" title="LG mobile phones">LG mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="Itel_Mobiles_Prices" title="itel mobile phones">itel Mobile</a>
# </li>
# <li>
# <a class="lnk" href="OnePlus_Mobiles_Prices" title="OnePlus mobile phones">OnePlus</a>
# </li>
# <li>
# <a class="lnk" href="Telenor_Mobiles_Prices" title="Telenor mobile phones">Telenor</a><img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Alcatel_Mobiles_Prices" title="Alcatel mobile phones">Alcatel Mobile</a>
# </li>
# <li>
# <a class="lnk" href="HTC_Mobiles_Prices" title="HTC mobile phones">HTC mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="Microsoft_Mobiles_Prices" title="Microsoft mobile phones">Microsoft Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Rivo_Mobiles_Prices" title="Rivo mobile phones">Rivo Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Haier_Mobiles_Prices" title="Haier mobile phones">Haier Mobile Prices</a>
# </li>
# <li>
# <a class="lnk" href="Mobilink_Mobiles_Prices" title="Mobilink Jazz X mobile phones">Mobilink JazzX</a>
# </li>
# <li>
# <a class="lnk" href="Motorola_Mobiles_Prices" title="Motorola mobile phones">Motorola</a>
# </li>
# <li>
# <a class="lnk" href="BlackBerry_Mobiles_Prices" title="Blackberry mobile phones">BlackBerry</a>
# </li>
# <li>
# <a class="lnk" href="Voice_Mobiles_Prices" title="Voice mobile phones">VOICE mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="Meizu_Mobiles_Prices" title="Meizu mobile phones">Meizu Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Calme_Mobiles_Prices" title="Calme mobile phones">Calme Mobile</a>
# </li>
# <li>
# <a class="lnk" href="GRight_Mobiles_Prices" title="Gright mobile phones">GRight Mobile</a>
# </li>
# <li>
# <a class="lnk" href="GFive_Mobiles_Prices" title="GFive mobile phones">G'Five mobile</a>
# </li>
# <li class="heading Menue">
# <span>Search by Price</span>
# </li>
# <li>
# <a class="lnk" href="45000_to_250001_Mobiles" title="Mobile phones with prices greater than 45000">Prices  &gt; 45,000</a>
# </li>
# <li>
# <a class="lnk" href="35000_to_45001_Mobiles" title="Mobile phones in a price range of 35000 to 40000">35,001 - 45,000</a>
# </li>
# <li>
# <a class="lnk" href="25000_to_35001_Mobiles" title="Mobile phones in a price range of 25000 to 35000">25,001 - 35,000</a>
# </li>
# <li>
# <a class="lnk" href="15000_to_25001_Mobiles" title="Mobile phones in a price range of 15000 to 25000">15,001 - 25,000</a>
# </li>
# <li>
# <a class="lnk" href="10000_to_15001_Mobiles" title="Mobile phones in a price range of 10000 to 15000">10,001 - 15,000</a>
# </li>
# <li>
# <a class="lnk" href="5000_to_10001_Mobiles" title="Mobile phones in a price range of 5000 to 10000">5,001 - 10,000</a>
# </li>
# <li>
# <a class="lnk" href="0_to_5001_Mobiles" title="Mobile phones below 5000 Rupees">Prices &lt; 5000</a>
# </li>
# <li>
# <a class="lnk" href="0_to_150001_Mobiles" title="All mobile phones">All Mobile Prices</a>
# </li>
# <li class="heading Menue">
# <span>Search by RAM</span>
# </li>
# <li>
# <a class="lnk" href="2GB-RAM_Mobile-Phones" title="Mobile phones with 2GB RAM">2GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="3GB-RAM_Mobile-Phones" title="Mobile phones with 3GB RAM">3GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="4GB-RAM_Mobile-Phones" title="Mobile phones with 4GB RAM">4GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="6GB-RAM_Mobile-Phones" title="Mobile phones with 6GB RAM">6GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="8GB-RAM_Mobile-Phones" title="Mobile phones with 8GB RAM">8GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="12GB-RAM_Mobile-Phones" title="Mobile phones with 12GB RAM">12GB &amp; above RAM</a>
# </li>
# <li class="heading Menue">
# <span>Search by Screen</span>
# </li>
# <li>
# <a class="lnk" href="1.0-To-2.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with less than 3 inch display">Less Then 3 Inches</a>
# </li>
# <li>
# <a class="lnk" href="3.0-To-4.0-inches-Display-Size_Mobile-Phones" title="Mobile phones with 3 to 4 inch display">3.0 inch - 4.0 inch</a>
# </li>
# <li>
# <a class="lnk" href="4.1-To-4.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 4.1 to 4.9 inch display">4.1 inch - 4.9 inch</a>
# </li>
# <li>
# <a class="lnk" href="5.0-To-6.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 5 to 6.9 inch display">5.0 inch - 6.9 inch</a>
# </li>
# <li>
# <a class="lnk" href="7.0-To-8.9-inches-Display-Size_Mobile-Phones" title="Devices with 7 to 8.9 inch display">7.0 inch - 8.9 inch</a>
# </li>
# <li class="heading Menue">
# <span>Search by Cam</span>
# </li>
# <li>
# <a class="lnk" href="13mp-Camera_Mobile-Phones" title="Mobile phones with 13MP Camera">13 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="8mp-Camera_Mobile-Phones" title="Mobile phones with 8MP Camera">8 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="5mp-Camera_Mobile-Phones" title="Mobile phones with 5MP Camera">5 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="3mp-Camera_Mobile-Phones" title="Mobile phones with 3MP Camera">3 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="2mp-Camera_Mobile-Phones" title="Mobile phones with 2MP Camera">2 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="1mp-Camera_Mobile-Phones" title="Mobile phones with 1MP Camera">1 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="VGA-Camera_Mobile-Phones" title="Mobile phones with VGA Camera">VGA Cam or less</a>
# </li>
# <li>
# <a class="lnk" href="Without-Camera_Mobile-Phones" title="Mobile phones without Camera">Without Camera</a>
# </li>
# <li class="heading Menue">
# <span>Search by Type</span>
# </li>
# <li>
# <a class="lnk" href="Camera_Mobile-Phones" title="Mobile phones having a Camera">Camera Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="Video_Mobile-Phones" title="Mobile phones with video recording feature">Video Recording</a>
# </li>
# <li>
# <a class="lnk" href="Bluetooth_Mobile-Phones" title="Mobile phones with bluetooth">Bluetooth Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="DualSim_Mobile-Phones" title="Dual-Sim mobile phones">Dual Sim Phones</a>
# </li>
# <li>
# <a class="lnk" href="LAN_Mobile-Phones" title="Mobile phones with Wifi">Wireless LAN </a>
# </li>
# <li>
# <a class="lnk" href="MP3_Mobile-Phones" title="Mobile phones with MP3 playback">MP3 Playback </a>
# </li>
# <li>
# <a class="lnk" href="FM_Mobile-Phones" title="Mobile phones with FM Radio">FM Radio Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="MemoryCard_Mobile-Phones" title="Mobile phones having a card slot">Memory Card </a>
# </li>
# <li class="heading Menue">
# <span>Search by OS<img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/></span>
# </li>
# <li>
# <a class="lnk" href="Android_Mobile-Phones" title="All Android mobile phones">Android Phones </a>
# </li>
# <li>
# <a class="lnk" href="Feature_Mobile-Phones" title="All Feature mobile phones">Feature Phones </a>
# </li>
# <li>
# <a class="lnk" href="Windows_Mobile-Phones" title="All Windows mobile phones">Windows Phones </a>
# </li>
# <li>
# <a class="lnk" href="Smartphone_Mobile-Phones" title="All Smartphones">All Smartphones </a>
# </li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# <div>
# <img alt="price list options end" class="noBorder" height="19" src="images/bottom.gif" width="152"/>
# </div>
# </div>
# <br/>
# <div class="verticalMenu" style="width:152px">
# <div>
# <img alt="price list options start" class="noBorder" height="19" src="images/upper.gif" width="152"/>
# </div>
# <ul>
# <li> </li>
# <li class="heading Menue">
# <span><a class="Menue" href="advanceSearch.php" style="text-decoration:none" title="Advance mobile phone search">Advance Search</a></span>
# </li>
# <li> </li>
# </ul>
# <div>
# <img alt="price list options end" class="noBorder" height="19" src="images/bottom.gif" width="152"/>
# </div>
# </div> </div>
# <div style="float:left">
# <div style="width:653px">
# <div style="width:100%;text-align: right;display: inline-block">
# <span class="NavLinks">   <ol class="NavLinks">
# <li class="NavLinks"><a class="NavLinks" href="../">Mobile Prices</a></li>
# <li class="NavLinks">  &gt;  <u><a href="/Samsung_Mobiles_Prices">Samsung Mobiles with Price</a></u>
# </li>
# </ol></span>  <span class="RowBG2"> Samsung Mobile Prices </span>
#
#                 </div>
# <div style="width:100%;text-align: left">
# <h1 class="hdngLookup" style="padding:0px; margin:0px; display:inline-block;">
#                            Samsung Mobiles - Samsung Mobile Phone Prices                         </h1>
# <div class="BiggerText" style="padding-left: 17px; padding-top: 10px; padding-bottom: 10px;" valign="middle">Samsung Electric is a South Korean company based in Seoul and was founded in 1969. Samsung Electronics is known for producing some world-class products ranging from semiconductors to LEDs, quantum dot TVs, notebooks, and Samsung Mobile Phones to Android tablets. Since releasing its debut Android smartphone in 2009, the company now holds the lion's share in the smartphone and Phablet market not just in Pakistan but around the world. From feature phones to Windows handsets and from smartphones running on Tizen OS to Android-based smartphones. Samsung's latest mobile phones need no introduction. Whether it be the Galaxy range or Note, or A series, Samsung offers a reliable multifunctional cell phone soup at different price ranges. Listed below is the Samsung New Model 2024 Phone Price in Pakistan.</div><div align="left" class="RowBG2" colspan="6" style="padding-left: 17px; padding-top: 3px; padding-bottom: 3px;" valign="middle"> <h2 class="Heading1" style="padding:0px; margin:0px; display:inline;">Latest Samsung Phones Price in Pakistan 2024</h2></div> <div class="BiggerText" style="padding-left: 17px; padding-top: 10px; padding-bottom: 10px;" valign="middle"></div>
# <ul class="nav nav-tabs">
# <li class="active" role="presentation"><a href="Samsung_Mobiles_Prices">Prices</a></li>
# <li class="" role="presentation"><a href="Latest_Samsung_Mobiles_Prices">Latest</a></li>
# <li class="" role="presentation">
# <a href="Comingsoon_Samsung_Mobiles_Prices">Coming Soon</a></li>
# </ul>
# <div class="mobiles" itemscope="" itemtype="http://schema.org/ItemList">
# <meta content="Descending" itemprop="itemListOrder"/>
# <meta content="136 Items" itemprop="name"/>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="1" itemprop="position">
# <div>
# <a href="/Samsung_Galaxy-Z-Fold-5" itemprop="url" title="Samsung Galaxy Z Fold 5 mobiles support 7.6 inches display 1812 x 2176 Pixels (~373 PPI)
# Smartphone Sensors: Accelerometer, Compass, Fingerprint (side-mounted), Gyro, Proximity">
# <img alt="Samsung Galaxy Z Fold 5 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFold5-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-5" style="text-decoration:none" title="Samsung Galaxy Z Fold 5 price">
#                                             Samsung<br/>Galaxy Z Fold 5<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 656,999                                        </span>
# </div>
# </meta></div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="2" itemprop="position">
# <div>
# <a href="/Samsung_Galaxy-Z-Fold-6" itemprop="url" title="Samsung Galaxy Z Fold 6 mobiles support 7.6 inches display 1856 x 2160 Pixels (~375 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, FingerPrint, Proximity, Samsung DeX, Ultra Wideband">
# <img alt="Samsung Galaxy Z Fold 6 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFold6-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-6" style="text-decoration:none" title="Samsung Galaxy Z Fold 6 price">
#                                             Samsung<br/>Galaxy Z Fold 6<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 604,999                                        </span>
# </div>
# </meta></div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="3" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Z-Fold-4-12GB" itemprop="url" title="Samsung Galaxy Z Fold 4 12GB mobiles support 7.6 inches display 1812 x 2176 Pixels (~373 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (side mounted), Gyro, Proximity">
# <img alt="Samsung Galaxy Z Fold 4 12GB Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFold412GB-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-4-12GB" style="text-decoration:none" title="Samsung Galaxy Z Fold 4 12GB price">
#                                             Samsung<br/>Galaxy Z Fold 4 12GB<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 574,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="4" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Z-Fold-4" itemprop="url" title="Samsung Galaxy Z Fold 4 mobiles support 7.6 inches display 1812 x 2176 Pixels (~373 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (side mounted), Gyro, Proximity">
# <img alt="Samsung Galaxy Z Fold 4 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFold4-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-4" style="text-decoration:none" title="Samsung Galaxy Z Fold 4 price">
#                                             Samsung<br/>Galaxy Z Fold 4<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 539,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="5" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S24-Ultra-512GB" itemprop="url" title="Samsung Galaxy S24 Ultra 512GB mobiles support 6.8 inches display 1440 x 3120 Pixels (~505 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S24 Ultra 512GB Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS24Ultra512-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S24-Ultra-512GB" style="text-decoration:none" title="Samsung Galaxy S24 Ultra 512GB price">
#                                             Samsung<br/>Galaxy S24 Ultra 512GB<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 469,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="6" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S24-Ultra" itemprop="url" title="Samsung Galaxy S24 Ultra mobiles support 6.8 inches display 1440 x 3120 Pixels (~505 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S24 Ultra Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS24Ultra-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S24-Ultra" style="text-decoration:none" title="Samsung Galaxy S24 Ultra price">
#                                             Samsung<br/>Galaxy S24 Ultra<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 434,999                                        </span>
# </div>
# </div>
# <div><hr/></div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="7" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S22-Ultra" itemprop="url" title="Samsung Galaxy S22 Ultra mobiles support 6.8 inches display 1440 x 3080 Pixels (~500 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S22 Ultra Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS22Ultra-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S22-Ultra" style="text-decoration:none" title="Samsung Galaxy S22 Ultra price">
#                                             Samsung<br/>Galaxy S22 Ultra<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 424,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="8" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S23" itemprop="url" title="Samsung Galaxy S23 mobiles support 6.1 inches display 1980 x 2340 Pixels (~503 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, FingerPrint (under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S23 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS23-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S23" style="text-decoration:none" title="Samsung Galaxy S23 price">
#                                             Samsung<br/>Galaxy S23<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 399,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="9" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S23-Ultra" itemprop="url" title="Samsung Galaxy S23 Ultra mobiles support 6.8 inches display 1440 x 3088 Pixels (~501 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S23 Ultra Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS23Ultra-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S23-Ultra" style="text-decoration:none" title="Samsung Galaxy S23 Ultra price">
#                                             Samsung<br/>Galaxy S23 Ultra<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 389,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="10" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Z-Flip-6" itemprop="url" title="Samsung Galaxy Z Flip 6 mobiles support 6.7 inches display 1080 x 2640 Pixels (~426 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (side mounted), Gyro, Proximity">
# <img alt="Samsung Galaxy Z Flip 6 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFlip6-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Flip-6" style="text-decoration:none" title="Samsung Galaxy Z Flip 6 price">
#                                             Samsung<br/>Galaxy Z Flip 6<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 384,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="11" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Z-Flip-5" itemprop="url" title="Samsung Galaxy Z Flip 5 mobiles support 6.7 inches display 1080 x 2640 Pixels (~426 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (side mounted), Gyro, Proximity">
# <img alt="Samsung Galaxy Z Flip 5 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFlip5-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Flip-5" style="text-decoration:none" title="Samsung Galaxy Z Flip 5 price">
#                                             Samsung<br/>Galaxy Z Flip 5<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 368,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="12" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Z-Flip-4" itemprop="url" title="Samsung Galaxy Z Flip 4 mobiles support 6.7 inches display 1080 x 2640 Pixels (~426 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (side mounted), Gyro, Proximity">
# <img alt="Samsung Galaxy Z Flip 4 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFlip4-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Flip-4" style="text-decoration:none" title="Samsung Galaxy Z Flip 4 price">
#                                             Samsung<br/>Galaxy Z Flip 4<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 332,999                                        </span>
# </div>
# </div>
# <div><hr/></div>
# <!-- show advertisement -->
# <div style="text-align: center">
# <!-- Category_300x250_Left -->
# <div class="ad-item" id="div-gpt-ad-1382589263041-0" style="width:300px; height:250px;">
# <script type="text/javascript">
#                                             googletag.cmd.push(function () {
#                                                 googletag.display('div-gpt-ad-1382589263041-0');
#                                             });
#                                         </script>
# </div>
# <!-- Category_300x250_Right -->
# <div class="ad-item" id="div-gpt-ad-1386929247463-0" style="width:300px; height:250px;">
# <script type="text/javascript">
#                                             googletag.cmd.push(function () {
#                                                 googletag.display('div-gpt-ad-1386929247463-0');
#                                             });
#                                         </script>
# </div>
# </div>
# <div>
# <hr/>
# </div>
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="13" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Z-Fold-3" itemprop="url" title="Samsung Galaxy Z Fold 3 mobiles support 7.6 inches display 1768 x 2208 Pixels (~372 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (side mounted), Gyro, Proximity">
# <img alt="Samsung Galaxy Z Fold 3 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFold3-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-3" style="text-decoration:none" title="Samsung Galaxy Z Fold 3 price">
#                                             Samsung<br/>Galaxy Z Fold 3<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 314,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="14" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S24" itemprop="url" title="Samsung Galaxy S24 mobiles support 6.2 inches display 1080 x 2340 Pixels (~416 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, FingerPrint (under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S24 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS24-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S24" style="text-decoration:none" title="Samsung Galaxy S24 price">
#                                             Samsung<br/>Galaxy S24<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 289,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="15" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S21-Ultra" itemprop="url" title="Samsung Galaxy S21 Ultra mobiles support 6.8 inches display 1440 x 3200 Pixels (~516 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S21 Ultra Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS21Ultra-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S21-Ultra" style="text-decoration:none" title="Samsung Galaxy S21 Ultra price">
#                                             Samsung<br/>Galaxy S21 Ultra<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 242,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="16" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S22" itemprop="url" title="Samsung Galaxy S22 mobiles support 6.1 inches display 1080 x 2340 Pixels (~422 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, FingerPrint (under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S22 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS22-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S22" style="text-decoration:none" title="Samsung Galaxy S22 price">
#                                             Samsung<br/>Galaxy S22<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 232,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="17" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Note-20-Ultra" itemprop="url" title="Samsung Galaxy Note 20 Ultra mobiles support 6.9 inches display 1440 x 3088 Pixels (~494 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, FingerPrint (under display, ultrasonic), Gyro">
# <img alt="Samsung Galaxy Note 20 Ultra Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyNote20Ultra-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Note-20-Ultra" style="text-decoration:none" title="Samsung Galaxy Note 20 Ultra price">
#                                             Samsung<br/>Galaxy Note 20 Ultra<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 219,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="18" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S24-FE" itemprop="url" title="Samsung Galaxy S24 FE mobiles support 6.7 inches display 1080 x 2340 Pixels (~385 PPI)
# Smartphone Sensors: Accelerometer, Compass, Fingerprint (under display, optical), Gyro, Virtual proximity sensing, Samsung DeX, Circle to Search">
# <img alt="Samsung Galaxy S24 FE Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS24FE-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S24-FE" style="text-decoration:none" title="Samsung Galaxy S24 FE price">
#                                             Samsung<br/>Galaxy S24 FE<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 219,999                                        </span>
# </div>
# </div>
# <div><hr/></div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="19" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S23-FE" itemprop="url" title="Samsung Galaxy S23 FE mobiles support 6.4 inches display 1080 x 2340 Pixels (~403 PPI)
# Smartphone Sensors: Accelerometer, Compass, Fingerprint (under display, optical), Gyro, Proximity, Virtual proximity sensing">
# <img alt="Samsung Galaxy S23 FE Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS23FE-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S23-FE" style="text-decoration:none" title="Samsung Galaxy S23 FE price">
#                                             Samsung<br/>Galaxy S23 FE<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 204,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="20" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Z-Flip-3" itemprop="url" title="Samsung Galaxy Z Flip 3 mobiles support 6.7 inches display 1080 x 2640 Pixels (~426 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (side mounted), Gyro, Proximity">
# <img alt="Samsung Galaxy Z Flip 3 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyZFlip3-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Z-Flip-3" style="text-decoration:none" title="Samsung Galaxy Z Flip 3 price">
#                                             Samsung<br/>Galaxy Z Flip 3<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 199,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="21" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S21-Plus" itemprop="url" title="Samsung Galaxy S21 Plus mobiles support 6.7 inches display 1080 x 2400 Pixels (~393 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint(under display, ultrasonic), Gyro, Proximity">
# <img alt="Samsung Galaxy S21 Plus Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS21Plus-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S21-Plus" style="text-decoration:none" title="Samsung Galaxy S21 Plus price">
#                                             Samsung<br/>Galaxy S21 Plus<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 184,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="22" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-Note-20" itemprop="url" title="Samsung Galaxy Note 20 mobiles support 6.7 inches display 1080 x 2400 Pixels (~393 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (under display, ultrasonic), Gyro">
# <img alt="Samsung Galaxy Note 20 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyNote20-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-Note-20" style="text-decoration:none" title="Samsung Galaxy Note 20 price">
#                                             Samsung<br/>Galaxy Note 20<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 179,999                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="23" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S21" itemprop="url" title="Samsung Galaxy S21 mobiles support 6.2 inches display 1080 x 2400 Pixels (~424 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (under display, ultrasonic), Gyro, Proximity, SpO2">
# <img alt="Samsung Galaxy S21 Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS21-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S21" style="text-decoration:none" title="Samsung Galaxy S21 price">
#                                             Samsung<br/>Galaxy S21<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 176,499                                        </span>
# </div>
# </div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="24" itemprop="position"/>
# <div>
# <a href="/Samsung_Galaxy-S21-FE-256GB" itemprop="url" title="Samsung Galaxy S21 FE 256GB mobiles support 6.4 inches display 1080 x 2400 Pixels (~411 PPI)
# Smartphone Sensors: Accelerometer, Barometer, Compass, Fingerprint (under display, optical), Gyro, Proximity">
# <img alt="Samsung Galaxy S21 FE 256GB Price in Pakistan" border="0" height="100" itemprop="image" src="admin/images/Samsung/SamsungGalaxyS21FE256GB-s.jpg" width="75"/>
# </a>
# <h4 class="p4 biggertext"><a class="BiggerText" href="/Samsung_Galaxy-S21-FE-256GB" style="text-decoration:none" title="Samsung Galaxy S21 FE 256GB price">
#                                             Samsung<br/>Galaxy S21 FE 256GB<br/></a></h4>
# <span class="PriceFont">
#                                             Rs. 172,999                                        </span>
# </div>
# </div>
# <div><hr/></div>
# <!-- show advertisement -->
# <!-- show mobile items -->
# <div class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <meta content="25" itemprop="position"/>
# <div>
# ...
# <div style="width: 155px; float:right">
# <style type="text/css">
#     <!--
#     .style8 {
#         font-size: 12px;
#         font-weight: bold;
#         font-family: Verdana, Arial, Helvetica, sans-serif;
#         color: #194073;
#     }
#
#     .border {
#         border: 1px solid #D9DBDF;
#     }
#
#     .borderp {
#         border: 1px solid #D9DBDF;
#         width: 160px;
#     }
#
#     .style9 {
#         font-size: 3px;
#         color: #FFFFFF;
#     }
#
#     -->
#     .post_thumbnail img {
#         max-width: 100%;
#         height: 100px;
#     }
# </style>
# <div style="width:160px; height: 761px">
# <!--    <div style="height: 4px">&nbsp;</div>-->
# <div style="width: 150px; height: 12px">
# <img alt="Samsung in Pakistan" height="15" src="images/uppergray.gif" width="150"/>
# </div>
# <div class="div-outer" style="width: 150px; height:51px; text-align: center; background-image: url('images/betweengrey2.gif')">
# <div class="div-centered">
# <div style="width:116px; height: 36px; line-height: 36px; text-align: right; float:left">
# <a href="advanceSearch.php"><span class="style8"><u>Advance Search</u></span></a>
# </div>
# <div style="width:30px; float: left">
# <img alt="Samsung Mobiles" height="36" src="search.gif" width="29">
# <script src="https://apis.google.com/js/plusone.js" type="text/javascript"></script>
# </img></div>
# </div>
# </div>
# <div style="width: 150px; height:12px;">
# <img height="15" src="images/belowgrey.gif" width="150"/>
# </div>
# <br/>
# <div>
# <!-- AddThis Button BEGIN
#         <script type="text/javascript">addthis_pub  = 'aamirprince20';</script>
#         <a href="http://www.addthis.com/bookmark.php" onmouseover="return addthis_open(this, '', '[URL]', '[TITLE]')" onmouseout="addthis_close()" onclick="return addthis_sendto()"><img src="http://s9.addthis.com/button1-bm.gif" width="125" height="16" border="0" alt="" /></a><script type="text/javascript" src="http://s7.addthis.com/js/152/addthis_widget.js"></script>
#          AddThis Button END -->
# </div>
# <div class="border">
# <div id="div-gpt-ad-1382717875007-0" style="width:160px; height:600px;">
# <script type="text/javascript">
#                 googletag.cmd.push(function () {
#                     googletag.display('div-gpt-ad-1382717875007-0');
#                 });
#             </script>
# </div>
# </div>
# <br/>
# <!---- latest news  -->
# <div class="Latest NEwsnormText" id="reviews" style="width:100%; text-align: center;">
# <br/>
# <h2 style="    padding: 5px 10px;
#     font-size: 15px;
#     margin: 0px;
#     display: inline;
#     font-weight: small;
#     background-color: #808080;
# ">
# <a href="https://www.whatmobile.com.pk/news.php?tag=samsung" style="text-decoration:none; color: #FFF;"></a>Latest Samsung News
#             </h2>
# <ul style=" list-style-type: none;padding:0">
# <li style="margin-bottom: 10px;">
# <a href="https://www.whatmobile.com.pk/samsung-galaxy-s25-reappears-on-geekbench-now-sporting-an-exynos-chip-news-5642" style="text-decoration: none;" title="Samsung Galaxy S25+ Reappears on Geekbench, Now Sporting an Exynos Chip">
# <span class="post_thumbnail">
# <img alt="Samsung Galaxy S25+ Reappears on Geekbench, Now Sporting an Exynos Chip" async="" data-savepage-src="https://www.whatmobile.com.pk/control/news/assets/07122024/f87aa36ecbd6581a793325bb3791ce38_thumb.jpg" height="120" src="https://www.whatmobile.com.pk/control/news/assets/07122024/f87aa36ecbd6581a793325bb3791ce38_thumb.jpg" title="Samsung Galaxy S25+ Reappears on Geekbench, Now Sporting an Exynos Chip " width="160"/>
# </span>
# </a>
# <h6 class="p6 biggerText" style="font-weight: bold !important; margin:0px; display:inline;">
# <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-s25-reappears-on-geekbench-now-sporting-an-exynos-chip-news-5642" title="Samsung Galaxy S25+ Reappears on Geekbench, Now Sporting an Exynos Chip">
#
#                                 Samsung Galaxy S25+ Reappears on Geekbench, Now Sporting an Ex...
#                             </a></h6>
# </li>
# <li style="margin-bottom: 10px;">
# <a href="https://www.whatmobile.com.pk/samsung-galaxy-s25-slim-will-be-launching-worldwide-and-heres-the-proof-news-5624" style="text-decoration: none;" title="Samsung Galaxy S25 Slim will be Launching Worldwide and Here’s the Proof">
# <span class="post_thumbnail">
# <img alt="Samsung Galaxy S25 Slim will be Launching Worldwide and Here’s the Proof" async="" data-savepage-src="https://www.whatmobile.com.pk/control/news/assets/30112024/bfd30b48498bf59d895dfda9472e7365_thumb.jpg" height="120" src="https://www.whatmobile.com.pk/control/news/assets/30112024/bfd30b48498bf59d895dfda9472e7365_thumb.jpg" title="Samsung Galaxy S25 Slim will be Launching Worldwide and Here’s the Proof " width="160"/>
# </span>
# </a>
# <h6 class="p6 biggerText" style="font-weight: bold !important; margin:0px; display:inline;">
# <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-s25-slim-will-be-launching-worldwide-and-heres-the-proof-news-5624" title="Samsung Galaxy S25 Slim will be Launching Worldwide and Here’s the Proof">
#
#                                 Samsung Galaxy S25 Slim will be Launching Worldwide and Here�...
#                             </a></h6>
# </li>
# <li style="margin-bottom: 10px;">
# <a href="https://www.whatmobile.com.pk/samsung-galaxy-a54-bags-the-latest-security-stability-update-fornovember2024-news-5623" style="text-decoration: none;" title="Samsung Galaxy A54 Bags the Latest Security &amp; Stability Update for November 2024">
# <span class="post_thumbnail">
# <img alt="Samsung Galaxy A54 Bags the Latest Security &amp; Stability Update for November 2024" async="" data-savepage-src="https://www.whatmobile.com.pk/control/news/assets/30112024/19a942309a9f3ae4334fe7ea9f7c31d7_thumb.jpg" height="120" src="https://www.whatmobile.com.pk/control/news/assets/30112024/19a942309a9f3ae4334fe7ea9f7c31d7_thumb.jpg" title="Samsung Galaxy A54 Bags the Latest Security &amp; Stability Update for November 2024 " width="160"/>
# </span>
# </a>
# <h6 class="p6 biggerText" style="font-weight: bold !important; margin:0px; display:inline;">
# <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-a54-bags-the-latest-security-stability-update-fornovember2024-news-5623" title="Samsung Galaxy A54 Bags the Latest Security &amp; Stability Update for November 2024">
#
#                                 Samsung Galaxy A54 Bags the Latest Security &amp; Stability Update...
#                             </a></h6>
# </li>
# <li style="margin-bottom: 10px;">
# <a href="https://www.whatmobile.com.pk/samsung-galaxy-s25-ultra-live-shots-surface-alongside-the-first-look-at-one-ui-70-news-5618" style="text-decoration: none;" title="Samsung Galaxy S25 Ultra Live Shots Surface Alongside the First Look at One UI 7.0">
# <span class="post_thumbnail">
# <img alt="Samsung Galaxy S25 Ultra Live Shots Surface Alongside the First Look at One UI 7.0" async="" data-savepage-src="https://www.whatmobile.com.pk/control/news/assets/28112024/03e3389dc0a91db96bdc4a233a0b8257_thumb.jpg" height="120" src="https://www.whatmobile.com.pk/control/news/assets/28112024/03e3389dc0a91db96bdc4a233a0b8257_thumb.jpg" title="Samsung Galaxy S25 Ultra Live Shots Surface Alongside the First Look at One UI 7.0 " width="160"/>
# </span>
# </a>
# <h6 class="p6 biggerText" style="font-weight: bold !important; margin:0px; display:inline;">
# <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-s25-ultra-live-shots-surface-alongside-the-first-look-at-one-ui-70-news-5618" title="Samsung Galaxy S25 Ultra Live Shots Surface Alongside the First Look at One UI 7.0">
#
#                                 Samsung Galaxy S25 Ultra Live Shots Surface Alongside the Firs...
#                             </a></h6>
# </li>
# <li style="margin-bottom: 10px;">
# <a href="https://www.whatmobile.com.pk/samsung-galaxy-z-flip-fe-leaked-as-companys-first-budget-clamshell-with-exynos-2400e-news-5609" style="text-decoration: none;" title="Samsung Galaxy Z Flip FE Leaked as Company’s First Budget Clamshell with Exynos 2400e">
# <span class="post_thumbnail">
# <img alt="Samsung Galaxy Z Flip FE Leaked as Company’s First Budget Clamshell with Exynos 2400e" async="" data-savepage-src="https://www.whatmobile.com.pk/control/news/assets/27112024/c80e941e08bea4a4fbf78daf4ff8ab8a_thumb.jpg" height="120" src="https://www.whatmobile.com.pk/control/news/assets/27112024/c80e941e08bea4a4fbf78daf4ff8ab8a_thumb.jpg" title="Samsung Galaxy Z Flip FE Leaked as Company’s First Budget Clamshell with Exynos 2400e " width="160"/>
# </span>
# </a>
# <h6 class="p6 biggerText" style="font-weight: bold !important; margin:0px; display:inline;">
# <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-z-flip-fe-leaked-as-companys-first-budget-clamshell-with-exynos-2400e-news-5609" title="Samsung Galaxy Z Flip FE Leaked as Company’s First Budget Clamshell with Exynos 2400e">
#
#                                 Samsung Galaxy Z Flip FE Leaked as Company’s First Budget Cl...
#                             </a></h6>
# </li>
# <li style="margin-bottom: 10px;">
# <a href="https://www.whatmobile.com.pk/samsung-galaxy-a33-a34-finally-updated-with-november-2024-security-patch-news-5617" style="text-decoration: none;" title="Samsung Galaxy A33 &amp; A34 Finally Updated with November 2024 Security Patch">
# <span class="post_thumbnail">
# <img alt="Samsung Galaxy A33 &amp; A34 Finally Updated with November 2024 Security Patch" async="" data-savepage-src="https://www.whatmobile.com.pk/control/news/assets/28112024/ac823611982acd21ec533e059d902a10_thumb.jpg" height="120" src="https://www.whatmobile.com.pk/control/news/assets/28112024/ac823611982acd21ec533e059d902a10_thumb.jpg" title="Samsung Galaxy A33 &amp; A34 Finally Updated with November 2024 Security Patch " width="160"/>
# </span>
# </a>
# <h6 class="p6 biggerText" style="font-weight: bold !important; margin:0px; display:inline;">
# <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-a33-a34-finally-updated-with-november-2024-security-patch-news-5617" title="Samsung Galaxy A33 &amp; A34 Finally Updated with November 2024 Security Patch">
#
#                                 Samsung Galaxy A33 &amp; A34 Finally Updated with November 2024 Se...
#                             </a></h6>
# </li>
# </ul>
# <style>
#             .textLatest {
#                 text-decoration: none;
#                 /* font-size: 13px !important; */
#                 /* font-weight: 600 !important; */
#                 text-align: justify;
#                 /* padding: 4px 0px; */
#                 text-justify: inter-word;
#                 width: 100%;
#                 /* line-height: 15.5px; */
#                 margin-top: 5px;
#                 display: block;
#                 font-family: Arial, Helvetica, sans-serif;
#                 /* font-weight: normal;*/
#             }
#         </style>
# </div>
# <!----  latest news  -->
# <div class="border" style="text-align: center">
# <tr class="border" valign="top"> <td align="center" class="borderp" colspan="2" height="150" valign="top" width="160"><span class="hdngArial"> Tags </span><br/><br/> <span class="Taggs">Samsung Mobiles with Price,  Samsung Mobile Prices, Samsung Mobile Rates Pakistan, Samsung Mobile Phones Pakistan, Samsung Pakistan, Samsung Smartphones</span></td> </tr>
# <div> </div>
# </div>
# <div class="normText" id="reviews" style="width:100%; text-align: center;">
# </div>
# </div>
# </div>
# <div> </div>
# </div>
# <!--Footer-->
# <div style="width: 100%; text-align: center; display:inline-block;margin-bottom:20px;">
# <div style="width: 653px; margin:auto">
# <div align="center" class="normText"><span id="Footer1_S21">  <br> <strong>Disclaimer.</strong> Mobile Prices are updated daily from local Pakistani Mobile shops &amp; Mobile dealers in Pakistan but we can not guarantee that the information (Prices) on this page is 100% correct (Human error is possible). Always visit your local shop for exact mobile prices. *Above mobile prices and rates are only valid in Pakistan.<br/><br/>Copyright © 2024       www.whatmobile.com.pk. All Rights Reserved. </br></span><br/>
# <span id="Footer1_S21"><a href="Privacy.php" style="text-decoration:none">Privacy</a> | <a href="Advertise.php" style="text-decoration:none">Advertise</a> | <a href="feedback.php" style="text-decoration:none">Contact us</a>
#  | <a href="https://m.whatmobile.com.pk/Samsung_Mobiles_Prices" rel="alternate" style="text-decoration:none"> Mobile Version</a> </span>
# <table border="0" cellpadding="0" cellspacing="0" width="122">
# <tr>
# <td align="center"><!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3910358-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-3910358-1');
# </script>
#  </td>
# </tr>
# </table>
# <script type="text/javascript"> <!--
#
#         ap_showWaitMessage('waitDiv', 0);
#
#     //--> </script>
# <script src="js/jquery.min.js" type="text/javascript"></script>
# <script src="js/search.top.js" type="text/javascript"></script>
# <script src="js/ajax.js" type="text/javascript"></script>
# <script src="js/clamp.min.js" type="text/javascript"></script>
# <!-- Import and configure the Firebase SDK -->
# <script src="https://www.gstatic.com/firebasejs/7.24.0/firebase-app.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.24.0/firebase-messaging.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.24.0/firebase-auth.js"></script>
# <script src="https://cdn.firebase.com/libs/firebaseui/3.5.2/firebaseui.js"></script>
# <link href="https://cdn.firebase.com/libs/firebaseui/3.5.2/firebaseui.css" rel="stylesheet" type="text/css"/>
# <!-- Firebase initialization handled by init.js -->
# <script src="/js/fcmp/init.js?v=1.5"></script>
# <!-- Service class for WMService -->
# <script src="/js/fcmp/wm-service.js?v=1.5"></script>
# <!-- Messaging script for foreground notifications -->
# <script src="/js/fcmp/whatmobile-messaging1.js?v=1.5"></script>
# <!-- Register the service worker for background notifications -->
# <script>
# if ('serviceWorker' in navigator) {
#   navigator.serviceWorker.getRegistration('/firebase-messaging-sw.js').then(function(registration) {
#     if (!registration) {
#       // Service worker is not registered, register it
#       navigator.serviceWorker.register('/firebase-messaging-sw.js', { scope: '/' })
#         .then(function(registration) {
#           console.log('Service Worker registered with scope:', registration.scope);
#         }).catch(function(error) {
#           console.error('Service Worker registration failed:', error);
#         });
#     } else {
#       // Service worker is already registered
#       console.log('Service Worker already registered:', registration);
#     }
#   });
# }
# </script>
# </div> </div>
# </div>
# <div style="display:inline-block"> </div>
# </div>
# <div id="footer" style="position:fixed; bottom: 0;width:100%">
# <div>
# <div style="width:85%; float:left"> </div>
# <div style="float:left">
# <div style="width:104px; background-image: url('images/roundrect12004351.gif')">
# </div>
# </div>
# </div>
# <div>
# </div>
# </div>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'8ef5a61c6ff487f9',t:'MTczMzc1NDE2My4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>

# %% [markdown]
# ### Find all links with class "s1Q9rs" on the search results page

# %%
links = soup.find_all("a",class_="BiggerText")

# %% [markdown]
# ### Print the list of links

# %%
links
# Out:
# [<a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-5" style="text-decoration:none" title="Samsung Galaxy Z Fold 5 price">
#                                              Samsung<br/>Galaxy Z Fold 5<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-6" style="text-decoration:none" title="Samsung Galaxy Z Fold 6 price">
#                                              Samsung<br/>Galaxy Z Fold 6<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-4-12GB" style="text-decoration:none" title="Samsung Galaxy Z Fold 4 12GB price">
#                                              Samsung<br/>Galaxy Z Fold 4 12GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-4" style="text-decoration:none" title="Samsung Galaxy Z Fold 4 price">
#                                              Samsung<br/>Galaxy Z Fold 4<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S24-Ultra-512GB" style="text-decoration:none" title="Samsung Galaxy S24 Ultra 512GB price">
#                                              Samsung<br/>Galaxy S24 Ultra 512GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S24-Ultra" style="text-decoration:none" title="Samsung Galaxy S24 Ultra price">
#                                              Samsung<br/>Galaxy S24 Ultra<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S22-Ultra" style="text-decoration:none" title="Samsung Galaxy S22 Ultra price">
#                                              Samsung<br/>Galaxy S22 Ultra<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S23" style="text-decoration:none" title="Samsung Galaxy S23 price">
#                                              Samsung<br/>Galaxy S23<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S23-Ultra" style="text-decoration:none" title="Samsung Galaxy S23 Ultra price">
#                                              Samsung<br/>Galaxy S23 Ultra<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Flip-6" style="text-decoration:none" title="Samsung Galaxy Z Flip 6 price">
#                                              Samsung<br/>Galaxy Z Flip 6<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Flip-5" style="text-decoration:none" title="Samsung Galaxy Z Flip 5 price">
#                                              Samsung<br/>Galaxy Z Flip 5<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Flip-4" style="text-decoration:none" title="Samsung Galaxy Z Flip 4 price">
#                                              Samsung<br/>Galaxy Z Flip 4<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-3" style="text-decoration:none" title="Samsung Galaxy Z Fold 3 price">
#                                              Samsung<br/>Galaxy Z Fold 3<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S24" style="text-decoration:none" title="Samsung Galaxy S24 price">
#                                              Samsung<br/>Galaxy S24<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S21-Ultra" style="text-decoration:none" title="Samsung Galaxy S21 Ultra price">
#                                              Samsung<br/>Galaxy S21 Ultra<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S22" style="text-decoration:none" title="Samsung Galaxy S22 price">
#                                              Samsung<br/>Galaxy S22<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-20-Ultra" style="text-decoration:none" title="Samsung Galaxy Note 20 Ultra price">
#                                              Samsung<br/>Galaxy Note 20 Ultra<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S24-FE" style="text-decoration:none" title="Samsung Galaxy S24 FE price">
#                                              Samsung<br/>Galaxy S24 FE<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S23-FE" style="text-decoration:none" title="Samsung Galaxy S23 FE price">
#                                              Samsung<br/>Galaxy S23 FE<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Flip-3" style="text-decoration:none" title="Samsung Galaxy Z Flip 3 price">
#                                              Samsung<br/>Galaxy Z Flip 3<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S21-Plus" style="text-decoration:none" title="Samsung Galaxy S21 Plus price">
#                                              Samsung<br/>Galaxy S21 Plus<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-20" style="text-decoration:none" title="Samsung Galaxy Note 20 price">
#                                              Samsung<br/>Galaxy Note 20<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S21" style="text-decoration:none" title="Samsung Galaxy S21 price">
#                                              Samsung<br/>Galaxy S21<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S21-FE-256GB" style="text-decoration:none" title="Samsung Galaxy S21 FE 256GB price">
#                                              Samsung<br/>Galaxy S21 FE 256GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S20" style="text-decoration:none" title="Samsung Galaxy S20 price">
#                                              Samsung<br/>Galaxy S20<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A73" style="text-decoration:none" title="Samsung Galaxy A73 price">
#                                              Samsung<br/>Galaxy A73<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S21-FE" style="text-decoration:none" title="Samsung Galaxy S21 FE price">
#                                              Samsung<br/>Galaxy S21 FE<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A54" style="text-decoration:none" title="Samsung Galaxy A54 price">
#                                              Samsung<br/>Galaxy A54<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A55" style="text-decoration:none" title="Samsung Galaxy A55 price">
#                                              Samsung<br/>Galaxy A55<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A53" style="text-decoration:none" title="Samsung Galaxy A53 price">
#                                              Samsung<br/>Galaxy A53<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S20-FE" style="text-decoration:none" title="Samsung Galaxy S20 FE price">
#                                              Samsung<br/>Galaxy S20 FE<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A35" style="text-decoration:none" title="Samsung Galaxy A35 price">
#                                              Samsung<br/>Galaxy A35<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A34-256GB" style="text-decoration:none" title="Samsung Galaxy A34 256GB price">
#                                              Samsung<br/>Galaxy A34 256GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A33-8GB" style="text-decoration:none" title="Samsung Galaxy A33 8GB price">
#                                              Samsung<br/>Galaxy A33 8GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A34" style="text-decoration:none" title="Samsung Galaxy A34 price">
#                                              Samsung<br/>Galaxy A34<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A25" style="text-decoration:none" title="Samsung Galaxy A25 price">
#                                              Samsung<br/>Galaxy A25<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A52s-256GB" style="text-decoration:none" title="Samsung Galaxy A52s 256GB price">
#                                              Samsung<br/>Galaxy A52s 256GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A72" style="text-decoration:none" title="Samsung Galaxy A72 price">
#                                              Samsung<br/>Galaxy A72<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-M52" style="text-decoration:none" title="Samsung Galaxy M52 price">
#                                              Samsung<br/>Galaxy M52<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A23" style="text-decoration:none" title="Samsung Galaxy A23 price">
#                                              Samsung<br/>Galaxy A23<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A32" style="text-decoration:none" title="Samsung Galaxy A32 price">
#                                              Samsung<br/>Galaxy A32<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A24" style="text-decoration:none" title="Samsung Galaxy A24 price">
#                                              Samsung<br/>Galaxy A24<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A52s" style="text-decoration:none" title="Samsung Galaxy A52s price">
#                                              Samsung<br/>Galaxy A52s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A22-6GB" style="text-decoration:none" title="Samsung Galaxy A22 6GB price">
#                                              Samsung<br/>Galaxy A22 6GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A52" style="text-decoration:none" title="Samsung Galaxy A52 price">
#                                              Samsung<br/>Galaxy A52<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A13-128GB" style="text-decoration:none" title="Samsung Galaxy A13 128GB price">
#                                              Samsung<br/>Galaxy A13 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A33" style="text-decoration:none" title="Samsung Galaxy A33 price">
#                                              Samsung<br/>Galaxy A33<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-M51" style="text-decoration:none" title="Samsung Galaxy M51 price">
#                                              Samsung<br/>Galaxy M51<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A22" style="text-decoration:none" title="Samsung Galaxy A22 price">
#                                              Samsung<br/>Galaxy A22<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A15-256GB" style="text-decoration:none" title="Samsung Galaxy A15 256GB price">
#                                              Samsung<br/>Galaxy A15 256GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A71" style="text-decoration:none" title="Samsung Galaxy A71 price">
#                                              Samsung<br/>Galaxy A71<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A51-8GB" style="text-decoration:none" title="Samsung Galaxy A51 8GB price">
#                                              Samsung<br/>Galaxy A51 8GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A15" style="text-decoration:none" title="Samsung Galaxy A15 price">
#                                              Samsung<br/>Galaxy A15<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A51" style="text-decoration:none" title="Samsung Galaxy A51 price">
#                                              Samsung<br/>Galaxy A51<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-M31s" style="text-decoration:none" title="Samsung Galaxy M31s price">
#                                              Samsung<br/>Galaxy M31s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A14-6GB" style="text-decoration:none" title="Samsung Galaxy A14 6GB price">
#                                              Samsung<br/>Galaxy A14 6GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-M31" style="text-decoration:none" title="Samsung Galaxy M31 price">
#                                              Samsung<br/>Galaxy M31<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A05s-6GB" style="text-decoration:none" title="Samsung Galaxy A05s 6GB price">
#                                              Samsung<br/>Galaxy A05s 6GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A13" style="text-decoration:none" title="Samsung Galaxy A13 price">
#                                              Samsung<br/>Galaxy A13<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A04s-128GB" style="text-decoration:none" title="Samsung Galaxy A04s 128GB price">
#                                              Samsung<br/>Galaxy A04s 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A03-4GB" style="text-decoration:none" title="Samsung Galaxy A03 4GB price">
#                                              Samsung<br/>Galaxy A03 4GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A04s" style="text-decoration:none" title="Samsung Galaxy A04s price">
#                                              Samsung<br/>Galaxy A04s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A30s-128GB" style="text-decoration:none" title="Samsung Galaxy A30s 128GB price">
#                                              Samsung<br/>Galaxy A30s 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A05s" style="text-decoration:none" title="Samsung Galaxy A05s price">
#                                              Samsung<br/>Galaxy A05s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A30s" style="text-decoration:none" title="Samsung Galaxy A30s price">
#                                              Samsung<br/>Galaxy A30s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A31" style="text-decoration:none" title="Samsung Galaxy A31 price">
#                                              Samsung<br/>Galaxy A31<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A05-6GB" style="text-decoration:none" title="Samsung Galaxy A05 6GB price">
#                                              Samsung<br/>Galaxy A05 6GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A04-4GB" style="text-decoration:none" title="Samsung Galaxy A04 4GB price">
#                                              Samsung<br/>Galaxy A04 4GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A21s-128GB" style="text-decoration:none" title="Samsung Galaxy A21s 128GB price">
#                                              Samsung<br/>Galaxy A21s 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A04e" style="text-decoration:none" title="Samsung Galaxy A04e price">
#                                              Samsung<br/>Galaxy A04e<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A14" style="text-decoration:none" title="Samsung Galaxy A14 price">
#                                              Samsung<br/>Galaxy A14<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A06-128GB" style="text-decoration:none" title="Samsung Galaxy A06 128GB price">
#                                              Samsung<br/>Galaxy A06 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A20s" style="text-decoration:none" title="Samsung Galaxy A20s price">
#                                              Samsung<br/>Galaxy A20s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A21s" style="text-decoration:none" title="Samsung Galaxy A21s price">
#                                              Samsung<br/>Galaxy A21s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A05-128GB" style="text-decoration:none" title="Samsung Galaxy A05 128GB price">
#                                              Samsung<br/>Galaxy A05 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A20" style="text-decoration:none" title="Samsung Galaxy A20 price">
#                                              Samsung<br/>Galaxy A20<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A03" style="text-decoration:none" title="Samsung Galaxy A03 price">
#                                              Samsung<br/>Galaxy A03<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A12-128GB" style="text-decoration:none" title="Samsung Galaxy A12 128GB price">
#                                              Samsung<br/>Galaxy A12 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A06" style="text-decoration:none" title="Samsung Galaxy A06 price">
#                                              Samsung<br/>Galaxy A06<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-M11" style="text-decoration:none" title="Samsung Galaxy M11 price">
#                                              Samsung<br/>Galaxy M11<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A12" style="text-decoration:none" title="Samsung Galaxy A12 price">
#                                              Samsung<br/>Galaxy A12<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A05" style="text-decoration:none" title="Samsung Galaxy A05 price">
#                                              Samsung<br/>Galaxy A05<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A04" style="text-decoration:none" title="Samsung Galaxy A04 price">
#                                              Samsung<br/>Galaxy A04<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A03s-4GB" style="text-decoration:none" title="Samsung Galaxy A03s 4GB price">
#                                              Samsung<br/>Galaxy A03s 4GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A03s" style="text-decoration:none" title="Samsung Galaxy A03s price">
#                                              Samsung<br/>Galaxy A03s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A10" style="text-decoration:none" title="Samsung Galaxy A10 price">
#                                              Samsung<br/>Galaxy A10<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A02s-4GB" style="text-decoration:none" title="Samsung Galaxy A02s 4GB price">
#                                              Samsung<br/>Galaxy A02s 4GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A11" style="text-decoration:none" title="Samsung Galaxy A11 price">
#                                              Samsung<br/>Galaxy A11<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A02s" style="text-decoration:none" title="Samsung Galaxy A02s price">
#                                              Samsung<br/>Galaxy A02s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A03-Core" style="text-decoration:none" title="Samsung Galaxy A03 Core price">
#                                              Samsung<br/>Galaxy A03 Core<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A02-64GB" style="text-decoration:none" title="Samsung Galaxy A02 64GB price">
#                                              Samsung<br/>Galaxy A02 64GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A10s" style="text-decoration:none" title="Samsung Galaxy A10s price">
#                                              Samsung<br/>Galaxy A10s<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A02" style="text-decoration:none" title="Samsung Galaxy A02 price">
#                                              Samsung<br/>Galaxy A02<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A01" style="text-decoration:none" title="Samsung Galaxy A01 price">
#                                              Samsung<br/>Galaxy A01<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A72-256GB" style="text-decoration:none" title="Samsung Galaxy A72 256GB price">
#                                              Samsung<br/>Galaxy A72 256GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Fold" style="text-decoration:none" title="Samsung Galaxy Fold price">
#                                              Samsung<br/>Galaxy Fold<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-10-Lite" style="text-decoration:none" title="Samsung Galaxy Note 10 Lite price">
#                                              Samsung<br/>Galaxy Note 10 Lite<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-2" style="text-decoration:none" title="Samsung Galaxy Z Fold 2 price">
#                                              Samsung<br/>Galaxy Z Fold 2<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S20-Plus" style="text-decoration:none" title="Samsung Galaxy S20 Plus price">
#                                              Samsung<br/>Galaxy S20 Plus<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Z-Flip" style="text-decoration:none" title="Samsung Galaxy Z Flip price">
#                                              Samsung<br/>Galaxy Z Flip<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S10-Lite" style="text-decoration:none" title="Samsung Galaxy S10 Lite price">
#                                              Samsung<br/>Galaxy S10 Lite<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-10" style="text-decoration:none" title="Samsung Galaxy Note 10 price">
#                                              Samsung<br/>Galaxy Note 10<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-J7-Prime" style="text-decoration:none" title="Samsung Galaxy J7 Prime price">
#                                              Samsung<br/>Galaxy J7 Prime<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-J7-Pro-64GB" style="text-decoration:none" title="Samsung Galaxy J7 Pro 64GB price">
#                                              Samsung<br/>Galaxy J7 Pro 64GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A50" style="text-decoration:none" title="Samsung Galaxy A50 price">
#                                              Samsung<br/>Galaxy A50<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S7-Edge" style="text-decoration:none" title="Samsung Galaxy S7 Edge price">
#                                              Samsung<br/>Galaxy S7 Edge<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A30" style="text-decoration:none" title="Samsung Galaxy A30 price">
#                                              Samsung<br/>Galaxy A30<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-5" style="text-decoration:none" title="Samsung Galaxy Note 5 price">
#                                              Samsung<br/>Galaxy Note 5<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S7-Edge-128GB" style="text-decoration:none" title="Samsung Galaxy S7 Edge 128GB price">
#                                              Samsung<br/>Galaxy S7 Edge 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A5-2017" style="text-decoration:none" title="Samsung Galaxy A5 2017 price">
#                                              Samsung<br/>Galaxy A5 2017<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Core-Prime" style="text-decoration:none" title="Samsung Galaxy Core Prime price">
#                                              Samsung<br/>Galaxy Core Prime<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-10-Plus" style="text-decoration:none" title="Samsung Galaxy Note 10 Plus price">
#                                              Samsung<br/>Galaxy Note 10 Plus<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A7-2017" style="text-decoration:none" title="Samsung Galaxy A7 2017 price">
#                                              Samsung<br/>Galaxy A7 2017<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A3-2017" style="text-decoration:none" title="Samsung Galaxy A3 2017 price">
#                                              Samsung<br/>Galaxy A3 2017<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-J5-Prime" style="text-decoration:none" title="Samsung Galaxy J5 Prime price">
#                                              Samsung<br/>Galaxy J5 Prime<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A6" style="text-decoration:none" title="Samsung Galaxy A6 price">
#                                              Samsung<br/>Galaxy A6<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A6-Plus-2018" style="text-decoration:none" title="Samsung Galaxy A6 Plus 2018 price">
#                                              Samsung<br/>Galaxy A6 Plus 2018<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-9" style="text-decoration:none" title="Samsung Galaxy Note 9 price">
#                                              Samsung<br/>Galaxy Note 9<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-J5-Pro" style="text-decoration:none" title="Samsung Galaxy J5 Pro price">
#                                              Samsung<br/>Galaxy J5 Pro<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-J6" style="text-decoration:none" title="Samsung Galaxy J6 price">
#                                              Samsung<br/>Galaxy J6<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S9" style="text-decoration:none" title="Samsung Galaxy S9 price">
#                                              Samsung<br/>Galaxy S9<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A7-2018" style="text-decoration:none" title="Samsung Galaxy A7 2018 price">
#                                              Samsung<br/>Galaxy A7 2018<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S9-Plus-128GB" style="text-decoration:none" title="Samsung Galaxy S9 Plus 128GB price">
#                                              Samsung<br/>Galaxy S9 Plus 128GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-C7" style="text-decoration:none" title="Samsung Galaxy C7 price">
#                                              Samsung<br/>Galaxy C7<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S10-Plus-512GB" style="text-decoration:none" title="Samsung Galaxy S10 Plus 512GB price">
#                                              Samsung<br/>Galaxy S10 Plus 512GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S10" style="text-decoration:none" title="Samsung Galaxy S10 price">
#                                              Samsung<br/>Galaxy S10<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-J6-Plus" style="text-decoration:none" title="Samsung Galaxy J6 Plus price">
#                                              Samsung<br/>Galaxy J6 Plus<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-7" style="text-decoration:none" title="Samsung Galaxy Note 7 price">
#                                              Samsung<br/>Galaxy Note 7<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-8" style="text-decoration:none" title="Samsung Galaxy Note 8 price">
#                                              Samsung<br/>Galaxy Note 8<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S8-Plus" style="text-decoration:none" title="Samsung Galaxy S8 Plus price">
#                                              Samsung<br/>Galaxy S8 Plus<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A80" style="text-decoration:none" title="Samsung Galaxy A80 price">
#                                              Samsung<br/>Galaxy A80<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S8" style="text-decoration:none" title="Samsung Galaxy S8 price">
#                                              Samsung<br/>Galaxy S8<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-Note-9-512GB" style="text-decoration:none" title="Samsung Galaxy Note 9 512GB price">
#                                              Samsung<br/>Galaxy Note 9 512GB<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S9-Plus" style="text-decoration:none" title="Samsung Galaxy S9 Plus price">
#                                              Samsung<br/>Galaxy S9 Plus<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S10-Plus" style="text-decoration:none" title="Samsung Galaxy S10 Plus price">
#                                              Samsung<br/>Galaxy S10 Plus<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S20-Ultra" style="text-decoration:none" title="Samsung Galaxy S20 Ultra price">
#                                              Samsung<br/>Galaxy S20 Ultra<br/></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S25-Slim" style="text-decoration:none" title="Samsung Galaxy S25 Slim">
#                                              Samsung<br>Galaxy S25 Slim<br/></br></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A26" style="text-decoration:none" title="Samsung Galaxy A26">
#                                              Samsung<br>Galaxy A26<br/></br></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A16-5G" style="text-decoration:none" title="Samsung Galaxy A16 5G">
#                                              Samsung<br>Galaxy A16 5G<br/></br></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-S25-FE" style="text-decoration:none" title="Samsung Galaxy S25 FE">
#                                              Samsung<br>Galaxy S25 FE<br/></br></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A36" style="text-decoration:none" title="Samsung Galaxy A36">
#                                              Samsung<br>Galaxy A36<br/></br></a>,
#  <a class="BiggerText" href="/Samsung_Galaxy-A56" style="text-decoration:none" title="Samsung Galaxy A56">
#                                              Samsung<br>Galaxy A56<br/></br></a>,
#  <a class="BiggerText" href="Samsung_Galaxy-S24-FE" rel="nofolow" style="text-decoration: none">Samsung Galaxy S24 FE</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-A06" rel="nofolow" style="text-decoration: none">Samsung Galaxy A06</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-Z-Fold-6" rel="nofolow" style="text-decoration: none">Samsung Galaxy Z Fold 6</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-Z-Flip-6" rel="nofolow" style="text-decoration: none">Samsung Galaxy Z Flip 6</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-A06-128GB" rel="nofolow" style="text-decoration: none">Samsung Galaxy A06 128GB</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-A55" rel="nofolow" style="text-decoration: none">Samsung Galaxy A55</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-A35" rel="nofolow" style="text-decoration: none">Samsung Galaxy A35</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-S24-Ultra-512GB" rel="nofolow" style="text-decoration: none">Samsung Galaxy S24 Ultra 512GB</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-S24-Ultra" rel="nofolow" style="text-decoration: none">Samsung Galaxy S24 Ultra</a>,
#  <a class="BiggerText" href="Samsung_Galaxy-S24" rel="nofolow" style="text-decoration: none">Samsung Galaxy S24</a>,
#  <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-s25-reappears-on-geekbench-now-sporting-an-exynos-chip-news-5642" title="Samsung Galaxy S25+ Reappears on Geekbench, Now Sporting an Exynos Chip">
#
#                                  Samsung Galaxy S25+ Reappears on Geekbench, Now Sporting an Ex...
#                              </a>,
#  <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-s25-slim-will-be-launching-worldwide-and-heres-the-proof-news-5624" title="Samsung Galaxy S25 Slim will be Launching Worldwide and Here’s the Proof">
#
#                                  Samsung Galaxy S25 Slim will be Launching Worldwide and Here�...
#                              </a>,
#  <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-a54-bags-the-latest-security-stability-update-fornovember2024-news-5623" title="Samsung Galaxy A54 Bags the Latest Security &amp; Stability Update for November 2024">
#
#                                  Samsung Galaxy A54 Bags the Latest Security &amp; Stability Update...
#                              </a>,
#  <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-s25-ultra-live-shots-surface-alongside-the-first-look-at-one-ui-70-news-5618" title="Samsung Galaxy S25 Ultra Live Shots Surface Alongside the First Look at One UI 7.0">
#
#                                  Samsung Galaxy S25 Ultra Live Shots Surface Alongside the Firs...
#                              </a>,
#  <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-z-flip-fe-leaked-as-companys-first-budget-clamshell-with-exynos-2400e-news-5609" title="Samsung Galaxy Z Flip FE Leaked as Company’s First Budget Clamshell with Exynos 2400e">
#
#                                  Samsung Galaxy Z Flip FE Leaked as Company’s First Budget Cl...
#                              </a>,
#  <a class="textLatest BiggerText" href="https://www.whatmobile.com.pk/samsung-galaxy-a33-a34-finally-updated-with-november-2024-security-patch-news-5617" title="Samsung Galaxy A33 &amp; A34 Finally Updated with November 2024 Security Patch">
#
#                                  Samsung Galaxy A33 &amp; A34 Finally Updated with November 2024 Se...
#                              </a>]

# %% [markdown]
# ### Get the first link from the list

# %%
links[0]
# Out:
# <a class="BiggerText" href="/Samsung_Galaxy-Z-Fold-5" style="text-decoration:none" title="Samsung Galaxy Z Fold 5 price">
#                                             Samsung<br/>Galaxy Z Fold 5<br/></a>

# %% [markdown]
# ### Extract the href attribute from the first link to get the product URL

# %%
link = links[0].get("href")

# %% [markdown]
# ### Print the extracted product URL

# %%
link
# Out:
# '/Samsung_Galaxy-Z-Fold-5'

# %% [markdown]
# ### Construct the full product URL by appending it to the base URL

# %%
product_url = "https://www.whatmobile.com.pk/" + link

# %% [markdown]
# ### Print the full product URL

# %%
product_url
# Out:
# 'https://www.whatmobile.com.pk//Samsung_Galaxy-Z-Fold-5'

# %% [markdown]
# ### Send a new HTTP GET request to the product URL

# %%
new_response = requests.get(product_url,headers=HEADERS)

# %% [markdown]
# ### Print the new HTTP response object

# %%
new_response
# Out:
# <Response [200]>

# %% [markdown]
# ### Parse the HTML content of the product page using BeautifulSoup

# %%
new_soup = BeautifulSoup(new_response.content,"html.parser")

# %%
new_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NVDVQQ');</script>
# <!-- End Google Tag Manager -->
# <link href="/manifest.json" rel="manifest"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=1060, initial-scale=1.0" name="viewport"/>
# <title> Samsung Galaxy Z Fold 5 Price in Pakistan &amp; Specifications 2023</title>
# <meta content="Samsung Galaxy Z Fold 5 price in Pakistan, daily updated Samsung phones including specs &amp; information : WhatMobile.com.pk : Samsung Galaxy Z Fold 5 price Pakistan :" name="Description">
# <meta content="Samsung Galaxy Z Fold 5, Samsung Galaxy Z Fold 5 Price, Galaxy Z Fold 5, Samsung Galaxy Z Fold 5 price Pakistan, Samsung Galaxy Z Fold 5 Pakistan, Galaxy Z Fold 5 Price,  specification, Samsung Galaxy Z Fold 5 in pakistan, Samsung Galaxy Z Fold 5 review, Samsung Galaxy Z Fold 5 price in Pakistan, comparison, zone" name="Keywords">
# <meta content="PK" name="sitecode"/>
# <meta content="2024-12-09" name="last-modified"/>
# <meta content="WhatMobile" property="fb:admins"/>
# <meta content="Samsung Galaxy Z Fold 5 Price in Pakistan &amp; Specifications - WhatMobile" property="og:title"/>
# <meta content="Samsung Galaxy Z Fold 5 price in Pakistan, daily updated Samsung phones including specs &amp; information : WhatMobile.com.pk : Samsung Galaxy Z Fold 5 price Pakistan :" property="og:description"/>
# <meta content="1451235568231998" property="fb:app_id"/>
# <meta content="https://www.whatmobile.com.pk/admin/images/Samsung/SamsungGalaxyZFold5-b.jpg" property="og:image"/>
# <meta content="WhatMobile" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.whatmobile.com.pk/Samsung_Galaxy-Z-Fold-5" property="og:url"/>
# <link href="https://www.whatmobile.com.pk/Samsung_Galaxy-Z-Fold-5" rel="canonical">
# <link href="https://m.whatmobile.com.pk/Samsung_Galaxy-Z-Fold-5" rel="alternate"/>
# <script defer="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#       googletag.defineSlot('/1013266/SpecsLargeRec226x280', [336, 280], 'div-gpt-ad-1387525175047-1').addService(googletag.pubads());
#       googletag.defineSlot('/1013266/Specs_120x600', [120, 600], 'div-gpt-ad-1386071686884-0').addService(googletag.pubads());
#       googletag.defineSlot('/1013266/specs_160x600New', [160, 600], 'div-gpt-ad-1478500508567-0').addService(googletag.pubads());
#       googletag.defineSlot('/1013266/Specs1x1', [1, 1], 'div-gpt-ad-1581089702359-0').addService(googletag.pubads());
#       googletag.defineSlot('/1013266/vivo350x80', [350, 80], 'div-gpt-ad-1522750675784-0').addService(googletag.pubads());
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#   });
# </script>
# <!--BreadCrumb List Schema -->
# <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [{
#     "@type": "ListItem",
#     "position": 1,
#     "item": {
#     "@id": "https://www.whatmobile.com.pk/",
#     "name": "Mobile Prices"
#     }
#     },{
#     "@type": "ListItem",
#     "position": 2,
#     "item": {
#     "@id": "https://www.whatmobile.com.pk/Samsung_Mobiles_Prices",
#     "name": "Samsung Mobiles"
#     }
#     },{
#     "@type": "ListItem",
#     "position": 3,
#     "item": {
#     "@id": "https://www.whatmobile.com.pk/Samsung_Galaxy-Z-Fold-5",
#     "name": "Samsung Galaxy Z Fold 5 Price in Pakistan"
#     }
#     }]
#     }
#
#
#
#     </script>
# <!--Product Schema -->
# <script type="application/ld+json">
#             {
#             "@context": "http://schema.org/",
#             "@type": "Product",
#             "category" : "Mobile Phones",
#             "name": "Samsung Galaxy Z Fold 5",
#             "url"  : "https://www.whatmobile.com.pk/Samsung_Galaxy-Z-Fold-5",
#             "image": "https://www.whatmobile.com.pk/admin/images/Samsung/SamsungGalaxyZFold5-b.jpg",
#             "description": " Samsung Galaxy Z Fold 5 - The Future Foldable Smartphone Of Samsung!
# Samsung will bring the new Galaxy Z 5 Fold in near future. We learned from a Korean blog that Samsung is already ...",
#             "sku": "Samsung_Galaxy-Z-Fold-5",
#             "mpn": "Galaxy Z Fold 5",
#             "model": "Galaxy Z Fold 5",
#             "brand": {
#             "@type": "Thing",
#             "name": "Samsung"
#             },
#             "aggregateRating": {
#             "@type": "AggregateRating",
#             "ratingValue": "5",
#             "reviewCount": "3"
#             }			}
#
#
#
#     </script>
# <link href="style7.css" rel="stylesheet" type="text/css"/>
# <link as="style" href="css/bootstrap.min.css" onload="this.rel='stylesheet'" rel="preload"/>
# <link href="rateit/scripts/rateit.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# <noscript><link href="rateit/scripts/rateit.css" rel="stylesheet"/></noscript>
# <style type="text/css">
#         <!--
#         body {
#
#             margin-left: 1px;
#             margin-top: 0px;
#             margin-right: 0px;
#             margin-bottom: 0px;
#
#         }
#
#         .style5 {
#             font-size: 12px
#         }
#
#         .style6 {
#             color: #000000
#         }
#
#         img {
#             border: none;
#         }
#
#         a.noborder {
#             border: none;
#         }
#
#         -->
#
#         .specs {
#             border-collapse: collapse;
#             border: 1px solid #abc4e8;
#         }
#
#         .bottom-border-section {
#             border-bottom: 1px solid #abc4e8;
#         }
#
#         .bottom-border {
#             border-bottom: 1px solid #d1dff3;
#         }
#
#         .right-border {
#             border-right: 1px solid #abc4e8;
#         }
#
#         .specs-mainheading {
#             padding: 5px 12px 5px 10px;
#         }
#
#         .specs-subHeading {
#             padding: 6px 10px !important;
#         }
#
#         .specs-value {
#             padding-left: 6px;
#             background-color: white;
#             font-weight: 100;
#             border-left: 1px solid #d1dff3;
#         }
#
#         @-moz-document url-prefix() {
#             .specs-value {
#                 width: 100%;
#                 padding-left: 6px;
#                 background-color: white;
#                 border-left: 1px solid #d1dff3;
#             }
#         }
#
#         .video-container {
#             position: relative;
#             padding-bottom: 56.25%;
#             padding-top: 30px;
#             height: 0;
#             overflow: hidden;
#         }
#
#         .video-container iframe,
#         .video-container object,
#         .video-container embed {
#             position: absolute;
#             top: 0;
#             left: 0;
#             width: 100%;
#             height: 100%;
#         }
#
#         .comp-item {
#             width: 195px;
#             float: left;
#             border: 1px solid #abc4e8;
#             padding: 8px;
#             margin: 5px;
#             margin-left: 0;
#         }
#
#         .comp-item .comp-label {
#             height: 30px;
#             margin-top: 10px;
#             display: block;
#             text-decoration: none;
#         }
#
# /* Container to center the image and control the flex layout */
# .image-container {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     width: 100%; /* Full width of the parent container */
#     margin: 0 auto;
#     padding: 10px 0; /* Optional padding for spacing */
# }
#
# /* Image styling to make it responsive and maintain aspect ratio */
# .product-image {
#     max-width: 350px;  /* Max width for the image */
#     height: auto;  /* Automatically adjusts the height based on the aspect ratio */
#     display: block;
#     border: none;
#     object-fit: contain;  /* Ensures the image fits within the given space without distortion */
# }
# .youtube-wrapper {
#     position: relative;
#     width: 100%;
#     max-width: 604px; /* Adjust based on your design */
# }
#
# .youtube-placeholder img {
#     width: 100%;
#     cursor: pointer;
# }
#
# .youtube-play-button {
#     position: absolute;
#     top: 50%;
#     left: 50%;
#     transform: translate(-50%, -50%);
#     width: 64px;
#     height: 64px;
#     background: url('https://www.whatmobile.com.pk/images/yplay/yplay.png') no-repeat center center;
#     background-size: cover;
#     pointer-events: none;
# }
#
# .NavLinks li {
#     display: inline; /* Display all <li> items inline */
#     margin-right: 5px; /* Spacing between list items */
# }
#
# .NavLinks li:not(:last-child)::after {
#     content: " > "; /* Add the separator after every <li> except the last one */
#     margin-left: 5px; /* Add space after the separator */
# }
#     </style>
# <!-- BuySellAds Ad Code
#     <script type="text/javascript">
#     (function(){
#       var bsa = document.createElement('script');
#          bsa.type = 'text/javascript';
#          bsa.async = true;
#          bsa.src = 'http://s3.buysellads.com/ac/bsa.js';
#       (document.getElementsByTagName('head')[0]||document.getElementsByTagName('body')[0]).appendChild(bsa);
#     })();
#     </script> -->
# <style>
#
#         .broad, #DynContainer {
#             min-width: 1000px !important;
#             max-width: 1000px !important;
#             margin: 0 auto !important;
#             width: 1000px !important;
#         }
#
#         .broad:hover, #DynContainer:hover {
#             min-width: 1000px !important;
#             max-width: 1000px !important;
#             margin: 0 auto !important;
#             width: 1000px !important;
#         }
#     </style>
# </link></meta></meta></head>
# <body class="broad">
# <div class="rowssd"></div>
# <div id="DynContainer">
# <div><link href="css/search.css" rel="stylesheet" type="text/css">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVDVQQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div style="width:1000px;">
# <div itemscope="" itemtype="http://schema.org/Organization">
# <meta content="What Mobile" itemprop="name"/>
# <meta content="https://www.whatmobile.com.pk/" itemprop="url"/>
# <meta content="https://m.whatmobile.com.pk/" itemprop="sameAs"/>
# <meta content="https://www.facebook.com/whatmobile.com.pk/" itemprop="sameAs"/>
# </div>
# <div itemscope="" itemtype="http://schema.org/WebSite">
# <meta content="WhatMobile" itemprop="name"/>
# <meta content="https://www.whatmobile.com.pk/" itemprop="url"/>
# </div>
# <div style="width:998px">
# <div style="width:764px; float:left">
# <img alt="Mobile Prices" border="0" height="137" src="images/header-Left-new2.gif" usemap="#Map" width="764"/>
# <map id="Map" name="Map">
# <area coords="63,116,169,137" href="//www.whatmobile.com.pk" shape="rect"/>
# <area coords="187,115,291,135" href="//www.whatmobile.com.pk/reviews/" shape="rect"/>
# <area coords="306,116,411,148" href="news.php" shape="rect"/>
# <area coords="550,111,655,143" href="outlets.php" shape="rect"/>
# <area coords="427,112,536,135" href="feedback.php" shape="rect"/>
# <!--  <area shape="rect" coords="427,113,536,136" href="feedback.php" />
#                <area shape="rect" coords="550,115,659,135" href="outlets.php" /> -->
# </map>
# </div>
# <div class="main-search" style="width:234px; height:137px; float:left; position:relative;
#         background-image: url('images/header-RightSearch128888.gif'); background-size: 101% 100%;">
# <div style="width:100%;position:absolute; top:25%;">
# <div class="Heading1" id="search">
# <form action="/search.php" autocomplete="off" method="get">
# <input id="searchInput" name="q" placeholder="Search" style="width:90%; height:26px" type="text"/>
# <input style="position: absolute; left: -9999px; width: 1px; height: 1px;" tabindex="-1" type="submit">
# <div class="search-buttons">
# <a href="#" id="go">Go</a>
# <a href="advanceSearch.php">Advanced</a>
# </div>
# </input></form>
# <div class="search-result" style="width:110%">
# <div id="livesearch"></div>
# </div>
# </div>
# <!-- <form method="get" action="/search.php" target="_top">
#
#                     <div style="margin-bottom: 5px">
#                         <br />
#                         <input type="hidden" name="domains" value="www.whatmobile.com.pk"/>
#                         <label for="sbi" style="display: none">Enter your search terms</label>
#                         <input type="text" name="q" size="22" maxlength="255" value="" id="sbi"/>
#                     </div>
#                     <div>
#                         <div style="width:100%; margin-bottom: 5px">
#                             <input type="radio" name="sitesearch" value="" id="ss0"/>
#                             <label for="ss0" title="Search the Web"><font size="-1" color="#ffffff">Web</font></label>
#                             &nbsp;
#                             <input type="radio" name="sitesearch" value="www.whatmobile.com.pk" checked id="ss1"/>
#                             <label for="ss1" title="Search www.whatmobile.com.pk"><font size="-1" color="#ffffff">WhatMobile</font></label>
#                         </div>
#
#                         <label for="sbb" style="display: none">Submit search form</label>
#                         <input name="sa" type="submit" class="btn" id="sbb" value="Google Search"/>
#                     </div>
#                 </form> -->
# </div>
# </div>
# </div>
# <div>
# <div style="width:820px; float:left"> </div>
# <div style="width:180px; float:left">
# <div style="width:104px; background-image: url('images/roundrect12004351.gif')">
# <div class="lnk" style="text-align: center; padding-top: 2px; padding-bottom: 4px">
# <span style="color:#333399">Today's Prices</span>
# </div>
# </div>
# </div>
# </div>
# <div>
# <marquee bgcolor="#D9DBDF" height="23" onmouseout="javascript:start()" onmouseover="javascript:stop()" scrollamount="2" scrolldelay="50" width="1000">
# <div style="width:100%; padding: 1px; white-space: nowrap">
# </div>
# </marquee>
# </div>
# </div> </link></div>
# <div style="width:1000px; display:inline-block; text-align:center;">
# <div style="float:left;width: 150px; height:1012px;  vertical-align: top; marigin:0; auto;"><style type="text/css">
#
#
#
#     <!--
#
#
#
#     .border {
#
#
#
#         border: 1px solid #D9DBDF;
#
#
#
#     }
#
#
#
#     -->
#     .upper {
#         background-image: url("images/upper.gif");
#     }
#
#     .verticalMenu ul {
#         list-style-type: none;
#         margin: 0;
#         padding-top:1px;
#         padding-bottom: 1px;
#         padding-left: 10px;
#         padding-right: 9px;
#         background-image: url("images/shape16424016.gif");
#     }
#
#     .verticalMenu ul li {
#         text-align: left;
#         margin-top:2px;
#         margin-bottom: 2px;
#     }
#
#     .verticalMenu ul li.center {
#         text-align: center;
#     }
#
#     .verticalMenu ul li.heading {
#         display: block;
#         height:23px;
#         line-height: 23px;
#         text-align: center;
#         background-image: url("images/roundrect14918782.gif");
#         background-repeat: no-repeat;
#         background-position: center;
#     }
#
#     .verticalMenu ul li span {
#         vertical-align: middle;
#     }
#
#     .news {
#         font-family: Verdana, Arial, Helvetica, sans-serif;
#         padding: 0;
#         margin-bottom: 12px;
#     }
#     .news img {
#         width: 100%;
#     }
#     .news a {
#         text-decoration: none;
#         color: 808080;
#     }
#     .news h1 {
#         font-size: 0.7rem;
#     }
#
# </style>
# <div class="verticalMenu" style="width:152px">
# <div>
# <img alt="price list options start" class="noBorder" height="19" src="images/upper.gif" width="152"/>
# </div>
# <ul>
# <li class="center">
# <a class="lnk" href="StolenMobile.php" title="Block stolen mobile phones"><u>Block Stolen Mobile </u></a>
# </li>
# <li class="center">
# <a class="lnk" href="VideoReviews.php" title="Mobile phone Video Reviews"><u>Video Reviews</u></a>
# </li>
# <li class="heading Menue">
# <span>Search by Network</span>
# </li>
# <li>
# <a class="lnk" href="Price-List-Of-All-4G_Mobile-Phones" title="4G mobile phones with prices">4G Mobile Prices</a>
# </li>
# <li>
# <a class="lnk" href="Price-List-Of-All-5G_Mobile-Phones" title="5G mobile phones with prices">5G Mobiles </a><img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li class="heading Menue">
# <span>Search by Brand</span>
# </li>
# <li>
# <a class="lnk" href="Samsung_Mobiles_Prices" title="Samsung mobile phones">Samsung mobile</a>
# </li>
# <li>
# <a class="lnk" href="Huawei_Mobiles_Prices" title="Huawei mobile phones">Huawei mobile</a>
# </li>
# <li>
# <a class="lnk" href="Vivo_Mobiles_Prices" title="Vivo mobile phones">Vivo</a>
# </li>
# <li>
# <a class="lnk" href="Honor_Mobiles_Prices" title="Honor mobile phones">Honor mobile</a>
# </li>
# <li><a class="lnk" href="Oppo_Mobiles_Prices" title="OPPO mobile phones">Oppo Mobile</a>
# </li>
# <li><a class="lnk" href="Realme_Mobiles_Prices" title="Realme mobile phones">Realme Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Nokia_Mobiles_Prices" title="Nokia mobile phones">Nokia mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="Xiaomi_Mobiles_Prices" title="Xiaomi mobile phones">Xiaomi Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Infinix_Mobiles_Prices" title="Infinix mobile phones">Infinix Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Apple_Mobiles_Prices" title="Apple iphones">Apple iphone prices</a>
# </li>
# <li>
# <a class="lnk" href="Tecno_Mobiles_Prices" title="Tecno mobile phones">Tecno Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Zte_Mobiles_Prices" title="ZTE mobile phones">ZTE Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Sparx_Mobiles_Prices" title="Sparx mobile phones">Sparx Mobile</a><img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Dcode_Mobiles_Prices" title="Dcode mobile phones">Dcode</a><img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Qmobile_Mobiles_Prices" title="QMobile mobile phones">QMobile</a>
# </li>
# <li>
# <a class="lnk" href="Lenovo_Mobiles_Prices" title="Lenovo mobile phones">Lenovo Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Sony_Mobiles_Prices" title="Sony mobile phones">Sony mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="LG_Mobiles_Prices" title="LG mobile phones">LG mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="Itel_Mobiles_Prices" title="itel mobile phones">itel Mobile</a>
# </li>
# <li>
# <a class="lnk" href="OnePlus_Mobiles_Prices" title="OnePlus mobile phones">OnePlus</a>
# </li>
# <li>
# <a class="lnk" href="Telenor_Mobiles_Prices" title="Telenor mobile phones">Telenor</a><img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/>
# </li>
# <li>
# <a class="lnk" href="Alcatel_Mobiles_Prices" title="Alcatel mobile phones">Alcatel Mobile</a>
# </li>
# <li>
# <a class="lnk" href="HTC_Mobiles_Prices" title="HTC mobile phones">HTC mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="Microsoft_Mobiles_Prices" title="Microsoft mobile phones">Microsoft Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Rivo_Mobiles_Prices" title="Rivo mobile phones">Rivo Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Haier_Mobiles_Prices" title="Haier mobile phones">Haier Mobile Prices</a>
# </li>
# <li>
# <a class="lnk" href="Mobilink_Mobiles_Prices" title="Mobilink Jazz X mobile phones">Mobilink JazzX</a>
# </li>
# <li>
# <a class="lnk" href="Motorola_Mobiles_Prices" title="Motorola mobile phones">Motorola</a>
# </li>
# <li>
# <a class="lnk" href="BlackBerry_Mobiles_Prices" title="Blackberry mobile phones">BlackBerry</a>
# </li>
# <li>
# <a class="lnk" href="Voice_Mobiles_Prices" title="Voice mobile phones">VOICE mobile prices</a>
# </li>
# <li>
# <a class="lnk" href="Meizu_Mobiles_Prices" title="Meizu mobile phones">Meizu Mobile</a>
# </li>
# <li>
# <a class="lnk" href="Calme_Mobiles_Prices" title="Calme mobile phones">Calme Mobile</a>
# </li>
# <li>
# <a class="lnk" href="GRight_Mobiles_Prices" title="Gright mobile phones">GRight Mobile</a>
# </li>
# <li>
# <a class="lnk" href="GFive_Mobiles_Prices" title="GFive mobile phones">G'Five mobile</a>
# </li>
# <li class="heading Menue">
# <span>Search by Price</span>
# </li>
# <li>
# <a class="lnk" href="45000_to_250001_Mobiles" title="Mobile phones with prices greater than 45000">Prices  &gt; 45,000</a>
# </li>
# <li>
# <a class="lnk" href="35000_to_45001_Mobiles" title="Mobile phones in a price range of 35000 to 40000">35,001 - 45,000</a>
# </li>
# <li>
# <a class="lnk" href="25000_to_35001_Mobiles" title="Mobile phones in a price range of 25000 to 35000">25,001 - 35,000</a>
# </li>
# <li>
# <a class="lnk" href="15000_to_25001_Mobiles" title="Mobile phones in a price range of 15000 to 25000">15,001 - 25,000</a>
# </li>
# <li>
# <a class="lnk" href="10000_to_15001_Mobiles" title="Mobile phones in a price range of 10000 to 15000">10,001 - 15,000</a>
# </li>
# <li>
# <a class="lnk" href="5000_to_10001_Mobiles" title="Mobile phones in a price range of 5000 to 10000">5,001 - 10,000</a>
# </li>
# <li>
# <a class="lnk" href="0_to_5001_Mobiles" title="Mobile phones below 5000 Rupees">Prices &lt; 5000</a>
# </li>
# <li>
# <a class="lnk" href="0_to_150001_Mobiles" title="All mobile phones">All Mobile Prices</a>
# </li>
# <li class="heading Menue">
# <span>Search by RAM</span>
# </li>
# <li>
# <a class="lnk" href="2GB-RAM_Mobile-Phones" title="Mobile phones with 2GB RAM">2GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="3GB-RAM_Mobile-Phones" title="Mobile phones with 3GB RAM">3GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="4GB-RAM_Mobile-Phones" title="Mobile phones with 4GB RAM">4GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="6GB-RAM_Mobile-Phones" title="Mobile phones with 6GB RAM">6GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="8GB-RAM_Mobile-Phones" title="Mobile phones with 8GB RAM">8GB RAM</a>
# </li>
# <li>
# <a class="lnk" href="12GB-RAM_Mobile-Phones" title="Mobile phones with 12GB RAM">12GB &amp; above RAM</a>
# </li>
# <li class="heading Menue">
# <span>Search by Screen</span>
# </li>
# <li>
# <a class="lnk" href="1.0-To-2.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with less than 3 inch display">Less Then 3 Inches</a>
# </li>
# <li>
# <a class="lnk" href="3.0-To-4.0-inches-Display-Size_Mobile-Phones" title="Mobile phones with 3 to 4 inch display">3.0 inch - 4.0 inch</a>
# </li>
# <li>
# <a class="lnk" href="4.1-To-4.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 4.1 to 4.9 inch display">4.1 inch - 4.9 inch</a>
# </li>
# <li>
# <a class="lnk" href="5.0-To-6.9-inches-Display-Size_Mobile-Phones" title="Mobile phones with 5 to 6.9 inch display">5.0 inch - 6.9 inch</a>
# </li>
# <li>
# <a class="lnk" href="7.0-To-8.9-inches-Display-Size_Mobile-Phones" title="Devices with 7 to 8.9 inch display">7.0 inch - 8.9 inch</a>
# </li>
# <li class="heading Menue">
# <span>Search by Cam</span>
# </li>
# <li>
# <a class="lnk" href="13mp-Camera_Mobile-Phones" title="Mobile phones with 13MP Camera">13 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="8mp-Camera_Mobile-Phones" title="Mobile phones with 8MP Camera">8 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="5mp-Camera_Mobile-Phones" title="Mobile phones with 5MP Camera">5 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="3mp-Camera_Mobile-Phones" title="Mobile phones with 3MP Camera">3 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="2mp-Camera_Mobile-Phones" title="Mobile phones with 2MP Camera">2 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="1mp-Camera_Mobile-Phones" title="Mobile phones with 1MP Camera">1 MP Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="VGA-Camera_Mobile-Phones" title="Mobile phones with VGA Camera">VGA Cam or less</a>
# </li>
# <li>
# <a class="lnk" href="Without-Camera_Mobile-Phones" title="Mobile phones without Camera">Without Camera</a>
# </li>
# <li class="heading Menue">
# <span>Search by Type</span>
# </li>
# <li>
# <a class="lnk" href="Camera_Mobile-Phones" title="Mobile phones having a Camera">Camera Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="Video_Mobile-Phones" title="Mobile phones with video recording feature">Video Recording</a>
# </li>
# <li>
# <a class="lnk" href="Bluetooth_Mobile-Phones" title="Mobile phones with bluetooth">Bluetooth Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="DualSim_Mobile-Phones" title="Dual-Sim mobile phones">Dual Sim Phones</a>
# </li>
# <li>
# <a class="lnk" href="LAN_Mobile-Phones" title="Mobile phones with Wifi">Wireless LAN </a>
# </li>
# <li>
# <a class="lnk" href="MP3_Mobile-Phones" title="Mobile phones with MP3 playback">MP3 Playback </a>
# </li>
# <li>
# <a class="lnk" href="FM_Mobile-Phones" title="Mobile phones with FM Radio">FM Radio Mobiles</a>
# </li>
# <li>
# <a class="lnk" href="MemoryCard_Mobile-Phones" title="Mobile phones having a card slot">Memory Card </a>
# </li>
# <li class="heading Menue">
# <span>Search by OS<img align="absbottom" alt="New Listing" height="17" src="images/new5.GIF" width="35"/></span>
# </li>
# <li>
# <a class="lnk" href="Android_Mobile-Phones" title="All Android mobile phones">Android Phones </a>
# </li>
# <li>
# <a class="lnk" href="Feature_Mobile-Phones" title="All Feature mobile phones">Feature Phones </a>
# </li>
# <li>
# <a class="lnk" href="Windows_Mobile-Phones" title="All Windows mobile phones">Windows Phones </a>
# </li>
# <li>
# <a class="lnk" href="Smartphone_Mobile-Phones" title="All Smartphones">All Smartphones </a>
# </li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# <div>
# <img alt="price list options end" class="noBorder" height="19" src="images/bottom.gif" width="152"/>
# </div>
# </div>
# <br/>
# <div class="verticalMenu" style="width:152px">
# <div>
# <img alt="price list options start" class="noBorder" height="19" src="images/upper.gif" width="152"/>
# </div>
# <ul>
# <li> </li>
# <li class="heading Menue">
# <span><a class="Menue" href="advanceSearch.php" style="text-decoration:none" title="Advance mobile phone search">Advance Search</a></span>
# </li>
# <li> </li>
# </ul>
# <div>
# <img alt="price list options end" class="noBorder" height="19" src="images/bottom.gif" width="152"/>
# </div>
# </div> </div>
# <div id="centerContainer" style="float: left;width:680px !important;   vertical-align: top; margin:0 auto; display:inline-block;
#              text-align:center;">
# <div style="width:604px;  vertical-align: top; margin: auto;">
# <div>
# <div align="right">
# <ol class="NavLinks" style="list-style: none; padding: 0; margin: 0; display: inline-block;">
# <li class="NavLinks"><a class="NavLinks" href="../">Mobile Prices</a></li>
# <li class="NavLinks"><a class="NavLinks" href="/Samsung_Mobiles_Prices">Samsung Mobiles</a></li>
# <li class="NavLinks"><u>Samsung Galaxy Z Fold 5 Price in Pakistan</u></li>
# </ol>
# </div>
# <!--<script type="text/javascript">
#                         var infolink_pid = 12922;
#                         var infolink_link_color = '0000ff';
#                     </script>
#                     <script type="text/javascript" src="https://resources.infolinks.com/js/infolinks_main.js"></script>
#                 </div>
#                 <div style="text-align:center; vertical-align:top; margin:0 auto;"> -->
# <div style="width:604px; vertical-align:top; margin:0 auto;">
# <div style="float:left; width:600px; text-align:left;">
# <h1 class="hdng3" style="padding:0px;  margin:0px; display:inline;">Samsung Galaxy Z Fold 5</h1></div>
# <div class="rateit" data-rateit-ispreset="true" data-rateit-readonly="true" data-rateit-value="5" style="clear: both; display: block; text-align: left; width: 80px; height: 16px;">
# </div>
# <div class="hdng" style="text-align:left; clear:both;">
#     Rs. 656,999                                                                <br/>USD $2009                            <br/></div>
# <div style="width:604px; margin-top:10px; vertical-align:top;">
# <div style="float:left">
# <div class="image-container">
# <img alt="Samsung Galaxy Z Fold 5 Price in Pakistan" class="product-image" loading="lazy" src="admin/images/Samsung/SamsungGalaxyZFold5-b.jpg" title="Samsung Galaxy Z Fold 5 Mobile Price in Pakistan"/>
# </div>
# <div id="videoReview" style="width:180px; height: 32px">
# <div style="float:left">
# </div>
# <div style="width: 130px; float:left">
# </div>
# </div>
# </div>
# <br/>
# <div class="RowBG1" style="width: 375px; height: 348px; float: left; margin-bottom:8px">
# <div id="fbpage" style="height:210px; width:348px; margin: 6px auto;">
# <div class="facebook-widget" style="width: 350px; height: 220px; border: 1px solid #ccc; padding: 10px; text-align: center; font-family: Arial, sans-serif;">
# <a href="https://www.facebook.com/whatmobile.com.pk" style="text-decoration: none; color: inherit;" target="_blank">
# <img alt="WhatMobile Facebook Banner" src="/images/facebookpage.png" style="width: 328px; height: 122px;"/>
# <div style="margin-top: 10px; font-size: 20px; font-weight: bold;">WhatMobile</div>
# <div style="font-size: 14px; color: #555;">1,058,586 followers</div>
# <button onclick="window.open('https://www.facebook.com/whatmobile.com.pk', '_blank')" style="margin-top: 10px; background-color: #4267B2; color: white; border: none; padding: 10px 20px; font-size: 14px; cursor: pointer;">
#             Follow
#         </button>
# </a>
# </div>
# </div>
# <!-- /1013266/vivo350x80 -->
# <div id="div-gpt-ad-1522750675784-0" style="height:80px; width:350px; margin: 6px auto;">
# <script>
#                                         googletag.cmd.push(function () {
#                                             googletag.display('div-gpt-ad-1522750675784-0');
#                                         });
#                                     </script>
# </div>
# <div style="text-align: left; padding-left: 5px;">
# <span class="Heading1">
#                                         Samsung Galaxy Z Fold 5                                    </span><br>
# <span class="hdng">Accessories</span>
# </br></div>
# <br>
# </br></div>
# </div>
# <div style="width:604px;">
# <div class="Heading1" style="width:510px; text-align:left">
# <div align="right">
# <form action="//search.whatmobile.com.pk" id="cse-search-box" name="cse-search-box">
# <div>
# <input name="cx" type="hidden" value="partner-pub-5636963752834926:ygdbfs8e2uq"/>
# <input name="cof" type="hidden" value="FORID:10"/>
# <input name="ie" type="hidden" value="ISO-8859-1"/>
# <input name="q" size="31" type="text"/>
# <input name="sa" type="submit" value="Search"/>
# </div>
# </form>
# <script src="https://www.google.com/coop/cse/brand?form=cse-search-box&amp;lang=en" type="text/javascript"></script>
# </div>
# </div>
# <!-- options navbar -->
# <div style="display: inline-block;margin-top: 8px; width:604px;">
# <nav class="navbar navbar-inverse">
# <div class="container-fluid">
# <ul class="nav nav-pills nav-justified">
# <li title="Compare Samsung Galaxy Z Fold 5"><a href="/Samsung_Galaxy-Z-Fold-5-vs-"><span class="glyphicon glyphicon-transfer"></span> Compare</a>
# </li>
# <li title="Samsung Galaxy Z Fold 5 Pictures"><a href="Samsung_Galaxy-Z-Fold-5_Pictures"><span class="glyphicon glyphicon-picture"></span> Pictures</a>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# <!-- options navbar ends -->
# <div class="RowBG1" style="width:604px; text-align:left;">
# <div style="padding:5px;">
# <h2 style="margin:0px;">Samsung Galaxy Z Fold 5 price in Pakistan</h2>
# <p style="margin-top:2px; margin-bottom:4px;">Samsung Galaxy Z Fold 5 price                                        in Pakistan is Rs. 656,999. Official dealers and warranty providers
#                                         regulate the retail price of Samsung mobile products in official
#                                         warranty.
#
#                                     <ul style="padding:13px; margin-top:-10px; margin-bottom:-10px;">
# <li>Price of Samsung Galaxy Z Fold 5 in Pakistan is
#                                             Rs. 656,999.
#                                         </li>
# <li>Price of Samsung  in USD is
#                                             $2009.
#                                         </li>
# </ul>
# </p> <p><b> Samsung Galaxy Z Fold 5 - The Future Foldable Smartphone Of Samsung!</b><br/>
# Samsung will bring the new Galaxy Z 5 Fold in near future. We learned from a Korean blog that Samsung is already working on a foldable smartphone, which will be Samsung's Galaxy Z Fold 5. Furthermore, we will share the exciting features and specifications with you today. Let's expose this beast. As we know there will be massive dual Foldable Dynamic AMOLED 2X Capacitive Touchscreen screens on this Samsung Z Fold 5. Screen size may be 7.6 inches, which will support a full HD+ resolution of 1812 x 2176 pixels. The display is protected by the tough layer of Corning Gorilla Glass Victus+. The Samsung Galaxy's Z Fold 5 is powered by the powerful and best Qualcomm SM8475 Snapdragon 8+ Gen 2 chipset with the addition of a 3.360 GHz Octa Core CPU. So they both will easily run this beast with great speed. Additionally Galaxy Z Fold 5 will offer 12GB of RAM and 256/512GB and 1TB internal storage variants. The latest leaks suggest that it will not have any dedicated slot for external memory. The body of this Z Fold 5 could be more slim and stylish according to a leaked picture. There will be a bigger 4400 mAh battery pack that will last all day on just a single charge. It will also support Fast wired charging of 25W, wireless charging of 15W and reverse wireless charging of 4.5W. The official launching date of Samsung's Galaxy Z Fold 5 has not been confirmed yet but soon it will land in local and global markets. Now other brands will face a tough competitor in the form of Galaxy Z Fold by <a href="https://www.whatmobile.com.pk/Samsung_Mobiles_Prices" style="text-decoration: none; color: #666666;">Samsung</a> especially in the category of foldable smartphones.</p></div>
# </div>
# </div>
# <div class="Heading1" style="text-align:left; width:604px; margin-top:12px">
# <h2 class="Heading1" style="padding:0px; margin:0px; display:inline;">Samsung Galaxy Z Fold 5                                detailed specifications</h2>
# <table border="0" cellpadding="0" cellspacing="0" class="specs" width="604">
# <tbody>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainheading bottom-border-section" rowspan="6" style="text-align: left;vertical-align: top;">Build</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">OS</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Android 13 OS
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">UI</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     One UI 5.1.1
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Dimensions</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Unfolded: (158.5 x 128.5 x 6.5 mm), Folded: (158.5 x 67.5 x 14.5-16 mm)
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Weight</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     275 g
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">SIM</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Nano-SIM and eSIM or Dual SIM (2 Nano-SIMs and eSIM, dual stand-by)
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Colors</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                     Black; other colors
#                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainheading bottom-border-section" rowspan="4" style="text-align: left;vertical-align: top;">Frequency</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">2G Band</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2"><b>SIM1:</b> GSM 850 / 900 / 1800 / 1900<br><b>SIM2:</b> GSM 850 / 900 / 1800 / 1900
#                                                 </br></td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">3G Band</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">4G Band</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     LTE
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">5G Band</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                     SA/NSA/Sub6/mmWave
#                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainheading bottom-border-section" rowspan="3" style="text-align: left;vertical-align: top;">Processor</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">CPU</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Octa-core (1 x 3.36 GHz Cortex-X3 &amp; 2x2.8 GHz Cortex-A715 + 2x 2.8 GHz Cortex-A710 + 3 x 2.0 GHz Cortex-A510)
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Chipset</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Qualcomm SM8550-AC Snapdragon 8 Gen 2 (4 nm)
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">GPU</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                     Adreno 740
#                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainheading bottom-border-section" rowspan="5" style="text-align: left;vertical-align: top;">Display</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Technology</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Foldable Dynamic AMOLED 2X Capacitive Touchscreen, Multitouch
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Size</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     7.6 Inches
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Resolution</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     1812 x 2176 Pixels (~373 PPI)
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Protection</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Corning Gorilla Glass Victus+
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Extra Features</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                     120Hz, HDR10+, Cover display: 6.2 inches, 904 x 2316 pixels, 23.1:9 ratio,, Dynamic AMOLED 2X, 120Hz, Corning Gorilla Glass Victus+
#                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainheading bottom-border-section" rowspan="2" style="text-align: left;vertical-align: top;">Memory</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Built-in</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">256/512GB, 1TB Built-in, 12GB RAM, UFS 4.0
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Card</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                     No
#                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainheading bottom-border-section" rowspan="3" style="text-align: left;vertical-align: top;">Camera</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Main</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Triple Camera: 50 MP, f/1.8, 23mm (wide), Dual Pixel PDAF, OIS + 10 MP, f/2.4, (telephoto), PDAF, OIS, 3x optical zoom + 12 MP, f/2.2, 123Ë, 12mm (ultrawide), LED Flash
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Features</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Geo-tagging, touch focus, HDR, panorama, Video (8K@24fps, 4K@60fps, 1080p@60/240fps (gyro-EIS), 720p@960fps (gyro-EIS), HDR10+)
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Front</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
#                                                     Under display Cover camera: 10 MP, f/2.2, 24mm (wide), 1/3" + 4 MP, f/1.8, 26mm (wide), HDR, Video (4K@30/60fps, 1080p@30/60fps, gyro-EIS)
#                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainheading bottom-border-section" rowspan="6" style="text-align: left;vertical-align: top;">Connectivity</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">WLAN</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Wi-Fi 802.11 a/b/g/n/ac/6e/7, tri-band, Wi-Fi Direct
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Bluetooth</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     v5.3 with A2DP, LE, apt-X HD
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">GPS</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Yes + AGPS, GLONASS, BDS, GALILEO
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">USB</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     USB Type-C 3.2, OTG
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">NFC</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Yes
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Data</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
# <font color="#000077"><b>GPRS</b></font>, Edge, 3G (HSPA 42.2/5.76 Mbps, 4G (LTE-A (7CA) Cat20 2000/200 Mbps), 5G capable
#                                                 </td>
# </tr>
# <!--Main Category-->
# <tr class="RowBG2">
# <td class="hdngArial specs-mainheading bottom-border-section" rowspan="7" style="text-align: left;vertical-align: top;">Features</td>
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Sensors</th>
# <td class="fasla RowBG1 specs-value bottom-border" colspan="2">Accelerometer, Compass, Fingerprint (side-mounted), Gyro, Proximity
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Audio</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     32-bit/384kHz audio Tuned by AKG, Speaker Phone
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Browser</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     HTML5
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Messaging</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     SMS(threaded view), MMS, Email, Push Mail, IM
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Games</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Built-in + Downloadable
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border">Torch</th>
# <td class="fasla specs-value bottom-border" colspan="2">
#                                                     Yes
#                                                 </td>
# </tr>
# <tr class="RowBG1">
# <th align="left" class="hdngArial specs-subHeading RowBG1 bottom-border-section">Extra</th>
# <td class="fasla specs-value bottom-border-section" colspan="2">
# ...
#                                     Samsung                                    Galaxy Z Fold 6</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-Z-Flip-6" style="text-decoration:none" title="Samsung Galaxy Z Flip 6">
#                                     Samsung                                    Galaxy Z Flip 6</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A06-128GB" style="text-decoration:none" title="Samsung Galaxy A06 128GB">
#                                     Samsung                                    Galaxy A06 128GB</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A55" style="text-decoration:none" title="Samsung Galaxy A55">
#                                     Samsung                                    Galaxy A55</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A35" style="text-decoration:none" title="Samsung Galaxy A35">
#                                     Samsung                                    Galaxy A35</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-S24-Ultra-512GB" style="text-decoration:none" title="Samsung Galaxy S24 Ultra 512GB">
#                                     Samsung                                    Galaxy S24 Ultra 512GB</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-S24-Ultra" style="text-decoration:none" title="Samsung Galaxy S24 Ultra">
#                                     Samsung                                    Galaxy S24 Ultra</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-S24" style="text-decoration:none" title="Samsung Galaxy S24">
#                                     Samsung                                    Galaxy S24</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A25" style="text-decoration:none" title="Samsung Galaxy A25">
#                                     Samsung                                    Galaxy A25</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A15-256GB" style="text-decoration:none" title="Samsung Galaxy A15 256GB">
#                                     Samsung                                    Galaxy A15 256GB</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A15" style="text-decoration:none" title="Samsung Galaxy A15">
#                                     Samsung                                    Galaxy A15</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A05-6GB" style="text-decoration:none" title="Samsung Galaxy A05 6GB">
#                                     Samsung                                    Galaxy A05 6GB</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A05s-6GB" style="text-decoration:none" title="Samsung Galaxy A05s 6GB">
#                                     Samsung                                    Galaxy A05s 6GB</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A05-128GB" style="text-decoration:none" title="Samsung Galaxy A05 128GB">
#                                     Samsung                                    Galaxy A05 128GB</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A05s" style="text-decoration:none" title="Samsung Galaxy A05s">
#                                     Samsung                                    Galaxy A05s</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A05" style="text-decoration:none" title="Samsung Galaxy A05">
#                                     Samsung                                    Galaxy A05</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A34-256GB" style="text-decoration:none" title="Samsung Galaxy A34 256GB">
#                                     Samsung                                    Galaxy A34 256GB</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A34" style="text-decoration:none" title="Samsung Galaxy A34">
#                                     Samsung                                    Galaxy A34</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A54" style="text-decoration:none" title="Samsung Galaxy A54">
#                                     Samsung                                    Galaxy A54</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-Z-Flip-5" style="text-decoration:none" title="Samsung Galaxy Z Flip 5">
#                                     Samsung                                    Galaxy Z Flip 5</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-Z-Fold-5" style="text-decoration:none" title="Samsung Galaxy Z Fold 5">
#                                     Samsung                                    Galaxy Z Fold 5</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-S23-FE" style="text-decoration:none" title="Samsung Galaxy S23 FE">
#                                     Samsung                                    Galaxy S23 FE</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A04s-128GB" style="text-decoration:none" title="Samsung Galaxy A04s 128GB">
#                                     Samsung                                    Galaxy A04s 128GB</a>
# </li>
# <li>
# <a class="lilinks" href="/Samsung_Galaxy-A04s" style="text-decoration:none" title="Samsung Galaxy A04s">
#                                     Samsung                                    Galaxy A04s</a>
# </li>
# </ul>
# </div>
# <div class="clearall"></div>
# </div>
# </span>
# </div>
# <div class="slinks" style="width: 165px; text-align: left;">
# <h2 class="Heading1 biggerText" style="padding:0px; display:block;"><a class="hdng" href="/Comingsoon_Samsung_Mobiles_Prices" span="" style="text-decoration:none">Coming Soon
#                     Mobiles</a></h2>
# <ul style="overflow: hidden; list-style: none !important; margin: 0 !important; padding: 0 !important;">
# <li style="float: left; height: 130px; position: relative; text-align: center; width: 100px; list-style: none !important; margin: 0px 0px 5px 0px; padding-top: 0;">
# <a href="/Samsung_Galaxy-S25-Slim">
# <img alt="&lt;h6&gt;Samsung Galaxy S25 Slim Price in Pakistan and specifications&lt;/h6&gt;" src="admin/images/Samsung/SamsungGalaxyS25Slim-s"/></a><br>
# <h6 class="p6 biggerText"><a class="biggerText" href="/Samsung_Galaxy-S25-Slim" style="margin-top: 3px; display: block; text-decoration:none" title="Samsung Galaxy S25 Slim">
#                                 Samsung Galaxy S25 Slim<br/></a></h6>
# </br></li>
# <li style="float: left; height: 130px; position: relative; text-align: center; width: 100px; list-style: none !important; margin: 0px 0px 5px 0px; padding-top: 0;">
# <a href="/Samsung_Galaxy-A26">
# <img alt="&lt;h6&gt;Samsung Galaxy A26 Price in Pakistan and specifications&lt;/h6&gt;" src="admin/images/Samsung/SamsungGalaxyA26-s"/></a><br>
# <h6 class="p6 biggerText"><a class="biggerText" href="/Samsung_Galaxy-A26" style="margin-top: 3px; display: block; text-decoration:none" title="Samsung Galaxy A26">
#                                 Samsung Galaxy A26<br/></a></h6>
# </br></li>
# <li style="float: left; height: 130px; position: relative; text-align: center; width: 100px; list-style: none !important; margin: 0px 0px 5px 0px; padding-top: 0;">
# <a href="/Samsung_Galaxy-A16-5G">
# <img alt="&lt;h6&gt;Samsung Galaxy A16 5G Price in Pakistan and specifications&lt;/h6&gt;" src="admin/images/Samsung/SamsungGalaxyA165G-s"/></a><br>
# <h6 class="p6 biggerText"><a class="biggerText" href="/Samsung_Galaxy-A16-5G" style="margin-top: 3px; display: block; text-decoration:none" title="Samsung Galaxy A16 5G">
#                                 Samsung Galaxy A16 5G<br/></a></h6>
# </br></li>
# <li style="float: left; height: 130px; position: relative; text-align: center; width: 100px; list-style: none !important; margin: 0px 0px 5px 0px; padding-top: 0;">
# <a href="/Samsung_Galaxy-S25-FE">
# <img alt="&lt;h6&gt;Samsung Galaxy S25 FE Price in Pakistan and specifications&lt;/h6&gt;" src="admin/images/Samsung/SamsungGalaxyS25FE-s"/></a><br>
# <h6 class="p6 biggerText"><a class="biggerText" href="/Samsung_Galaxy-S25-FE" style="margin-top: 3px; display: block; text-decoration:none" title="Samsung Galaxy S25 FE">
#                                 Samsung Galaxy S25 FE<br/></a></h6>
# </br></li>
# <li style="float: left; height: 130px; position: relative; text-align: center; width: 100px; list-style: none !important; margin: 0px 0px 5px 0px; padding-top: 0;">
# <a href="/Samsung_Galaxy-A36">
# <img alt="&lt;h6&gt;Samsung Galaxy A36 Price in Pakistan and specifications&lt;/h6&gt;" src="admin/images/Samsung/SamsungGalaxyA36-s"/></a><br/>
# <h6 class="p6 biggerText"><a class="biggerText" href="/Samsung_Galaxy-A36" style="margin-top: 3px; display: block; text-decoration:none" title="Samsung Galaxy A36">
#                                 Samsung Galaxy A36<br/></a></h6>
# </li>
# <li style="float: left; height: 130px; position: relative; text-align: center; width: 100px; list-style: none !important; margin: 0px 0px 5px 0px; padding-top: 0;">
# <a href="/Samsung_Galaxy-A56">
# <img alt="&lt;h6&gt;Samsung Galaxy A56 Price in Pakistan and specifications&lt;/h6&gt;" src="admin/images/Samsung/SamsungGalaxyA56-s"/></a><br/>
# <h6 class="p6 biggerText"><a class="biggerText" href="/Samsung_Galaxy-A56" style="margin-top: 3px; display: block; text-decoration:none" title="Samsung Galaxy A56">
#                                 Samsung Galaxy A56<br/></a></h6>
# </li>
# <li style="float: left; height: 130px; position: relative; text-align: center; width: 100px; list-style: none !important; margin: 0px 0px 5px 0px; padding-top: 0;">
# <a href="/Samsung_Galaxy-S25-Plus">
# <img alt="&lt;h6&gt;Samsung Galaxy S25 Plus Price in Pakistan and specifications&lt;/h6&gt;" src="admin/images/Samsung/SamsungGalaxyS25Plus-s"/></a><br/>
# <h6 class="p6 biggerText"><a class="biggerText" href="/Samsung_Galaxy-S25-Plus" style="margin-top: 3px; display: block; text-decoration:none" title="Samsung Galaxy S25 Plus">
#                                 Samsung Galaxy S25 Plus<br/></a></h6>
# </li>
# <li style="float: left; height: 130px; position: relative; text-align: center; width: 100px; list-style: none !important; margin: 0px 0px 5px 0px; padding-top: 0;">
# <a href="/Samsung_Galaxy-Z-Fold-SE">
# <img alt="&lt;h6&gt;Samsung Galaxy Z Fold SE Price in Pakistan and specifications&lt;/h6&gt;" src="admin/images/Samsung/SamsungGalaxyZFoldSE-s"/></a><br/>
# <h6 class="p6 biggerText"><a class="biggerText" href="/Samsung_Galaxy-Z-Fold-SE" style="margin-top: 3px; display: block; text-decoration:none" title="Samsung Galaxy Z Fold SE">
#                                 Samsung Galaxy Z Fold SE<br/></a></h6>
# </li>
# </ul>
# </div>
# </div> </div>
# </div>
# <div style="width:100%; /*height:44px;*/  vertical-align: top; display:inline-block; text-align:center;">
# <div style="width:650px; /*height:44px;*/ margin:0;display:inline-block;"><style>
#
#     /*.p4, .p6 {*/
#         /*text-decoration: none !important;*/
#         /*display: block !important;*/
#         /*font-weight: normal !important;*/
#         /*margin-top: 0 !important;*/
#         /*margin-bottom: 0 !important;*/
#     /*}*/
# </style><div style="padding-top: 5px;"><input name="IL_IN_TAG" type="hidden" value="2"/> </div>
# <div align="center" class="normText"><span id="Footer1_S21">  <strong>Disclaimer.</strong> Mobile Prices are updated daily from local Pakistani Mobile shops &amp; Mobile dealers in Pakistan but we can not guarantee that the information (Prices) on this page is 100% correct (Human error is possible). Always visit your local shop for exact mobile prices. *Above mobile prices and rates are only valid in Pakistan.<br/><br/>Copyright © 2024       www.whatmobile.com.pk. All Rights Reserved. </span><br/>
# <span id="Footer1_S21"><a href="Privacy.php" style="text-decoration:none">Privacy</a> | <a href="Advertise.php" style="text-decoration:none">Advertise</a> | <a href="feedback.php" style="text-decoration:none">Contact us</a>
#          | <a href="https://m.whatmobile.com.pk/Samsung_Galaxy-Z-Fold-5" rel="alternate" style="text-decoration:none"> Mobile Version</a> </span>
# <div style="width:122px;">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVDVQQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#     </div>
# <!-- /1013266/Specs1x1 -->
# <div id="div-gpt-ad-1581089702359-0" style="width: 1px; height: 1px;">
# <script>
#      googletag.cmd.push(function() { googletag.display('div-gpt-ad-1581089702359-0'); });
#   </script>
# </div>
# <script src="js/jquery.min.js" type="text/javascript"></script>
# <script src="js/search.top.js" type="text/javascript"></script>
# <script src="js/ajax.js" type="text/javascript"></script>
# <script src="js/clamp.min.js" type="text/javascript"></script>
# </div>
# <!-- Import and configure the Firebase SDK -->
# <script src="https://www.gstatic.com/firebasejs/7.24.0/firebase-app.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.24.0/firebase-messaging.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.24.0/firebase-auth.js"></script>
# <script src="https://cdn.firebase.com/libs/firebaseui/3.5.2/firebaseui.js"></script>
# <link href="https://cdn.firebase.com/libs/firebaseui/3.5.2/firebaseui.css" rel="stylesheet" type="text/css">
# <!-- Firebase initialization handled by init.js -->
# <script src="/js/fcmp/init.js?v=1.5"></script>
# <!-- Service class for WMService -->
# <script src="/js/fcmp/wm-service.js?v=1.5"></script>
# <!-- Messaging script for foreground notifications -->
# <script src="/js/fcmp/whatmobile-messaging1.js?v=1.5"></script>
# <!-- Register the service worker for background notifications -->
# <script>
# if ('serviceWorker' in navigator) {
#   navigator.serviceWorker.getRegistration('/firebase-messaging-sw.js').then(function(registration) {
#     if (!registration) {
#       // Service worker is not registered, register it
#       navigator.serviceWorker.register('/firebase-messaging-sw.js', { scope: '/' })
#         .then(function(registration) {
#           console.log('Service Worker registered with scope:', registration.scope);
#         }).catch(function(error) {
#           console.error('Service Worker registration failed:', error);
#         });
#     } else {
#       // Service worker is already registered
#       console.log('Service Worker already registered:', registration);
#     }
#   });
# }
# </script></link></div>
# </div>
# </div>
# <script src="rateit/scripts/jquery.rateit.js" type="text/javascript"></script>
# <script>
# document.addEventListener('DOMContentLoaded', function() {
#     var youtubePlaceholders = document.querySelectorAll('.youtube-placeholder');
#
#     youtubePlaceholders.forEach(function(placeholder) {
#         placeholder.addEventListener('click', function() {
#             var videoId = this.getAttribute('data-video-id');
#             var iframe = document.createElement('iframe');
#
#             iframe.setAttribute('width', '604');
#             iframe.setAttribute('height', '370');
#             iframe.setAttribute('frameborder', '0');
#             iframe.setAttribute('allowfullscreen', 'true');
#             iframe.setAttribute('src', 'https://www.youtube.com/embed/' + videoId + '?rel=0&autoplay=1');
#
#             this.parentNode.replaceChild(iframe, this);
#         });
#     });
# });
# </script>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'8ef489922876ce56',t:'MTczMzc0MjUwOC4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>

# %% [markdown]
# ### Find and print the product title

# %%
new_soup.find("h2",class_="Heading1")
# Out:
# <h2 class="Heading1" style="padding:0px; margin:0px; display:inline;">Samsung Galaxy Z Fold 5                                detailed specifications</h2>

# %% [markdown]
# ### Extract and print the product title without unwanted characters

# %%
new_soup.find("h2",class_="Heading1").text
# Out:
# 'Samsung Galaxy Z Fold 5                                detailed specifications'

# %%
new_soup.find("h2",class_="Heading1").text.replace("                                detailed specifications'","")
# Out:
# 'Samsung Galaxy Z Fold 5                                detailed specifications'

# %% [markdown]
# ### Find and print the product price

# %%
new_soup.find("div",class_="_30jeq3 _16Jk6d")
# Out:
# <div class="_30jeq3 _16Jk6d">₹45,999</div>

# %%
new_soup.find("div",class_="_30jeq3 _16Jk6d").text
# Out:
# '₹45,999'

# %% [markdown]
# ### Extract and print the product rating

# %%
new_soup.find("div",class_="_3LWZlK").text
# Out:
# '4.3'

# %% [markdown]
# ### Extract and print the number of reviews

# %%
new_soup.find("span",class_="_2_R_DZ").find_all("span")[3].text.replace("\xa0","")
# Out:
# '7,441 Reviews'

# %% [markdown]
# ### Extract and print product color

# %%
new_soup.find_all("tr",class_="_1s_Smc row")[3].find("li",class_="_21lJbe").text
# Out:
# 'Olive'

# %% [markdown]
# ### Extract and print product display size

# %%
new_soup.find_all("tr",class_="_1s_Smc row")[9].find("li",class_="_21lJbe").text
# Out:
# 'Yes'
