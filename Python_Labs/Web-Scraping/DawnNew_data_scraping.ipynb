# %% [markdown]
# # Problem Statement: Web Scraping News Information from DawnNews WebPortal
#
# **Background:**
#
# Dawn News is an News platform where users can search for and read various news & articles.
#
# **Objective:**
#
# The objective of this project is to create a Python script that performs web scraping on Dawn News website to extract essential information about Samsung mobile phone and store it for further analysis or use.

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

# %% [markdown]
# ### Define the URL to scrape data

# %%
URL = f"https://www.dawn.com/latest-news"

# %% [markdown]
# ### Setting user-agent headers

# %%
HEADERS = {"User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36'}

# %% [markdown]
# ### Send an HTTP GET request to the URL

# %%
response = requests.get(URL,headers=HEADERS)

# %% [markdown]
# ### Print the HTTP response object

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Get the content of the HTTP response

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n\n<head>\n        \n    <!-- meta -->\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n    <!--[if IE]> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <![endif]-->\n    <title>Latest - DAWN.COM</title> \n     <meta name=\'subject\' content=\'Your window to latest news, analysis and features from Pakistan, South Asia and the world.\' /> \n     <meta name=\'description\' content=\'Pakistan&rsquo;s most trusted outlet for the breaking, latest and top news across the country and the world.\' /> \n     <meta property=\'fb:app_id\' content=\'1383068068604634\' />  \n     <meta property=\'og:locale\' content=\'en_US\' /> \n     <link rel=\'canonical\' href=\'https://www.dawn.com/latest-news\' /> \n     <link rel=\'alternate\' type=\'application/rss+xml\' title=\'The Dawn News\' href=\'https://www.dawn.com/feeds/latest-news/\' />  \n     \n     <link rel=\'index\' href=\'https://www.dawn.com/latest-news\' />\n     <meta name=\'twitter:image\' content=\'https://www.dawn.com/_img/social-default.jpg\' />\n     <meta property=\'og:image\' content=\'https://www.dawn.com/_img/social-default.jpg\' />\n     <meta itemprop=\'image\' content=\'https://www.dawn.com/_img/social-default.jpg\' />    \n    \n    <!-- Google tag (gtag.js) -->\n    <script async src="https://www.googletagmanager.com/gtag/js?id=G-C521GRS8DF"></script>\n    <script>\n        window.dataLayer = window.dataLayer || [];\n        window.googletag = window.googletag || {cmd: []};\n        function gtag(){dataLayer.push(arguments);}\n        gtag(\'js\', new Date());\n        gtag(\'config\', \'G-C521GRS8DF\');\n    </script>\n    <script>\n        gtag(\'event\', \'custom\', {\n            "Category": "Latest",\n            "non_interaction": true\n        });\n    </script>\n    \n<script type="application/ld+json">\n    {"@context":"http:\\/\\/schema.org","@type":"organization","logo":"https:\\/\\/www.dawn.com\\/_img\\/logo.png","name":"DAWN.COM","url":"https:\\/\\/www.dawn.com","sameAs":["https:\\/\\/www.facebook.com\\/dawndotcom\\/","https:\\/\\/twitter.com\\/dawn_com","https:\\/\\/www.instagram.com\\/dawn.today\\/",""],"potentialAction":{"@type":"SearchAction","target":"https:\\/\\/www.dawn.com\\/search?cx=016184311056644083324:a1i8yd7zymy&ie=UTF-8&q={search_term_string}","query-input":"required name=search_term_string"}}\n</script>\n<script type="application/ld+json">\n    {"@context": "http://schema.org", "@type": "BreadcrumbList","itemListElement": [{"@type":"ListItem","position":1,"item":{"@id":"https:\\/\\/www.dawn.com\\/latest-news","name":"Latest"}}]}\n</script>\n\n    <!-- - - - - start:counters - - - - -->\n    <script type=\'text/javascript\'>\n    document.addEventListener("DOMContentLoaded", function() {\n        Counter.count([{"category":"Latest"}]);\n    });\n    </script>\n    <!-- - - - - end:counters - - - - -->\n        \n    \n    <link rel=\'stylesheet\'  href=\'https://fonts.googleapis.com/css?family=Playfair+Display:400,400i,700,700i,900&amp;display=swap\' media=\'all\'>\n    <link rel=\'stylesheet\'  href=\'https://www.dawn.com/_css/newskit.20241118133706.css\' media=\'all\'>\n    <link rel=\'stylesheet\'  href=\'https://www.dawn.com/_css/merriweather.20241015121807.css\' media=\'all\'>\n    <link rel=\'stylesheet\'  href=\'https://www.dawn.com/_css/shame.20241206112808.css\' media=\'all\'>\n    <script  src=\'https://code.jquery.com/jquery-3.6.0.min.js\' defer=\'true\'></script>\n    <script  src=\'https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.3.2/lazysizes.min.js\' defer=\'true\'></script>\n    <script  src=\'https://www.dawn.com/_js/ad-sticky-close.20240401153110.js\' defer=\'true\'></script>\n    <script  src=\'https://www.dawn.com/_js/all.20241115144107.js\' defer=\'true\'></script>\n    <link rel=\'preload\' as=\'style\' href=\'https://www.dawn.com/_css/headroom.20241114121412.css\'>\n    <link rel=\'preload\' as=\'font\'  ...

# %% [markdown]
# ### Parse the HTML content of the response using BeautifulSoup

# %%
soup = BeautifulSoup(response.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- meta -->
# <meta charset="utf-8"/>
# <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
# <!--[if IE]> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <![endif]-->
# <title>Latest - DAWN.COM</title>
# <meta content="Your window to latest news, analysis and features from Pakistan, South Asia and the world." name="subject">
# <meta content="Pakistan’s most trusted outlet for the breaking, latest and top news across the country and the world." name="description">
# <meta content="1383068068604634" property="fb:app_id"/>
# <meta content="en_US" property="og:locale"/>
# <link href="https://www.dawn.com/latest-news" rel="canonical"/>
# <link href="https://www.dawn.com/feeds/latest-news/" rel="alternate" title="The Dawn News" type="application/rss+xml"/>
# <link href="https://www.dawn.com/latest-news" rel="index"/>
# <meta content="https://www.dawn.com/_img/social-default.jpg" name="twitter:image"/>
# <meta content="https://www.dawn.com/_img/social-default.jpg" property="og:image"/>
# <meta content="https://www.dawn.com/_img/social-default.jpg" itemprop="image"/>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-C521GRS8DF"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         window.googletag = window.googletag || {cmd: []};
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#         gtag('config', 'G-C521GRS8DF');
#     </script>
# <script>
#         gtag('event', 'custom', {
#             "Category": "Latest",
#             "non_interaction": true
#         });
#     </script>
# <script type="application/ld+json">
#     {"@context":"http:\/\/schema.org","@type":"organization","logo":"https:\/\/www.dawn.com\/_img\/logo.png","name":"DAWN.COM","url":"https:\/\/www.dawn.com","sameAs":["https:\/\/www.facebook.com\/dawndotcom\/","https:\/\/twitter.com\/dawn_com","https:\/\/www.instagram.com\/dawn.today\/",""],"potentialAction":{"@type":"SearchAction","target":"https:\/\/www.dawn.com\/search?cx=016184311056644083324:a1i8yd7zymy&ie=UTF-8&q={search_term_string}","query-input":"required name=search_term_string"}}
# </script>
# <script type="application/ld+json">
#     {"@context": "http://schema.org", "@type": "BreadcrumbList","itemListElement": [{"@type":"ListItem","position":1,"item":{"@id":"https:\/\/www.dawn.com\/latest-news","name":"Latest"}}]}
# </script>
# <!-- - - - - start:counters - - - - -->
# <script type="text/javascript">
#     document.addEventListener("DOMContentLoaded", function() {
#         Counter.count([{"category":"Latest"}]);
#     });
#     </script>
# <!-- - - - - end:counters - - - - -->
# <link href="https://fonts.googleapis.com/css?family=Playfair+Display:400,400i,700,700i,900&amp;display=swap" media="all" rel="stylesheet"/>
# <link href="https://www.dawn.com/_css/newskit.20241118133707.css" media="all" rel="stylesheet"/>
# <link href="https://www.dawn.com/_css/merriweather.20241015121807.css" media="all" rel="stylesheet"/>
# <link href="https://www.dawn.com/_css/shame.20241206112807.css" media="all" rel="stylesheet"/>
# <script defer="true" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
# <script defer="true" src="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.3.2/lazysizes.min.js"></script>
# <script defer="true" src="https://www.dawn.com/_js/ad-sticky-close.20240324031335.js"></script>
# <script defer="true" src="https://www.dawn.com/_js/all.20241115144107.js"></script>
# <link as="style" href="https://www.dawn.com/_css/headroom.20241114121409.css" rel="preload"/>
# <link as="font" href="https://fonts.googleapis.com/css?family=Playfair+Display:400,400i,700,700i,900&amp;display=swap" rel="preload"/>
# <link as="style" href="https://www.dawn.com/_css/newskit.20241118133707.css" rel="preload"/>
# <link as="style" href="https://www.dawn.com/_css/merriweather.20241015121807.css" rel="preload"/>
# <link as="style" href="https://www.dawn.com/_css/shame.20241206112807.css" rel="preload"/>
# <link as="script" href="https://code.jquery.com/jquery-3.6.0.min.js" rel="preload"/>
# <link as="script" href="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.3.2/lazysizes.min.js" rel="preload"/>
# <link as="script" href="https://www.dawn.com/_js/ad-sticky-close.20240324031335.js" rel="preload"/>
# <link as="script" href="https://www.dawn.com/_js/all.20241115144107.js" rel="preload"/>
# <link href="i.dawn.com" rel="dns-prefetch preconnect"/>
# <link href="fonts.googleapis.com" rel="dns-prefetch preconnect"/>
# <link href="code.jquery.com" rel="dns-prefetch preconnect"/>
# <link href="cdnjs.cloudflare.com" rel="dns-prefetch preconnect"/>
# <!-- adverts:header start -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#     window.googletag = window.googletag || {cmd: []};
#     window.debugAds = window.location && window.location.search && window.location.search.includes('googfc');
#
#     googletag.cmd.push(function() {
#
#         googletag.defineSlot('/1029551/Dawn-Responsive-Middle-Leaderboard', [[970,250],[970,90],[728,90],[300,600],[320,480],[320,50],[320,100],[300,50],[300,250],[1,1]], 'div-gpt-ad-1693559881661-0')
#             .defineSizeMapping([[[728,0],[[728,90],[300,600],[320,480],[320,50],[320,100],[300,50],[1,1]]],[[0,0],[[300,600],[320,480],[300,250],[320,50],[320,100],[300,50],[1,1]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-BTF-MREC', [[300,250]], 'div-gpt-ad-1683363763562-0')
#             .defineSizeMapping([[[0,0],[[300,250]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-SKY-MREC', [[300,250],[320,480],[300,600],[160,600]], 'div-gpt-ad-1683363860950-0')
#             .defineSizeMapping([[[0,0],[[300,600],[320,480],[300,250],[160,600]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-ATF-MREC', [[300,250]], 'div-gpt-ad-1683363673257-0')
#             .defineSizeMapping([[[0,0],[[300,250]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-Footer-Stickable-Leaderboard', [[970,250],[970,90],[728,90],[320,50],[320,100],[300,50],[300,250],[1,1]], 'div-gpt-ad-1693559286339-0')
#             .defineSizeMapping([[[970,0],[[970,250],[970,90],[728,90],[320,50],[320,100],[300,50],[1,1]]],[[728,0],[[728,90],[320,50],[320,100],[300,50],[1,1]]],[[0,0],[[300,250],[320,50],[320,100],[300,50],[1,1]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-Header-Leaderboard', [[970,250],[970,90],[728,90],[320,50],[320,100],[300,50],[300,250]], 'div-gpt-ad-1683363187247-0')
#             .defineSizeMapping([[[970,0],[[970,250],[970,90],[728,90],[320,50],[320,100],[300,50]]],[[728,0],[[728,90],[320,50],[320,100],[300,50]]],[[0,0],[[320,50],[320,100],[300,50]]]])
#             .addService(googletag.pubads());
#
#         googletag.pubads().setTargeting('site', ["www.dawn.com"]);
#         googletag.pubads().setTargeting('category', ["Latest"]);
#
#         googletag.pubads().enableLazyLoad({
#             fetchMarginPercent: -1,
#             renderMarginPercent: 50,
#             mobileScaling: 2.0
#         });
#
#         googletag.pubads().enableSingleRequest();
#
#         // refreshAd('/3023235/Responsive-Middle-Leaderboard')
#         // refreshAd('div-gpt-ad-1693559881661-0')
#         window.refreshAd = ((id) => {
#             console.log(new Date().toISOString().substr(11, 8), 'refreshAd(' + id + ')');
#             for (let slot of googletag.pubads().getSlots()) {
#                 if (slot.getAdUnitPath() === id || slot.getSlotElementId() == id) {
#                     googletag.pubads().refresh([slot]);
#                 }
#             }
#         });
#
#         // <div data-refresh="30" id='div-gpt-ad-1234567890123-0' ...
#         googletag.pubads().addEventListener("slotRenderEnded", (e) => {
#             const id = e.slot.getSlotElementId();
#             document.getElementById(id).classList.add('ad-rendered');
#
#             // data-refresh
#             var seconds = null;
#             if (seconds = document.getElementById(id).getAttribute('data-refresh')) {
#                 console.log(new Date().toISOString().substr(11, 8), 'refreshAd(' + id + ') in ' + seconds + 's');
#                 window.__refreshAdTimeouts = window.__refreshAdTimeouts || [];
#                 clearTimeout(window.__refreshAdTimeouts[id]);
#                 window.__refreshAdTimeouts[id] = setTimeout(() => refreshAd(id), seconds * 1000);
#             };
#
#             // data-rendered-classes
#             var renderedClasses = null;
#             if (renderedClasses = document.getElementById(id).getAttribute('data-rendered-classes')) {
#                 document.getElementById(id).classList.add(renderedClasses);
#             }
#         });
#
#         if (debugAds) {
#             // debugging is enabled, add bgcolor and padding on all ad divs
#             document.querySelectorAll('[id^="div-gpt-ad-"]').forEach(el => {
#                 var hasError = el.classList.contains('advert-error');
#                 el.style.backgroundColor = hasError ? '#ecc' : '#ccc';
#                 el.title = el.dataset.name || '';
#                 el.innerHTML = hasError ? el.dataset.name : '';
#                 if (hasError) {
#                     el.style.padding = '10px';
#                 }
#                 el.style.height = el.dataset.height || '';
#                 el.style.width = el.dataset.width || '';
#             });
#         } else {
#             googletag.pubads().collapseEmptyDivs();
#         }
#
#         googletag.enableServices();
#     });
#
#     // Relocate Ads
#     window.addEventListener('DOMContentLoaded',function () {
#         document.querySelectorAll('[data-selector]').forEach(ad => {
#             if (target = document.querySelector(ad.getAttribute('data-selector'))) {
#                 target.insertAdjacentElement('afterend', ad);
#             }
#         });
#     });
#
#     // Relocate Ad if viewport width is less than 720px
#     window.addEventListener('DOMContentLoaded',function () {
#         if (window.matchMedia('(max-width: 720px)').matches) {
#             document.querySelectorAll('[data-selector-mobile]').forEach(ad => {
#                 if (target = document.querySelector(ad.getAttribute('data-selector-mobile'))) {
#                     target.insertAdjacentElement('afterend', ad);
#                 }
#             });
#         }
#     });
#     </script>
# <!-- adverts:header end -->
# <!-- - - - - start:onesignal link - - - - -->
# <link href="/manifest.json" rel="manifest"/>
# <!-- - - - - end:onesignal link - - - - -->
# </meta></meta></head>
# <body class="ar-8 latest-news antialiased">
# <header class="pb-2">
# <div class="w-full bg-black nav--network">
# <div class="px-2 hidden sm:block">
# <nav class="text-white flex flex-row flex-wrap text-2.5 justify-center text-center">
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://epaper.dawn.com">EPAPER</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawnnews.tv/watch-live">LIVE TV</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawnnews.tv">DAWNNEWS URDU</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://images.dawn.com">Images</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://herald.dawn.com">Herald</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://aurora.dawn.com">Aurora</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://cityfm89.com" rel="noreferrer" target="blank">CityFM89</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawn.com/advertise" rel="noreferrer" target="blank">Advertise</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawn.com/events" rel="noreferrer" target="blank">Events</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawn.com/events/supplements"><span class="-ml-4 mr-1">/</span>Supplements</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="http://classifieds.dawn.com/" rel="noreferrer" target="blank">Classifieds</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://obituary.dawn.com" rel="noreferrer" target="blank">Obituaries</a>
# </nav>
# </div>
# </div>
# <div class="">
# <div class="container px-2 sm:px-0">
# <div class="flex flex-col sm:flex-row">
# <div class="w-1/4">
# </div>
# <div class="sm:w-1/2 w-full">
# <div class="flex flex-col items-center mt-4 mb-3">
# <a class="logo mb-2" href="https://www.dawn.com/" title="DAWN.COM">
# <img alt="DAWN.COM Logo" class="w-44" src="https://www.dawn.com/_img/logo.png"/>
# <span class="hidden">DAWN.COM</span>
# </a>
# <h2 class="badge inline-flex text-2.5 font-arial uppercase text-gray-500 align-middle" dir="auto" id="span-class-font-bold-text-black-e-paper-span-december-09-2024"><a class="" href="https://epaper.dawn.com" title="&lt;span class='font-bold text-black'&gt;E-Paper&lt;/span&gt; | December 09, 2024"><span class="font-bold text-black">E-Paper</span> | December 09, 2024</a></h2>
# </div>
# </div>
# <div class="w-1/4">
# </div>
# </div>
# </div>
# </div>
# <div class="container px-2 sm:px-0 headroom">
# <div class="flow-root container mx-auto mx-auto px-0 sm:px-6.5">
# <!-- nav container -->
# <nav class="native-hidden js-nav relative font-sans container p-0 border-t-3 border-black">
# <div class="js-nav-container border-b border-gray-200">
# <div class="nav-alignment flex justify-between items-center">
# <!-- nav items -->
# <div class="js-nav-items flex overflow-y-hidden overflow-x-scroll px-0 w-full primary-scroll mr-1">
# <div class="flex flex-row overflow-x-scroll w-full justify-start">
# <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="//www.dawn.com" target="_self" title="Home">
#      Home
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 bg-gray-100 border-b border-gray-900" href="/latest-news" target="_self" title="Latest">
#      Latest
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 text-red-300" href="https://www.dawn.com/breathepakistan/" target="_self" title="Breathe">
#      Breathe
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 text-red-300" href="https://www.dawn.com/trends/gaza-invasion" target="_self" title="Gaza siege">
#      Gaza siege
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/pakistan" target="_self" title="Pakistan">
#      Pakistan
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/opinion" target="_self" title="Opinion">
#      Opinion
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/business" target="_self" title="Business">
#      Business
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/entertainment" target="_self" title="Images">
#      Images
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/prism" target="_self" title="Prism">
#      Prism
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/world" target="_self" title="World">
#      World
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/sport" target="_self" title="Sport">
#      Sport
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/magazines" target="_self" title="Magazines">
#      Magazines
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/tech" target="_self" title="Tech">
#      Tech
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/videos" target="_self" title="Videos">
#      Videos
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/popular" target="_self" title="Popular">
#      Popular
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/newspaper" target="_self" title="Archive">
#      Archive
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="https://www.dawnrelief.com/" target="_self" title="Flood Donations">
#      Flood Donations
#   </a> </div>
# </div>
# <!-- nav sandwich -->
# <div class="flex items-center relative hidden">
# <div class="js-nav-sandwich pt-1 mr-2">
# <button class="text-gray-400 hover:text-gray-500 focus:bg-gray-100 focus:text-gray-500 inline-flex items-center justify-center rounded-md focus:outline-none transition duration-150 ease-in-out">
# <!-- ☰ -->
# <svg class="block h-6 w-6" fill="none" id="navopen" stroke="currentColor" viewbox="0 0 24 24">
# <path d="M4 6h16M4 12h16M4 18h16" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path>
# </svg>
# <!-- X -->
# <svg class="hidden h-6 w-6" fill="none" id="navclose" stroke="currentColor" viewbox="0 0 24 24">
# <path d="M6 18L18 6M6 6l12 12" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path>
# </svg>
# </button>
# </div>
# <!-- nav dropdown -->
# <div class="js-nav-dropdown hidden z-50 absolute top-9 right-0 border border-gray-300 bg-white shadow-2xl text-3 w-40" id="nav-dropdown">
# <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="//www.dawn.com" target="_self" title="Home">
#      Home
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 bg-gray-100 border-b border-gray-900" href="/latest-news" target="_self" title="Latest">
#      Latest
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 text-red-300" href="https://www.dawn.com/breathepakistan/" target="_self" title="Breathe">
#      Breathe
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 text-red-300" href="https://www.dawn.com/trends/gaza-invasion" target="_self" title="Gaza siege">
#      Gaza siege
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/pakistan" target="_self" title="Pakistan">
#      Pakistan
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/opinion" target="_self" title="Opinion">
#      Opinion
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/business" target="_self" title="Business">
#      Business
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/entertainment" target="_self" title="Images">
#      Images
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/prism" target="_self" title="Prism">
#      Prism
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/world" target="_self" title="World">
#      World
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/sport" target="_self" title="Sport">
#      Sport
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/magazines" target="_self" title="Magazines">
#      Magazines
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/tech" target="_self" title="Tech">
#      Tech
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/videos" target="_self" title="Videos">
#      Videos
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/popular" target="_self" title="Popular">
#      Popular
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/newspaper" target="_self" title="Archive">
#      Archive
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="https://www.dawnrelief.com/" target="_self" title="Flood Donations">
#      Flood Donations
#   </a> </div>
# </div>
# <!-- desktop nav search -->
# <div class="js-nav-search justify-end items-center">
# <label class="sr-only" for="search" title="Search">Search</label>
# <div class="relative">
# <form accept-charset="utf-8" action="https://www.dawn.com/search" class="flex items-center" method="GET">
# <div class="cursor-pointer sm:pointer-events-none" onclick="document.querySelector('#js-mob-search').classList.toggle('hidden');">
# <svg class="h-4 w-4 text-gray-400" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M8 4a4 4 0 100 8 4 4 0 000-8zM2 8a6 6 0 1110.89 3.476l4.817 4.817a1 1 0 01-1.414 1.414l-4.816-4.816A6 6 0 012 8z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <input name="cx" type="hidden" value="016184311056644083324:a1i8yd7zymy"/>
# <input name="cof" type="hidden" value="FORID:10"/>
# <input name="ie" type="hidden" value="UTF-8"/>
# <input class="nav-search-input border-0 w-30 text-3 font-extralight ml-0.5 px-2 leading-5 placeholder-gray-400 focus:outline-none search-query hidden sm:block" data-remember="false" id="q" name="q" onblur="javascript:this.classList.remove('w-44');this.classList.remove('md:w-64')" onfocus="javascript:this.classList.add('w-44');this.classList.add('md:w-64')" placeholder="SEARCH" required="" type="text" value=""/>
# </form>
# </div>
# </div>
# </div>
# <!-- mobile nav search -->
# <div class="js-nav-search flex justify-center items-center sm:hidden mt-1">
# <label class="sr-only" for="search" title="Search">Search</label>
# <div class="relative">
# <form accept-charset="utf-8" action="https://www.dawn.com/search" class="flex items-center" method="GET">
# <input name="cx" type="hidden" value="016184311056644083324:a1i8yd7zymy"/>
# <input name="cof" type="hidden" value="FORID:10"/>
# <input name="ie" type="hidden" value="UTF-8"/>
# <input class="hidden text-3 w-64 font-extralight px-2 py-1 leading-none border rounded border-gray-300 mb-1 placeholder-gray-400 focus:outline-none search-query" data-remember="false" id="q" name="q" placeholder="SEARCH" required="" type="text" value=""/>
# </form>
# </div>
# </div>
# </div>
# </nav> </div>
# </div> </header>
# <div class="aux-content flex justify-center" style="overflow: hidden;">
# <!-- advert:start div-gpt-ad-1683363187247-0 -->
# <div class="ad__wrapper__slot px-1 py-2 mb-2" data-height="250px" data-name="Dawn-Responsive-Header-Leaderboard" data-refresh="180" data-rendered-classes="" data-width="970px" id="div-gpt-ad-1683363187247-0">
# <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1683363187247-0'); });</script>
# </div>
# <!-- advert:end -->
# </div>
# <div class="container">
# <div class="flex flex-col sm:flex-row">
# <div class="w-full max-w-screen-md overflow-hidden xl:pr-2">
# <div class="tabs my-2">
# <nav class="flex flex-wrap js-tabs tabs text-2.75 py-2 uppercase font-arial border-b border-gray-200 mb-6">
# <a class="bg-transparent bg-image-none p-1 ml-3 active" href="#all" id="all">all</a>
# <a class="bg-transparent bg-image-none p-1 ml-3" href="#pakistan" id="pakistan">pakistan</a>
# <a class="bg-transparent bg-image-none p-1 ml-3" href="#business" id="business">business</a>
# <a class="bg-transparent bg-image-none p-1 ml-3" href="#world" id="world">world</a>
# <a class="bg-transparent bg-image-none p-1 ml-3" href="#sport" id="sport">sport</a>
# </nav>
# <div class="flex flex-col sm:flex-row">
# <div class="sm:w-5/6 w-full mx-auto">
# <div class="tabs__content px-0">
# <div class="tabs__pane active" id="all">
# <article class="story relative overflow-hidden box pb-2 mb-5 sm:mb-4 border-b sm:border-none" data-id="1877696" data-layout="story" data-tags="" id="1877696"> <div class="flex flex-col sm:flex-row">
# <div class="sm:w-1/3 w-full">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1877696/may-9-riots-sc-constitutional-bench-rejects-govt-plea-allowing-military-courts-to-announce-verdicts" target="_self" title="May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts"><picture><img alt="May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts" class="lazyload" data-src="https://i.dawn.com/medium/2024/12/09162611d74d081.png?r=164304" src="..." title="May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts"/></picture></a></div>
# </figure>
# </div>
# <div class="sm:w-2/3 w-full sm:ml-6 sm:border-b border-gray-200">
# <!-- box/title title-bold-p:sm:2-px:0-playfairdisplay -->
# <h2 class="story__title font-bold font-playfair-display font-serif text-5 pt-1 sm:pt-0 pb-2 leading-6 font-bold overflow-hidden hover:text-red-400 sm:p-2 px-0" data-id="1877696" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877696/may-9-riots-sc-constitutional-bench-rejects-govt-plea-allowing-military-courts-to-announce-verdicts">May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts</a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt font-georgia text-3.5 text-gray-700 overflow-hidden pb-1 px-0 sm:px-2 mt-0" dir="auto">Also rejects former chief justice of Pakistan Jawwad Khawaja's petition to stay proceedings in intra-court appeals.
#
#     </div>
# <!-- box/date --><span class="story__time text-2.5 text-gray-500 uppercase font-arial font-arial text-2.5 text-gray-500 uppercase overflow-hidden p-0 sm:p-2"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2024-12-09T17:46:28+05:00"><span class="timestamp__calendar">09 Dec, 2024</span> <span class="timestamp__time">05:46pm</span></span></span> </div>
# </div>
# </article><article class="story relative overflow-hidden box pb-2 mb-5 sm:mb-4 border-b sm:border-none" data-id="1877700" data-layout="story" data-tags="" id="1877700"> <div class="flex flex-col sm:flex-row">
# <div class="sm:w-1/3 w-full">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1877700/kp-supervisory-committee-formed-to-restore-law-and-order-in-kurram" target="_self" title="KP supervisory committee formed to restore law and order in Kurram"><picture><img alt="KP supervisory committee formed to restore law and order in Kurram" class="lazyload" data-src="https://i.dawn.com/medium/2024/12/0917284143aa3dd.jpg?r=172901" src="..." title="KP supervisory committee formed to restore law and order in Kurram"/></picture></a></div>
# </figure>
# </div>
# <div class="sm:w-2/3 w-full sm:ml-6 sm:border-b border-gray-200">
# <!-- box/title title-bold-p:sm:2-px:0-playfairdisplay -->
# <h2 class="story__title font-bold font-playfair-display font-serif text-5 pt-1 sm:pt-0 pb-2 leading-6 font-bold overflow-hidden hover:text-red-400 sm:p-2 px-0" data-id="1877700" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877700/kp-supervisory-committee-formed-to-restore-law-and-order-in-kurram">KP supervisory committee formed to restore law and order in Kurram</a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt font-georgia text-3.5 text-gray-700 overflow-hidden pb-1 px-0 sm:px-2 mt-0" dir="auto">Committee to be headed by Barrister Muhammad Ali Saif.
#
#     </div>
# <!-- box/date --><span class="story__time text-2.5 text-gray-500 uppercase font-arial font-arial text-2.5 text-gray-500 uppercase overflow-hidden p-0 sm:p-2"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2024-12-09T17:40:41+05:00"><span class="timestamp__calendar">09 Dec, 2024</span> <span class="timestamp__time">05:40pm</span></span></span> </div>
# </div>
# </article><article class="story relative overflow-hidden box pb-2 mb-5 sm:mb-4 border-b sm:border-none" data-id="1877697" data-layout="story" data-tags="" id="1877697"> <div class="flex flex-col sm:flex-row">
# <div class="sm:w-1/3 w-full">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1877697/alexandrine-parrots-disappearing-from-pakistans-skies" target="_self" title="Alexandrine parrots disappearing from Pakistan’s skies"><picture><img alt="Alexandrine parrots disappearing from Pakistan’s skies" class="lazyload" data-src="https://i.dawn.com/medium/2024/12/0917110335470bb.jpg?r=171202" src="..." title="Alexandrine parrots disappearing from Pakistan’s skies"/></picture></a></div>
# </figure>
# </div>
# <div class="sm:w-2/3 w-full sm:ml-6 sm:border-b border-gray-200">
# <!-- box/title title-bold-p:sm:2-px:0-playfairdisplay -->
# <h2 class="story__title font-bold font-playfair-display font-serif text-5 pt-1 sm:pt-0 pb-2 leading-6 font-bold overflow-hidden hover:text-red-400 sm:p-2 px-0" data-id="1877697" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877697/alexandrine-parrots-disappearing-from-pakistans-skies">Alexandrine parrots disappearing from Pakistan’s skies</a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt font-georgia text-3.5 text-gray-700 overflow-hidden pb-1 px-0 sm:px-2 mt-0" dir="auto">Wildlife experts cite habitat alteration, pollution, poaching and illegal trade as major factors behind the decline.
#
#     </div>
# <!-- box/date --><span class="story__time text-2.5 text-gray-500 uppercase font-arial font-arial text-2.5 text-gray-500 uppercase overflow-hidden p-0 sm:p-2"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2024-12-09T18:16:30+05:00"><span class="timestamp__calendar">09 Dec, 2024</span> <span class="timestamp__time">06:16pm</span></span></span> </div>
# </div>
# </article><article class="story relative overflow-hidden box pb-2 mb-5 sm:mb-4 border-b sm:border-none" data-id="1877689" data-layout="story" data-tags="" id="1877689"> <div class="flex flex-col sm:flex-row">
# <div class="sm:w-1/3 w-full">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1877689/pakistan-ranked-among-lowest-12pc-globally-in-mobile-broadband-internet-speeds-in-oct-report" target="_self" title="Pakistan ranked among lowest 12pc globally in mobile, broadband internet speeds in Oct: report"><picture><img alt="Pakistan ranked among lowest 12pc globally in mobile, broadband internet speeds in Oct: report" class="lazyload" data-src="https://i.dawn.com/medium/2024/12/09151441b85db9a.png?r=151454" src="..." title="Pakistan ranked among lowest 12pc globally in mobile, broadband internet speeds in Oct: report"/></picture></a></div>
# </figure>
# </div>
# <div class="sm:w-2/3 w-full sm:ml-6 sm:border-b border-gray-200">
# <!-- box/title title-bold-p:sm:2-px:0-playfairdisplay -->
# <h2 class="story__title font-bold font-playfair-display font-serif text-5 pt-1 sm:pt-0 pb-2 leading-6 font-bold overflow-hidden hover:text-red-400 sm:p-2 px-0" data-id="1877689" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1
m</span></span></span> </div>
# </div>
# </article><article class="story relative overflow-hidden box pb-2 mb-5 sm:mb-4 border-b sm:border-none" data-id="1877677" data-layout="story" data-tags="" id="1877677"> <div class="flex flex-col sm:flex-row">
# <div class="sm:w-1/3 w-full">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1877677/dozens-of-schools-in-delhi-get-bomb-threats-report" target="_self" title="Dozens of schools in Delhi get bomb threats: report"><picture><img alt="Dozens of schools in Delhi get bomb threats: report" class="lazyload" data-src="https://i.dawn.com/medium/2024/12/09130825781b83e.jpg?r=130842" src="..." title="Dozens of schools in Delhi get bomb threats: report"/></picture></a></div>
# </figure>
# </div>
# <div class="sm:w-2/3 w-full sm:ml-6 sm:border-b border-gray-200">
# <!-- box/title title-bold-p:sm:2-px:0-playfairdisplay -->
# <h2 class="story__title font-bold font-playfair-display font-serif text-5 pt-1 sm:pt-0 pb-2 leading-6 font-bold overflow-hidden hover:text-red-400 sm:p-2 px-0" data-id="1877677" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877677/dozens-of-schools-in-delhi-get-bomb-threats-report">Dozens of schools in Delhi get bomb threats: report</a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt font-georgia text-3.5 text-gray-700 overflow-hidden pb-1 px-0 sm:px-2 mt-0" dir="auto">At least 40 schools receive email threatening multiple bombs would be detonated if sender not paid $30,000.
#
#     </div>
# <!-- box/date --><span class="story__time text-2.5 text-gray-500 uppercase font-arial font-arial text-2.5 text-gray-500 uppercase overflow-hidden p-0 sm:p-2"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2024-12-09T13:16:21+05:00"><span class="timestamp__calendar">09 Dec, 2024</span> <span class="timestamp__time">01:16pm</span></span></span> </div>
# </div>
# </article><article class="story relative overflow-hidden box pb-2 mb-5 sm:mb-4 border-b sm:border-none" data-id="1877675" data-layout="story" data-tags="" id="1877675"> <div class="flex flex-col sm:flex-row">
# <div class="sm:w-1/3 w-full">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1877617" target="_self" title="Damascus, in truth, has fallen and is also free"><picture><img alt="Damascus, in truth, has fallen and is also free" class="lazyload" data-src="https://i.dawn.com/medium/2024/12/09142543b10728e.jpg?r=142555" src="..." title="Damascus, in truth, has fallen and is also free"/></picture></a></div>
# </figure>
# </div>
# <div class="sm:w-2/3 w-full sm:ml-6 sm:border-b border-gray-200">
# <!-- box/title title-bold-p:sm:2-px:0-playfairdisplay -->
# <h2 class="story__title font-bold font-playfair-display font-serif text-5 pt-1 sm:pt-0 pb-2 leading-6 font-bold overflow-hidden hover:text-red-400 sm:p-2 px-0" data-id="1877675" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877617">Damascus, in truth, has fallen and is also free</a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt font-georgia text-3.5 text-gray-700 overflow-hidden pb-1 px-0 sm:px-2 mt-0" dir="auto">As metropolis of resistance to US dominance, Damascus has fallen. Yet, given the brutal minority rule of Assad regimes, it is indeed free — for the moment.
#
#     </div>
# <!-- box/date --><span class="story__time text-2.5 text-gray-500 uppercase font-arial font-arial text-2.5 text-gray-500 uppercase overflow-hidden p-0 sm:p-2"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2024-12-09T12:39:47+05:00"><span class="timestamp__calendar">09 Dec, 2024</span> <span class="timestamp__time">12:39pm</span></span></span> </div>
# </div>
# </article>
# <article class="story relative overflow-hidden box pb-2 mb-5 sm:mb-4 border-b sm:border-none" data-id="1877671" data-layout="story" data-tags="" id="1877671"> <div class="flex flex-col sm:flex-row">
# <div class="sm:w-1/3 w-full">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1877515" target="_self" title="Despite commercial activity picking up, business sentiment reportedly remains subdued"><picture><img alt="Despite commercial activity picking up, business sentiment reportedly remains subdued" class="lazyload" data-src="https://i.dawn.com/medium/2024/12/091218164ba59cb.gif?r=121823" src="..." title="Despite commercial activity picking up, business sentiment reportedly remains subdued"/></picture></a></div>
# </figure>
# </div>
# <div class="sm:w-2/3 w-full sm:ml-6 sm:border-b border-gray-200">
# <!-- box/title title-bold-p:sm:2-px:0-playfairdisplay -->
# <h2 class="story__title font-bold font-playfair-display font-serif text-5 pt-1 sm:pt-0 pb-2 leading-6 font-bold overflow-hidden hover:text-red-400 sm:p-2 px-0" data-id="1877671" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877515">Despite commercial activity picking up, business sentiment reportedly remains subdued</a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt font-georgia text-3.5 text-gray-700 overflow-hidden pb-1 px-0 sm:px-2 mt-0" dir="auto">Renegotiation of IPP contracts has been viewed by some as being in the same league as freezing foreign currency accounts in the 1990s and the nationalisation drive of the 1970s.
#
#     </div>
# <!-- box/date --><span class="story__time text-2.5 text-gray-500 uppercase font-arial font-arial text-2.5 text-gray-500 uppercase overflow-hidden p-0 sm:p-2"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2024-12-09T12:49:25+05:00"><span class="timestamp__calendar">09 Dec, 2024</span> <span class="timestamp__time">12:49pm</span></span></span> </div>
# </div>
# </article><article class="story relative overflow-hidden box pb-2 mb-5 sm:mb-4 border-b sm:border-none" data-id="1877670" data-layout="story" data-tags="" id="1877670"> <div class="flex flex-col sm:flex-row">
# <div class="sm:w-1/3 w-full">
# <!-- box/image -->
# <figure class="media sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://images.dawn.com/news/1193047/fawad-khan-vaani-kapoor-wrap-up-abir-gulaal-shoot-in-london-filmfare" target="_self" title="Fawad Khan, Vaani Kapoor wrap up Abir Gulaal shoot in London: Filmfare"><picture><img alt="Fawad Khan, Vaani Kapoor wrap up Abir Gulaal shoot in London: Filmfare" class="lazyload" data-src="https://i.dawn.com/medium/2024/12/0912123877d434e.jpg?r=121249" src="..." title="Fawad Khan, Vaani Kapoor wrap up Abir Gulaal shoot in London: Filmfare"/></picture></a></div>
# </figure>
# </div>
# <div class="sm:w-2/3 w-full sm:ml-6 sm:border-b border-gray-200">
# <!-- box/title title-bold-p:sm:2-px:0-playfairdisplay -->
# ...
# <!-- box/excerpt -->
# <div class="story__excerpt text-2.75 text-gray-600 tracking-wide leading-normal hidden" dir="auto">Every year, it becomes harder to practise journalism in Pakistan.
#
#     </div>
# </article>
# <!-- - - - /article - - - --> </div>
# </div>
# <div class="flex flex-row pt-1 pb-2">
# <div class="w-1/10 text-3.5 font-bold">
#                     4.
#                 </div>
# <div class="w-9/10 -ml-1.5 text-3.5 font-bold">
# <!-- box/byline --><span class="story__byline font-bold text-3.5 font-playfair-display mb-1 inline-block" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/6285/aisha-khan">Aisha Khan</a></span>
# <!-- - - - article - - - -->
# <article class="story relative overflow-hidden box font-bold font-merriweather" data-id="1877442" data-layout="story" data-tags="" id="1877442">
# <!-- box/title text:3 -->
# <h2 class="story__title text-3 leading-tight font-normal" data-id="1877442" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877442/strategic-dilemma">Strategic dilemma
# </a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt text-2.75 text-gray-600 tracking-wide leading-normal hidden" dir="auto">What began in Paris with hope ended in despair at Baku.
#
#     </div>
# </article>
# <!-- - - - /article - - - --> </div>
# </div>
# <div class="flex flex-row pt-1 pb-2">
# <div class="w-1/10 text-3.5 font-bold">
#                     5.
#                 </div>
# <div class="w-9/10 -ml-1.5 text-3.5 font-bold">
# <!-- box/byline --><span class="story__byline font-bold text-3.5 font-playfair-display mb-1 inline-block" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/6442/shahid-mehmood">Shahid Mehmood</a></span>
# <!-- - - - article - - - -->
# <article class="story relative overflow-hidden box font-bold font-merriweather" data-id="1877257" data-layout="story" data-tags="" id="1877257">
# <!-- box/title text:3 -->
# <h2 class="story__title text-3 leading-tight font-normal" data-id="1877257" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877257/milei-argentina-and-pakistan">Milei, Argentina and Pakistan
# </a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt text-2.75 text-gray-600 tracking-wide leading-normal hidden" dir="auto">Some in Pakistan have called for a Milei-like figure as an antidote to this country’s persistent economic malaise.
#
#     </div>
# </article>
# <!-- - - - /article - - - --> </div>
# </div>
# <div class="flex flex-row pt-1 pb-2">
# <div class="w-1/10 text-3.5 font-bold">
#                     6.
#                 </div>
# <div class="w-9/10 -ml-1.5 text-3.5 font-bold">
# <!-- box/byline --><span class="story__byline font-bold text-3.5 font-playfair-display mb-1 inline-block" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/9945/nazir-a-jogezai">Nazir A. Jogezai</a></span>
# <!-- - - - article - - - -->
# <article class="story relative overflow-hidden box font-bold font-merriweather" data-id="1877254" data-layout="story" data-tags="" id="1877254">
# <!-- box/title text:3 -->
# <h2 class="story__title text-3 leading-tight font-normal" data-id="1877254" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877254/extra-burden">Extra burden
# </a></h2>
# <!-- box/excerpt -->
# <div class="story__excerpt text-2.75 text-gray-600 tracking-wide leading-normal hidden" dir="auto">Heavy schoolbags can have a debilitating impact.
#
#     </div>
# </article>
# <!-- - - - /article - - - --> </div>
# </div>
# </div>
# </div>
# </aside> </div>
# </div><footer>
# <div class="flex justify-center p-2">
# <!-- advert:start div-gpt-ad-1693559286339-0 -->
# <div class="ad__wrapper__slot" data-height="250px" data-name="Dawn-Responsive-Footer-Stickable-Leaderboard" data-rendered-classes="" data-width="970px" id="div-gpt-ad-1693559286339-0">
# <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1693559286339-0'); });</script>
# </div>
# <!-- advert:end -->
# </div>
# <div class="w-full bg-black">
# <div class="py-4">
# <div class="container px-2">
# <div class="flex flex-row border-b-2 border-white mb-2 pb-2 justify-between items-center">
# <nav class="order-first">
# <a class="logo" href="https://www.dawn.com/" title="DAWN.COM">
# <img alt="DAWN.COM Logo" class="w-20" src="https://www.dawn.com/_img/logo-white.png"/>
# <span class="hidden">DAWN.COM</span>
# </a> <p class="hidden"> Compunode.com Pvt. Ltd. (<a class="px-0 sm:px-1 font-normal" href="https://www.compunode.com/">www.compunode.com</a>).Designed for <a class="px-0 sm:px-1 font-normal" href="https://www.dawn.com">Dawn</a>.</p>
# </nav>
# <nav class="nav flex mt-2 sm:mt-0 items-end order-last">
# <a class="outline-none" href="https://whatsapp.com/channel/0029VaMc238IiRov8okfYy3n"><img alt="Whatsapp" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2024/02/080925032506f93.png"/></a>
# <a class="outline-none" href="https://twitter.com/dawn_com"><img alt="Twitter" class="align-baseline mt-1 mr-2" src="https://i.dawn.com/large/2024/02/16125537351049d.png" style="height:17px"/></a>
# <a class="outline-none" href="https://www.facebook.com/dawndotcom"><img alt="Facebook" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c42cf5e8.png" width="20"/></a>
# <a class="outline-none" href="https://www.instagram.com/dawn.today/"><img alt="Instagram" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c430f9b2.png" width="20"/></a>
# <a class="outline-none" href="https://itunes.apple.com/pk/app/dawn-official-mobile-app/id935631940"><img alt="Apple" class="align-baseline mt-1 mr-2" height="34" src="https://i.dawn.com/thumbnail/2019/02/5c611c42d5669.png" width="20"/></a>
# <a class="outline-none" href="https://play.google.com/store/apps/details?id=com.mictronicx.dawn"><img alt="Android" class="align-baseline mt-1 mr-2" height="34" src="https://i.dawn.com/thumbnail/2019/02/5c611c42ce48d.png" width="20"/></a>
# <a class="outline-none" href="https://appgallery.huawei.com/#/app/C104007373"><img alt="Huwaei App Gallery" class="align-baseline mt-1" height="30" src="https://i.dawn.com/thumbnail/2021/05/60a360ab86d68.png" width="100"/></a>
# </nav>
# </div>
# <div class="grid grid-cols-2 sm:flex sm:flex-row">
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/contact">Contact</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/terms">Terms of Use</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/reproduction-copyrights">Reproduction Copyrights</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/contribution-guidelines">Contribution Guidelines</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/privacy">Privacy</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/comments-policy">Comment Moderation</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/code-of-ethics">Code of Ethics</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/subscription">Subscribe to Newspaper</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/marketing">Advertise on Dawn.com</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/sponsor-content">Sponsored Content</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://classifieds.dawn.com">Classifieds</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://obituary.dawn.com">Obituaries</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/prayers-timings">Prayer Timings</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/stocks">Stock/Forex/Gold</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/weather">Weather</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/">Dawn</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://herald.dawn.com">Herald</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://aurora.dawn.com">Aurora</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/prism">Prism</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/special-reports">Special Reports</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://www.dawnnews.tv/">Dawn News</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://images.dawn.com">Images</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/magazines">Eos/Icon/Young World</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://cityfm89.com">Cityfm89</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://www.youtube.com/channel/UCkMdI0K-74jAjOmh5J5H97Q">Teeli</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <p class="font-normal text-white text-left md:text-right mb-2">Copyright © 2024, Dawn</p>
# <p class="font-normal text-white text-left md:text-right">NewsKit Publishing Platform</p>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </div>
# <link href="https://www.dawn.com/_css/headroom.20241114121409.css" media="all" rel="stylesheet"/>
# <!-- - - - - start:ga-events - - - - -->
# <script type="text/javascript">
#
#     function sendInteractiveEvent(category, label) {
#         gtag("event", "custom_click", {
#             'event_category': category,
#             'event_action': "click",
#             'event_label': label
#         });
#     }
#
#     var eventItems = [{"selector":".latest-news #all","parent":"latest-all"},{"selector":".latest-news #pakistan","parent":"latest-pakistan"},{"selector":".latest-news #business","parent":"latest-business"},{"selector":".latest-news #world","parent":"latest-world"},{"selector":".latest-news #sport","parent":"latest-sport"}] || [];
#     document.querySelector("html").addEventListener("click", function(e) {
#         // https://github.com/aleemb/dawn.com/issues/1165
#         if (window.Element && Element.prototype.closest) {
#             var target = e.target;
#             var eventLabel =
#                 typeof target.href !== "undefined" &&
#                 !target.href.startsWith("javascript:")
#                     ? target.href
#                     : document.location.href;
#
#             for (i = 0; i < eventItems.length; i++) {
#                 if (target.matches(eventItems[i].selector + ', ' + eventItems[i].selector + ' *')) {
#                     sendInteractiveEvent(eventItems[i].parent, eventLabel);
#                     break;
#                 }
#             }
#         }
#     });
#
#     for (i = 0; i < eventItems.length; i++) {
#         if (eventItems[i].parent == 'audio') {
#             const audioPlayer = document.getElementById(eventItems[i].selector);
#             audioPlayer.addEventListener("play", (e) => sendInteractiveEvent('audio', e.type), false);
#             audioPlayer.addEventListener("pause", (e) => sendInteractiveEvent('audio', e.type), false);
#             audioPlayer.addEventListener("ended", (e) => sendInteractiveEvent('audio', e.type), false);
#         }
#     }
#     </script>
# <!-- - - - - end:ga-events - - - - -->
# <!-- - - - - start:onesignal - - - - -->
# <script async="async" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#             var OneSignal = window.OneSignal || [];
#             OneSignal.push(["init", {
#                 appId: "da41085a-a849-47c0-96e7-4b956b56f35e",
#                 /* Set to true to automatically prompt visitors */
#                 autoRegister: true,
#
#                 // https://documentation.onesignal.com/docs/customize-permission-messages-1
#                 notifyButton: {
#                     text: {
#                         'tip.state.unsubscribed': 'Subscribe to notifications',
#                         'tip.state.subscribed': "You're subscribed to notifications",
#                         'tip.state.blocked': "You've blocked notifications",
#                         'message.prenotify': 'Click to subscribe to notifications',
#                         'message.action.subscribed': "Thanks for subscribing!",
#                         'message.action.resubscribed': "You're subscribed to notifications",
#                         'message.action.unsubscribed': "You won't receive notifications again",
#                         'dialog.main.title': 'Manage Site Notifications',
#                         'dialog.main.button.subscribe': 'SUBSCRIBE',
#                         'dialog.main.button.unsubscribe': 'UNSUBSCRIBE',
#                         'dialog.blocked.title': 'Unblock Notifications',
#                         'dialog.blocked.message': "Follow these instructions to allow notifications:"
#                     },
#                     /* Set to false to hide */
#                     enable: false
#                 },
#
#                 prenotify: true,
#                 persistNotification: false,
#                 showCredit: false,
#                 // Your other init options here
#                 promptOptions: {
#                     /* Change bold title, limited to 30 characters */
#                     siteName: "Dawn.Com",
#                     /* Subtitle, limited to 90 characters */
#                     actionMessage: "We'd like to show you notifications for the latest news and updates.",
#                     /* Example notification title */
#                     exampleNotificationTitle: 'Subscribe for news updates',
#                     /* Example notification message */
#                     exampleNotificationMessage: "",
#                     /* Text below example notification, limited to 50 characters */
#                     exampleNotificationCaption: 'You can unsubscribe anytime',
#                     /* Accept button text, limited to 15 characters */
#                     acceptButtonText: "ALLOW",
#                     /* Cancel button text, limited to 15 characters */
#                     cancelButtonText: "NO THANKS"
#                 }
#             }]);
#             // OneSignal.setSubscription(true);
#             OneSignal.push(function() {
#                 // forcefully popup for notification subscription
#                 // OneSignal.registerForPushNotifications();
#                 // for debugging
#                 // OneSignal.log.setLevel('trace');
#                 /*OneSignal.isPushNotificationsEnabled(function(isEnabled) {
#                     if (isEnabled) {
#                       console.log("Push notifications are enabled!");
#                     }
#                     else {
#                       console.log("Push notifications are not enabled yet.");
#                     }
#                 });*/
#             });
#             </script>
# <!-- - - - - end:onesignal - - - - --></footer>
# </body>
# </html>

# %% [markdown]
# ### Find all links with class "s1Q9rs" on the search results page

# %%
links = soup.find_all("a",class_="story__link")

# %% [markdown]
# ### Print the list of links

# %%
links
# Out:
# [<a class="story__link" href="https://www.dawn.com/news/1877696/may-9-riots-sc-constitutional-bench-rejects-govt-plea-allowing-military-courts-to-announce-verdicts">May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877700/kp-supervisory-committee-formed-to-restore-law-and-order-in-kurram">KP supervisory committee formed to restore law and order in Kurram</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877697/alexandrine-parrots-disappearing-from-pakistans-skies">Alexandrine parrots disappearing from Pakistan’s skies</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877689/pakistan-ranked-among-lowest-12pc-globally-in-mobile-broadband-internet-speeds-in-oct-report">Pakistan ranked among lowest 12pc globally in mobile, broadband internet speeds in Oct: report</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877688/extreme-heat-endangers-garment-factory-workers-in-pakistan-and-beyond-study">Extreme heat endangers garment factory workers in Pakistan and beyond: study</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877685/sc-suspends-ecp-decision-to-disqualify-pml-n-lawmaker-adil-bazai">SC suspends ECP decision to disqualify PML-N lawmaker Adil Bazai</a>,
#  <a class="story__link" href="https://aurora.dawn.com/news/1145250">How long will it take for Pakistani businesses to become ESG compliant?</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877679/south-korea-president-yoon-banned-from-foreign-travel-as-leadership-crisis-deepens">South Korea President Yoon banned from foreign travel as leadership crisis deepens</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877677/dozens-of-schools-in-delhi-get-bomb-threats-report">Dozens of schools in Delhi get bomb threats: report</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877617">Damascus, in truth, has fallen and is also free</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877515">Despite commercial activity picking up, business sentiment reportedly remains subdued</a>,
#  <a class="story__link" href="https://images.dawn.com/news/1193047/fawad-khan-vaani-kapoor-wrap-up-abir-gulaal-shoot-in-london-filmfare">Fawad Khan, Vaani Kapoor wrap up Abir Gulaal shoot in London: Filmfare</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877643">By addressing systemic issues, Pakistan can break free from cycle of economic stagnation, move towards sustainable development</a>,
#  <a class="story__link" href="https://images.dawn.com/news/1193048/palestinian-journalists-motaz-azaiza-wael-al-dahdouh-honoured-at-doha-forum">Palestinian journalists Motaz Azaiza, Wael al-Dahdouh honoured at Doha Forum</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877513">Uninterrupted connectivity crucial to maintain IT exports’ growth rate: former P@sha chairman</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877665/kse-100-nears-110000-point-mark-as-shares-at-psx-trade-in-green-for-9th-consecutive-session">KSE-100 nears 110,000-point mark as shares at PSX trade in green for 9th consecutive session</a>,
#  <a class="story__link" href="https://images.dawn.com/news/1193046/michael-douglas-talks-about-emerging-from-the-shadow-of-a-famous-father">Michael Douglas talks about emerging from the shadow of a famous father</a>,
#  <a class="story__link" href="https://images.dawn.com/news/1193045/rapper-jay-z-accused-in-lawsuit-of-raping-13-year-old-girl">Rapper Jay-Z accused in lawsuit of raping 13-year-old girl</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877600">Roots of our instability lie in fairly consistent institutional and economic problems</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877656/syria-transition-must-ensure-accountability-for-past-crimes-un">Syria transition must ensure ‘accountability’ for past crimes: UN</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877599">Pakistan’s prospects of political stability are clouded by increasing autocratisation</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877603">Editorial: CPEC slowdown doesn’t mean China has lost interest in the connectivity project or in Pakistan</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1
a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877099/bushra-bibi-resurfaces-after-pti-protest-says-she-did-not-run-away">Bushra Bibi resurfaces after PTI protest, says she ‘did not run away’</a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877064/cartoon-6-december-2024">Cartoon: 6 December, 2024
#  </a>,
#  <a class="story__link" href="https://www.dawn.com/news/1876926/army-wants-action-against-those-behind-disinfo-on-protesters-deaths">Army wants action against those behind ‘disinfo’ on protesters’ deaths
#  </a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877260/threat-perception">Threat perception
#  </a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877443/rethinking-afghan-policy">Rethinking Afghan policy
#  </a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877444/gaza-genocide-degraded-axis">Gaza genocide, degraded Axis
#  </a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877441/free-the-press">Free the press
#  </a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877442/strategic-dilemma">Strategic dilemma
#  </a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877257/milei-argentina-and-pakistan">Milei, Argentina and Pakistan
#  </a>,
#  <a class="story__link" href="https://www.dawn.com/news/1877254/extra-burden">Extra burden
#  </a>]

# %% [markdown]
# ### Get the first link from the list

# %%
links[0]
# Out:
# <a class="story__link" href="https://www.dawn.com/news/1877696/may-9-riots-sc-constitutional-bench-rejects-govt-plea-allowing-military-courts-to-announce-verdicts">May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts</a>

# %% [markdown]
# ### Extract the href attribute from the first link to get the News URL

# %%
link = links[0].get("href")

# %% [markdown]
# ### Print the extracted News URL

# %%
link
# Out:
# 'https://www.dawn.com/news/1877696/may-9-riots-sc-constitutional-bench-rejects-govt-plea-allowing-military-courts-to-announce-verdicts'

# %% [markdown]
# ### Construct the full News URL by appending it to the base URL

# %%
News_url =  link

# %% [markdown]
# ### Print the full News URL

# %%
News_url
# Out:
# 'https://www.dawn.com/news/1877696/may-9-riots-sc-constitutional-bench-rejects-govt-plea-allowing-military-courts-to-announce-verdicts'

# %% [markdown]
# ### Send a new HTTP GET request to the News URL

# %%
new_response = requests.get(News_url,headers=HEADERS)

# %% [markdown]
# ### Print the new HTTP response object

# %%
new_response
# Out:
# <Response [200]>

# %% [markdown]
# ### Parse the HTML content of the News page using BeautifulSoup

# %%
new_soup = BeautifulSoup(new_response.content,"html.parser")

# %%
new_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- meta -->
# <meta charset="utf-8"/>
# <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
# <!--[if IE]> <meta http-equiv="X-UA-Compatible" content="IE=edge" /> <![endif]-->
# <title>Extreme heat endangers garment factory workers in Pakistan and beyond: study - World - DAWN.COM</title>
# <meta content="Your window to latest news, analysis and features from Pakistan, South Asia and the world." name="subject">
# <meta content="International Labor Organisation recommends as much rest as work in any given hour to maintain safe core body temperature levels." name="description">
# <meta content="1383068068604634" property="fb:app_id"/>
# <meta content="en_US" property="og:locale"/>
# <link href="https://www.dawn.com/news/1877688" rel="canonical"/>
# <link href="https://www.dawn.com/news/amp/1877688" rel="amphtml"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@dawn_com" name="twitter:site"/>
# <meta content="https://www.dawn.com/news/1877688" name="twitter:url"/>
# <meta content="Extreme heat endangers garment factory workers in Pakistan and beyond: study" name="twitter:title"/>
# <meta content="International Labor Organisation recommends as much rest as work in any given hour to maintain safe core body temperature levels." name="twitter:description"/>
# <meta content="DAWN.COM" property="og:site_name"/>
# <meta content="https://www.dawn.com/news/1877688" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="Extreme heat endangers garment factory workers in Pakistan and beyond: study" property="og:title"/>
# <meta content="International Labor Organisation recommends as much rest as work in any given hour to maintain safe core body temperature levels." property="og:description"/>
# <meta content="Extreme heat endangers garment factory workers in Pakistan and beyond: study" itemprop="title"/>
# <meta content="International Labor Organisation recommends as much rest as work in any given hour to maintain safe core body temperature levels." itemprop="description"/>
# <meta content="International Labor Organisation recommends as much rest as work in any given hour to maintain safe core body temperature levels." name="description"/>
# <meta content="https://i.dawn.com/large/2024/12/09145050954501e.png?r=145127" property="twitter:image"/>
# <meta content="https://i.dawn.com/large/2024/12/09145050954501e.png?r=145127" property="og:image"/>
# <meta content="https://i.dawn.com/large/2024/12/09145050954501e.png?r=145127" itemprop="image"/>
# <meta content="world" itemprop="articleSection" property="article:section"/>
# <meta content="https://www.dawn.com" property="article:publisher"/>
# <meta content="2024-12-09 15:11:20+05:00" property="article:published_time"/>
# <meta content="2024-12-09 15:11:20+05:00" property="article:modified_time"/>
# <meta content="Climate Change" property="article:tag"/>
# <meta content="Climate Change" name="keywords"/>
# <meta content="Climate Change" name="news_keywords"/>
# <meta content="https://www.dawn.com/authors/422/reuters" property="article:author"/>
# <meta content="Reuters" name="author"/>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-C521GRS8DF"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         window.googletag = window.googletag || {cmd: []};
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#         gtag('config', 'G-C521GRS8DF');
#     </script>
# <script>
#         gtag('event', 'custom', {
#             "Category": "World","Author": "Reuters-422","Authors": "Reuters-422","Tag": "Climate Change","Id": "news/1877688","PublishedDate": "2024-12-09 15:11:20","UpdatedDate": "2024-12-09 15:11:20","ArticleAge": "15 minutes","ArticleType": "Default","wordCount": "403",
#             "non_interaction": true
#         });
#     </script>
# <script type="application/ld+json">
#     {"@context":"http:\/\/schema.org","@type":"organization","logo":"https:\/\/www.dawn.com\/_img\/logo.png","name":"DAWN.COM","url":"https:\/\/www.dawn.com","sameAs":["https:\/\/www.facebook.com\/dawndotcom\/","https:\/\/twitter.com\/dawn_com","https:\/\/www.instagram.com\/dawn.today\/",""],"potentialAction":{"@type":"SearchAction","target":"https:\/\/www.dawn.com\/search?cx=016184311056644083324:a1i8yd7zymy&ie=UTF-8&q={search_term_string}","query-input":"required name=search_term_string"}}
# </script>
# <script type="application/ld+json">
#     {"@context": "http://schema.org", "@type": "BreadcrumbList","itemListElement": [{"@type":"ListItem","position":1,"item":{"@id":"https:\/\/www.dawn.com\/world","name":"World"}}]}
# </script> <script type="application/ld+json">
#         {"@context":"http:\/\/schema.org","@type":"NewsArticle","url":"https:\/\/www.dawn.com","publisher":{"@context":"http:\/\/schema.org","@type":"Organization","name":"DAWN.COM","url":"https:\/\/www.dawn.com","sameAs":["https:\/\/www.facebook.com\/dawndotcom\/","https:\/\/twitter.com\/dawn_com","https:\/\/www.instagram.com\/dawn.today\/",""],"logo":{"@context":"http:\/\/schema.org","@type":"ImageObject","url":"https:\/\/www.dawn.com\/_img\/logo.png"}},"copyrightYear":"2024","image":[{"@context":"http:\/\/schema.org","@type":"ImageObject","url":"https:\/\/i.dawn.com\/primary\/2024\/12\/09145050954501e.png?r=145127","width":"800","height":"480","caption":"AFP\/File Photo"}],"datePublished":"2024-12-09T15:11:20+05:00","dateModified":"2024-12-09T15:11:20+05:00","mainEntityOfPage":"https:\/\/www.dawn.com\/news\/1877688","headline":"Extreme heat endangers garment factory workers in Pakistan and beyond: study","description":"International Labor Organisation recommends as much rest as work in any given hour to maintain safe core body temperature levels.","author":[{"@context":"http:\/\/schema.org","@type":"Person","name":"Reuters","url":"https:\/\/www.dawn.com\/authors\/422\/reuters"}]}
#     </script>
# <!-- - - - - start:counters - - - - -->
# <script type="text/javascript">
#     document.addEventListener("DOMContentLoaded", function() {
#         Counter.count([{"news":"1877688"},{"parent":"World"},{"parent":"Home"},{"tag":"climate-change"},{"author":"422"},{"editor":"10721"}]);
#     });
#     </script>
# <!-- - - - - end:counters - - - - -->
# <link href="https://fonts.googleapis.com/css?family=Playfair+Display:400,400i,700,700i,900&amp;display=swap" media="all" rel="stylesheet"/>
# <link href="https://www.dawn.com/_css/print.20241015121807.css" media="print" rel="stylesheet"/>
# <link href="https://www.dawn.com/_css/newskit.20241118133706.css" media="all" rel="stylesheet"/>
# <link href="https://www.dawn.com/_css/merriweather.20241015121807.css" media="all" rel="stylesheet"/>
# <link href="https://www.dawn.com/_css/shame.20241206112808.css" media="all" rel="stylesheet"/>
# <script defer="true" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
# <script defer="true" src="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.3.2/lazysizes.min.js"></script>
# <script defer="true" src="https://www.dawn.com/_js/ad-sticky-close.20240401153110.js"></script>
# <script defer="true" src="https://www.dawn.com/_js/stories.20240401153110.js"></script>
# <script defer="true" src="https://apis.google.com/js/platform.js"></script>
# <script defer="true" src="https://www.dawn.com/_js/all.20241115144107.js"></script>
# <link as="style" href="https://www.dawn.com/_css/headroom.20241114121412.css" rel="preload"/>
# <link as="font" href="https://fonts.googleapis.com/css?family=Playfair+Display:400,400i,700,700i,900&amp;display=swap" rel="preload"/>
# <link as="style" href="https://www.dawn.com/_css/print.20241015121807.css" rel="preload"/>
# <link as="style" href="https://www.dawn.com/_css/newskit.20241118133706.css" rel="preload"/>
# <link as="style" href="https://www.dawn.com/_css/merriweather.20241015121807.css" rel="preload"/>
# <link as="style" href="https://www.dawn.com/_css/shame.20241206112808.css" rel="preload"/>
# <link as="script" href="https://code.jquery.com/jquery-3.6.0.min.js" rel="preload"/>
# <link as="script" href="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.3.2/lazysizes.min.js" rel="preload"/>
# <link as="script" href="https://www.dawn.com/_js/ad-sticky-close.20240401153110.js" rel="preload"/>
# <link as="script" href="https://www.dawn.com/_js/stories.20240401153110.js" rel="preload"/>
# <link as="script" href="https://apis.google.com/js/platform.js" rel="preload"/>
# <link as="script" href="https://www.dawn.com/_js/all.20241115144107.js" rel="preload"/>
# <link href="i.dawn.com" rel="dns-prefetch preconnect"/>
# <link href="fonts.googleapis.com" rel="dns-prefetch preconnect"/>
# <link href="code.jquery.com" rel="dns-prefetch preconnect"/>
# <link href="cdnjs.cloudflare.com" rel="dns-prefetch preconnect"/>
# <link href="apis.google.com" rel="dns-prefetch preconnect"/>
# <!-- adverts:header start -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#     window.googletag = window.googletag || {cmd: []};
#     window.debugAds = window.location && window.location.search && window.location.search.includes('googfc');
#
#     googletag.cmd.push(function() {
#
#         googletag.defineSlot('/1029551/Dawn-Responsive-Middle-Leaderboard', [[970,250],[970,90],[728,90],[300,600],[320,480],[320,50],[320,100],[300,50],[300,250],[1,1]], 'div-gpt-ad-1693559881661-0')
#             .defineSizeMapping([[[728,0],[[728,90],[300,600],[320,480],[320,50],[320,100],[300,50],[1,1]]],[[0,0],[[300,600],[320,480],[300,250],[320,50],[320,100],[300,50],[1,1]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-ATF-MREC', [[300,250]], 'div-gpt-ad-1683363673257-0')
#             .defineSizeMapping([[[0,0],[[300,250]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-SKY-MREC', [[300,250],[320,480],[300,600],[160,600]], 'div-gpt-ad-1683363860950-0')
#             .defineSizeMapping([[[0,0],[[300,600],[320,480],[300,250],[160,600]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-Footer-Stickable-Leaderboard', [[970,250],[970,90],[728,90],[320,50],[320,100],[300,50],[300,250],[1,1]], 'div-gpt-ad-1693559286339-0')
#             .defineSizeMapping([[[970,0],[[970,250],[970,90],[728,90],[320,50],[320,100],[300,50],[1,1]]],[[728,0],[[728,90],[320,50],[320,100],[300,50],[1,1]]],[[0,0],[[300,250],[320,50],[320,100],[300,50],[1,1]]]])
#             .addService(googletag.pubads());
#         googletag.defineSlot('/1029551/Dawn-Responsive-Header-Leaderboard', [[970,250],[970,90],[728,90],[320,50],[320,100],[300,50],[300,250]], 'div-gpt-ad-1683363187247-0')
#             .defineSizeMapping([[[970,0],[[970,250],[970,90],[728,90],[320,50],[320,100],[300,50]]],[[728,0],[[728,90],[320,50],[320,100],[300,50]]],[[0,0],[[320,50],[320,100],[300,50]]]])
#             .addService(googletag.pubads());
#
#         googletag.pubads().setTargeting('site', ["www.dawn.com"]);
#         googletag.pubads().setTargeting('category', ["World","Single Story"]);
#         googletag.pubads().setTargeting('tag', ["Climate Change"]);
#
#         googletag.pubads().enableLazyLoad({
#             fetchMarginPercent: -1,
#             renderMarginPercent: 50,
#             mobileScaling: 2.0
#         });
#
#         googletag.pubads().enableSingleRequest();
#
#         // refreshAd('/3023235/Responsive-Middle-Leaderboard')
#         // refreshAd('div-gpt-ad-1693559881661-0')
#         window.refreshAd = ((id) => {
#             console.log(new Date().toISOString().substr(11, 8), 'refreshAd(' + id + ')');
#             for (let slot of googletag.pubads().getSlots()) {
#                 if (slot.getAdUnitPath() === id || slot.getSlotElementId() == id) {
#                     googletag.pubads().refresh([slot]);
#                 }
#             }
#         });
#
#         // <div data-refresh="30" id='div-gpt-ad-1234567890123-0' ...
#         googletag.pubads().addEventListener("slotRenderEnded", (e) => {
#             const id = e.slot.getSlotElementId();
#             document.getElementById(id).classList.add('ad-rendered');
#
#             // data-refresh
#             var seconds = null;
#             if (seconds = document.getElementById(id).getAttribute('data-refresh')) {
#                 console.log(new Date().toISOString().substr(11, 8), 'refreshAd(' + id + ') in ' + seconds + 's');
#                 window.__refreshAdTimeouts = window.__refreshAdTimeouts || [];
#                 clearTimeout(window.__refreshAdTimeouts[id]);
#                 window.__refreshAdTimeouts[id] = setTimeout(() => refreshAd(id), seconds * 1000);
#             };
#
#             // data-rendered-classes
#             var renderedClasses = null;
#             if (renderedClasses = document.getElementById(id).getAttribute('data-rendered-classes')) {
#                 document.getElementById(id).classList.add(renderedClasses);
#             }
#         });
#
#         if (debugAds) {
#             // debugging is enabled, add bgcolor and padding on all ad divs
#             document.querySelectorAll('[id^="div-gpt-ad-"]').forEach(el => {
#                 var hasError = el.classList.contains('advert-error');
#                 el.style.backgroundColor = hasError ? '#ecc' : '#ccc';
#                 el.title = el.dataset.name || '';
#                 el.innerHTML = hasError ? el.dataset.name : '';
#                 if (hasError) {
#                     el.style.padding = '10px';
#                 }
#                 el.style.height = el.dataset.height || '';
#                 el.style.width = el.dataset.width || '';
#             });
#         } else {
#             googletag.pubads().collapseEmptyDivs();
#         }
#
#         googletag.enableServices();
#     });
#
#     // Relocate Ads
#     window.addEventListener('DOMContentLoaded',function () {
#         document.querySelectorAll('[data-selector]').forEach(ad => {
#             if (target = document.querySelector(ad.getAttribute('data-selector'))) {
#                 target.insertAdjacentElement('afterend', ad);
#             }
#         });
#     });
#
#     // Relocate Ad if viewport width is less than 720px
#     window.addEventListener('DOMContentLoaded',function () {
#         if (window.matchMedia('(max-width: 720px)').matches) {
#             document.querySelectorAll('[data-selector-mobile]').forEach(ad => {
#                 if (target = document.querySelector(ad.getAttribute('data-selector-mobile'))) {
#                     target.insertAdjacentElement('afterend', ad);
#                 }
#             });
#         }
#     });
#     </script>
# <!-- adverts:header end -->
# <!-- - - - - start:onesignal link - - - - -->
# <link href="/manifest.json" rel="manifest"/>
# <!-- - - - - end:onesignal link - - - - -->
# </meta></meta></head>
# <body class="article template--default world world- ar-8 adsonly single-story antialiased">
# <header class="pb-2">
# <div class="w-full bg-black nav--network">
# <div class="px-2 hidden sm:block">
# <nav class="text-white flex flex-row flex-wrap text-2.5 justify-center text-center">
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://epaper.dawn.com">EPAPER</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawnnews.tv/watch-live">LIVE TV</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawnnews.tv">DAWNNEWS URDU</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://images.dawn.com">Images</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://herald.dawn.com">Herald</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://aurora.dawn.com">Aurora</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://cityfm89.com" rel="noreferrer" target="blank">CityFM89</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawn.com/advertise" rel="noreferrer" target="blank">Advertise</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawn.com/events" rel="noreferrer" target="blank">Events</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://www.dawn.com/events/supplements"><span class="-ml-4 mr-1">/</span>Supplements</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="http://classifieds.dawn.com/" rel="noreferrer" target="blank">Classifieds</a>
# <a class="text-gray-400 uppercase py-1.25 px-2.5" href="https://obituary.dawn.com" rel="noreferrer" target="blank">Obituaries</a>
# </nav>
# </div>
# </div>
# <div class="">
# <div class="container px-2 sm:px-0">
# <div class="flex flex-col sm:flex-row">
# <div class="w-1/4">
# </div>
# <div class="sm:w-1/2 w-full">
# <div class="flex flex-col items-center mt-4 mb-3">
# <a class="logo mb-2" href="https://www.dawn.com/" title="DAWN.COM">
# <img alt="DAWN.COM Logo" class="w-44" src="https://www.dawn.com/_img/logo.png"/>
# <span class="hidden">DAWN.COM</span>
# </a>
# <h2 class="badge inline-flex text-2.5 font-arial uppercase text-gray-500 align-middle" dir="auto" id="span-class-font-bold-text-black-e-paper-span-december-09-2024"><a class="" href="https://epaper.dawn.com" title="&lt;span class='font-bold text-black'&gt;E-Paper&lt;/span&gt; | December 09, 2024"><span class="font-bold text-black">E-Paper</span> | December 09, 2024</a></h2>
# </div>
# </div>
# <div class="w-1/4">
# </div>
# </div>
# </div>
# </div>
# <div class="container px-2 sm:px-0 headroom">
# <div class="flow-root container mx-auto mx-auto px-0 sm:px-6.5 relative">
# <!-- nav container -->
# <nav class="native-hidden js-nav relative font-sans container p-0 border-t-3 border-black">
# <div class="js-nav-container border-b border-gray-200">
# <div class="nav-alignment flex justify-between items-center">
# <!-- nav items -->
# <div class="js-nav-items flex overflow-y-hidden overflow-x-scroll px-0 w-full primary-scroll mr-1">
# <div class="flex flex-row overflow-x-scroll w-full justify-start">
# <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="//www.dawn.com" target="_self" title="Home">
#      Home
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/latest-news" target="_self" title="Latest">
#      Latest
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 text-red-300" href="https://www.dawn.com/breathepakistan/" target="_self" title="Breathe">
#      Breathe
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 text-red-300" href="https://www.dawn.com/trends/gaza-invasion" target="_self" title="Gaza siege">
#      Gaza siege
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/pakistan" target="_self" title="Pakistan">
#      Pakistan
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/opinion" target="_self" title="Opinion">
#      Opinion
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/business" target="_self" title="Business">
#      Business
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/entertainment" target="_self" title="Images">
#      Images
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/prism" target="_self" title="Prism">
#      Prism
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/world" target="_self" title="World">
#      World
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/sport" target="_self" title="Sport">
#      Sport
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/magazines" target="_self" title="Magazines">
#      Magazines
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/tech" target="_self" title="Tech">
#      Tech
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/videos" target="_self" title="Videos">
#      Videos
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/popular" target="_self" title="Popular">
#      Popular
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/newspaper" target="_self" title="Archive">
#      Archive
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="https://www.dawnrelief.com/" target="_self" title="Flood Donations">
#      Flood Donations
#   </a> </div>
# </div>
# <!-- nav sandwich -->
# <div class="flex items-center relative hidden">
# <div class="js-nav-sandwich pt-1 mr-2">
# <button class="text-gray-400 hover:text-gray-500 focus:bg-gray-100 focus:text-gray-500 inline-flex items-center justify-center rounded-md focus:outline-none transition duration-150 ease-in-out">
# <!-- ☰ -->
# <svg class="block h-6 w-6" fill="none" id="navopen" stroke="currentColor" viewbox="0 0 24 24">
# <path d="M4 6h16M4 12h16M4 18h16" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path>
# </svg>
# <!-- X -->
# <svg class="hidden h-6 w-6" fill="none" id="navclose" stroke="currentColor" viewbox="0 0 24 24">
# <path d="M6 18L18 6M6 6l12 12" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path>
# </svg>
# </button>
# </div>
# <!-- nav dropdown -->
# <div class="js-nav-dropdown hidden z-50 absolute top-9 right-0 border border-gray-300 bg-white shadow-2xl text-3 w-40" id="nav-dropdown">
# <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="//www.dawn.com" target="_self" title="Home">
#      Home
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/latest-news" target="_self" title="Latest">
#      Latest
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 text-red-300" href="https://www.dawn.com/breathepakistan/" target="_self" title="Breathe">
#      Breathe
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75 text-red-300" href="https://www.dawn.com/trends/gaza-invasion" target="_self" title="Gaza siege">
#      Gaza siege
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/pakistan" target="_self" title="Pakistan">
#      Pakistan
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/opinion" target="_self" title="Opinion">
#      Opinion
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/business" target="_self" title="Business">
#      Business
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/entertainment" target="_self" title="Images">
#      Images
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/prism" target="_self" title="Prism">
#      Prism
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/world" target="_self" title="World">
#      World
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/sport" target="_self" title="Sport">
#      Sport
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/magazines" target="_self" title="Magazines">
#      Magazines
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/tech" target="_self" title="Tech">
#      Tech
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/videos" target="_self" title="Videos">
#      Videos
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/popular" target="_self" title="Popular">
#      Popular
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="/newspaper" target="_self" title="Archive">
#      Archive
#   </a> <a class="px-2 py-2 block whitespace-nowrap hover:bg-gray-200 uppercase leading-4 text-2.75" href="https://www.dawnrelief.com/" target="_self" title="Flood Donations">
#      Flood Donations
#   </a> </div>
# </div>
# <!-- desktop nav search -->
# <div class="js-nav-search justify-end items-center">
# <label class="sr-only" for="search" title="Search">Search</label>
# <div class="relative">
# <form accept-charset="utf-8" action="https://www.dawn.com/search" class="flex items-center" method="GET">
# <div class="cursor-pointer sm:pointer-events-none" onclick="document.querySelector('#js-mob-search').classList.toggle('hidden');">
# <svg class="h-4 w-4 text-gray-400" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M8 4a4 4 0 100 8 4 4 0 000-8zM2 8a6 6 0 1110.89 3.476l4.817 4.817a1 1 0 01-1.414 1.414l-4.816-4.816A6 6 0 012 8z" fill-rule="evenodd"></path>
# </svg>
# </div>
# <input name="cx" type="hidden" value="016184311056644083324:a1i8yd7zymy"/>
# <input name="cof" type="hidden" value="FORID:10"/>
# <input name="ie" type="hidden" value="UTF-8"/>
# <input class="nav-search-input border-0 w-30 text-3 font-extralight ml-0.5 px-2 leading-5 placeholder-gray-400 focus:outline-none search-query hidden sm:block" data-remember="false" id="q" name="q" onblur="javascript:this.classList.remove('w-44');this.classList.remove('md:w-64')" onfocus="javascript:this.classList.add('w-44');this.classList.add('md:w-64')" placeholder="SEARCH" required="" type="text" value=""/>
# </form>
# </div>
# </div>
# </div>
# <!-- mobile nav search -->
# <div class="js-nav-search flex justify-center items-center sm:hidden mt-1">
# <label class="sr-only" for="search" title="Search">Search</label>
# <div class="relative">
# <form accept-charset="utf-8" action="https://www.dawn.com/search" class="flex items-center" method="GET">
# <input name="cx" type="hidden" value="016184311056644083324:a1i8yd7zymy"/>
# <input name="cof" type="hidden" value="FORID:10"/>
# <input name="ie" type="hidden" value="UTF-8"/>
# <input class="hidden text-3 w-64 font-extralight px-2 py-1 leading-none border rounded border-gray-300 mb-1 placeholder-gray-400 focus:outline-none search-query" data-remember="false" id="q" name="q" placeholder="SEARCH" required="" type="text" value=""/>
# </form>
# </div>
# </div>
# </div>
# </nav> </div>
# </div> </header>
# <div class="aux-content flex justify-center" style="overflow: hidden;">
# <!-- advert:start div-gpt-ad-1683363187247-0 -->
# <div class="ad__wrapper__slot px-1 py-2 mb-2" data-height="250px" data-name="Dawn-Responsive-Header-Leaderboard" data-refresh="180" data-rendered-classes="" data-width="970px" id="div-gpt-ad-1683363187247-0">
# <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1683363187247-0'); });</script>
# </div>
# <!-- advert:end -->
# </div>
# <div class="container mx-auto px-2 sm:px-0">
# <div class="flex">
# <div class="w-full max-w-screen-md xl:pr-4">
# <article class="story relative overflow-hidden single bg-white font-georgia" data-id="1877688" data-layout="default" data-tags="" id="1877688"> <div class="flex items-baseline">
# </div>
# <div class="template__header flow-root px-1 border-b mb-4">
# <!-- box/title title-text:7.5-border-bottom-mt:1-pb:3-playfairdisplay-bold -->
# <h2 class="story__title text-7.5 font-bold font-playfair-display mt-1 pb-3 border-b border-gray-300 border-solid" data-id="1877688" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877688/extreme-heat-endangers-garment-factory-workers-in-pakistan-and-beyond-study">Extreme heat endangers garment factory workers in Pakistan and beyond: study</a></h2>
# <!-- box/byline --><div class="my-3 sm:ml-0 ml-1 block sm:inline-block float-none sm:float-left" dir="auto"><span class="story__byline text-3 text-gray-500 font-arial" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/422/reuters">Reuters</a></span><span class="divider text-3 text-gray-500 font-arial"></span><!-- box/date --><span class="story__time text-3 text-gray-500 font-arial"> <span class="timestamp--published">
# <span class="timestamp--label">Published</span>
# <span class="timestamp--date">December 9, 2024</span>
# </span> <span class="timestamp--updated">
# <span class="divider"></span>
# <span class="timestamp--label">Updated</span>
# <span class="timestamp--time timeago" title="2024-12-09T15:11:20+05:00">
# <span class="timestamp__calendar">December 9, 2024</span>
# <span class="timestamp__time">03:11pm</span>
# </span>
# </span></span> </div>
# <!-- box/social -->
# <div class="block sm:inline-block flow-root float-none sm:float-right"> <div class="social js-social-fb social--icon social--black social--flat social--facebook float-left mr-2 my-2">
# <a class="h-full w-full outline-none inline-block" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.dawn.com%2Fnews%2F1877688&amp;display=popup&amp;ref=plugin" onclick="return !window.open(this.href, 'Share on Facebook', 'width=640, height=536')" rel="noreferrer" target="_blank"><img height="20" src="/_img/social/icon-fb-black.png" width="20"/></a>
# </div> <div class="social js-social-twitter social--icon social--black social--flat social--twitter float-left mr-2 my-2">
# <a class="h-full w-full outline-none inline-block" href="https://twitter.com/share?text=Extreme%20heat%20endangers%20garment%20factory%20workers%20in%20Pakistan%20and%20beyond%3A%20study&amp;url=https%3A%2F%2Fwww.dawn.com%2Fnews%2F1877688&amp;counturl=https%3A%2F%2Fwww.dawn.com%2Fnews%2F1877688" onclick="return !window.open(this.href, 'Tweet', 'width=640, height=300')" rel="noreferrer" target="_blank"><img height="20" src="/_img/social/icon-twitter-black.png" width="20"/></a>
# </div> <div class="social js-social-whatsapp social--whatsapp float-left mr-2 my-2 social--icon social--black social--flat">
# <a class="inline-block uppercase align-middle text-gray-400" href="WhatsApp://send?text=Extreme%20heat%20endangers%20garment%20factory%20workers%20in%20Pakistan%20and%20beyond%3A%20study%20%0A%20https%3A%2F%2Fwww.dawn.com%2Fnews%2F1877688%3Fref%3Dwhatsapp" target="_blank">
# <img class="inline-block float-left mr-0.5 mb-2" height="" src="/_img/social/icon-whatsapp-black.png" width=""/>
# <span class=""></span>
# </a>
# </div> <div class="social js-social-print hidden sm:block social--print social--icon social--black social--flat social--icon social--black social--flat float-left mr-2 my-2">
# <a class="inline-block uppercase align-middle text-gray-400" href="https://www.dawn.com/news/print/1877688"><img height="20" src="/_img/social/icon-print-black.png" width="20"/>   </a>
# </div> <div class="social js-social-email social--email social--icon social--black social--flat float-left mr-2 my-2">
# <a class="h-full w-full outline-none inline-block inline-block uppercase text-gray-400" href="javascript:void(0)" onclick="$('#js-mailer [name^=id]').val(1877688);$('#js-mailer').removeClass('hidden');$('body').css('overflow', 'hidden');"><img height="18" src="/_img/social/icon-email-black.png" width="24"/></a>
# </div> <div class="social js-social-comment social--comment social--icon social--black social--flat social--count font-normal float-left mr-2 my-2">
# <a class="font-normal inline-block uppercase align-middle text-gray-400 text-center" data-comments-status="open" href="#comments"><img class="inline-block float-left mr-0.5" height="19" src="/_img/social/icon-comment-black.png" width="22"/><span class="mt-0.5 text-black text-3 font-arial inline-block align-top">0</span></a>
# </div></div> </div>
# <div class="template__main flow-root px-1 w-full sm:w-2/3 mx-auto md:min-w-183">
# <figure class="flex items-center">
# <figcaption class="text-3 font-sans uppercase mr-3 whitespace-no-wrap"><span class="hidden md:inline">Listen to article</span></figcaption>
# <audio class="h-5 w-60 sm:w-80 rounded-none" controls="" controlslist="noplaybackrate nodownload" id="tts" preload="metadata" src="https://i.dawn.com/newskit-tts-service/1877688.27b43b72-340f-4309-a2e4-92598bbf1e24.mp3"></audio>
# <button class="mx-3 text-3 font-sans" onclick="document.getElementById('tts').playbackRate = 1.0">1x</button>
# <button class="mr-3 text-3 font-sans" onclick="document.getElementById('tts').playbackRate = 1.2">1.2x</button>
# <button class="mr-3 text-3 font-sans" onclick="document.getElementById('tts').playbackRate = 1.5">1.5x</button>
# </figure> <div class="flex whatsapp-channel mt-4">
# <a class="text-4 bg-gray-50 text-black border border-gray-300 inline-flex items-center px-2 pt-2 font-fjalla whitespace-nowrap hover:bg-gray-200" dir="auto" href="https://whatsapp.com/channel/0029VaMc238IiRov8okfYy3n">
# <div class="social__label pl-1 text-3 font-sans uppercase whitespace-no-wrap">
# <img class="inline-block float-left mr-0.5 mb-2 pr-2" src="/_img/social/icon-whatsapp-black.png" style="filter: brightness(0.9) invert(.6) sepia(.5) hue-rotate(51deg) saturate(300%)"/>
#             Join our Whatsapp channel
# </div>
# </a>
# </div>
# <!-- box/content -->
# <div class="story__content overflow-hidden text-4 sm:text-4.5 pt-1 mt-1" dir="auto"><p>Workers in some of the world’s biggest garment manufacturing hubs in Pakistan, Bangladesh, and Vietnam are increasingly exposed to extreme heat as climate change pushes temperatures up, a <a class="link--external" href="https://www.ilr.cornell.edu/sites/default/files-d8/2024-12/gli-hot-air-4-december-2024.pdf" rel="noopener noreferrer" target="_blank">report</a> found on Sunday, a problem multinational retailers and brands will have to help address.</p>
# <p>New European Union regulations make retailers selling in the bloc, like Inditex, H&amp;M and Nike, legally liable for conditions at their suppliers, putting pressure on them to help fund improvements to cool factories they source from.</p>
# <p>In Karachi, Dhaka, Hanoi, Ho Chi Minh City, and Phnom Penh, the number of days with “wet-bulb” temperatures — a measurement that accounts for air temperature as well as humidity — above 30.5 degrees Celsius jumped by 42 per cent in 2020 to 2024 compared to 2005 to 2009, researchers at Cornell University’s Global Labor Institute found.</p>
# <p>Above that threshold, the International Labor Organisation recommends as much rest as work in any given hour to maintain safe core body temperature levels.</p>
# <p>The report identified only three retailers — Nike, Levi’s, and VF Corp — which specifically include protocols to protect workers from heat exhaustion in their supplier codes of conduct.</p>
# <h2><a aria-hidden="true" class="heading-permalink" href="#companies-warned" id="companies-warned" title="Permalink"></a>Companies warned</h2>
# <p>“We’ve been talking to brands for ages now about this issue, and they’re only now starting to turn their attention to it,” Jason Judd, executive director at Cornell University’s Global Labor Institute, told <em>Reuters</em>.</p>
# <p>“If a brand or retailer knows that temperatures in a production area are excessively high or doing damage to worker health, then they’re obligated under this new set of rules to do something about it,” he added.</p>
# <p>The EU Corporate Sustainability Due Diligence Directive came into force in July and will start applying to large companies from mid-2027.</p>
# <p>Fixes to cool factories could include better ventilation and water evaporative cooling systems, instead of energy-intensive and expensive air conditioning that would increase manufacturers’ carbon emissions.</p>
# <p>Some factory owners would likely be willing to make such investments themselves, given how heat stress significantly impacts productivity, Judd said, but the EU rules highlight brands’ responsibility to address the issue too.</p>
# <p>The report also urged retailers and brands to invest in higher wages and health protections so that workers can manage the risk of missing work days due to heatwaves.</p>
# <p>Extreme heat and flooding could <a href="https://www.dawn.com/news/1775791">erase $65 billion</a> in apparel export earnings from Bangladesh, Cambodia, Pakistan, and Vietnam by 2030, <a class="link--external" href="https://www.ilo.org/resource/article/ensuring-safety-and-health-work-changing-climate" rel="noopener noreferrer" target="_blank">research</a> from asset manager Schroders and the Global Labor Institute found last year.</p>
# </div>
# </div>
# <div class="template__footer flow-root px-1">
# <div class="w-full sm:w-2/3 mx-auto border-t border-gray-200 mb-4 pt-2">
# <!-- advert:start div-gpt-ad-1693559881661-0 -->
# <div class="ad__wrapper__slot clear-both flex justify-center py-6.5 my-4" data-height="90px" data-name="Dawn-Responsive-Middle-Leaderboard" data-rendered-classes="" data-selector=".story__content p:nth-of-type(4)" data-width="728px" id="div-gpt-ad-1693559881661-0">
# <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1693559881661-0'); });</script>
# </div>
# <!-- advert:end -->
# <div class="flex flex-col">
# <div class="mb-2 pb-2 italic border-b border-gray-200">
#                             Join DawnMedia’s <a class="text-blue-600" href="https://www.instagram.com/breathe_pakistan/" target="_blank">Breathe Pakistan</a> initiative to combat climate change.</div>
# </div>
# <div class="flex flex-col sm:flex-row">
# <div class="w-full sm:w-1/2">
# <div class="mb-0 sm:mb-4">
# <div class="flex">
# <div class="w-full">
# <span class="uppercase text-2.5 font-arial">
# <a class="text-red-400" href="/trends/climate-change">Climate Change</a> </span>
# </div>
# <div class="w-full">
# <!-- box/label -->
# <span class="badge inline-flex text-2.5 uppercase font-arial align-middle" dir="auto" id="world"><a class="text-2.5 uppercase font-arial" href="/world" title="World"><span>World </span></a></span>
# </div>
# </div>
# </div>
# </div>
# <div class="w-full sm:w-1/2">
# <div class="mt-2 sm:mt-0 flow-root float-left sm:float-right">
# <!-- box/social -->
# <div class="social js-social-fb social--icon social--black social--flat social--facebook float-left mr-2">
# <a class="h-full w-full outline-none inline-block" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.dawn.com%2Fnews%2F1877688&amp;display=popup&amp;ref=plugin" onclick="return !window.open(this.href, 'Share on Facebook', 'width=640, height=536')" rel="noreferrer" target="_blank"><img height="20" src="/_img/social/icon-fb-black.png" width="20"/></a>
# </div> <div class="social js-social-twitter social--icon social--black social--flat social--twitter float-left mr-2">
# <a class="h-full w-full outline-none inline-block" href="https://twitter.com/share?text=Extreme%20heat%20endangers%20garment%20factory%20workers%20in%20Pakistan%20and%20beyond%3A%20study&amp;url=https%3A%2F%2Fwww.dawn.com%2Fnews%2F1877688&amp;counturl=https%3A%2F%2Fwww.dawn.com%2Fnews%2F1877688" onclick="return !window.open(this.href, 'Tweet', 'width=640, height=300')" rel="noreferrer" target="_blank"><img height="20" src="/_img/social/icon-twitter-black.png" width="20"/></a>
# </div> <div class="social js-social-whatsapp social--whatsapp float-left mr-2 social--icon social--black social--flat">
# <a class="inline-block uppercase align-middle text-gray-400" href="WhatsApp://send?text=Extreme%20heat%20endangers%20garment%20factory%20workers%20in%20Pakistan%20and%20beyond%3A%20study%20%0A%20https%3A%2F%2Fwww.dawn.com%2Fnews%2F1877688%3Fref%3Dwhatsapp" target="_blank">
# <img class="inline-block float-left mr-0.5 mb-2" height="" src="/_img/social/icon-whatsapp-black.png" width=""/>
# <span class=""></span>
# </a>
# </div> <div class="social js-social-print hidden sm:block social--print social--icon social--black social--flat social--icon social--black social--flat float-left mr-2">
# <a class="inline-block uppercase align-middle text-gray-400" href="https://www.dawn.com/news/print/1877688"><img height="20" src="/_img/social/icon-print-black.png" width="20"/>   </a>
# </div> <div class="social js-social-email social--email social--icon social--black social--flat float-left mr-2">
# <a class="h-full w-full outline-none inline-block inline-block uppercase text-gray-400" href="javascript:void(0)" onclick="$('#js-mailer [name^=id]').val(1877688);$('#js-mailer').removeClass('hidden');$('body').css('overflow', 'hidden');"><img height="18" src="/_img/social/icon-email-black.png" width="24"/></a>
# </div> <div aria-labelledby="modal-title" aria-modal="true" class="hidden font-arial fixed z-10 inset-0 overflow-y-auto" dir="ltr" id="js-mailer" role="dialog" style="z-index:201">
# <div class="flex items-end justify-center pt-4 px-4 pb-20 text-center sm:block sm:p-0">
# <div aria-hidden="true" class="fixed inset-0 bg-gray-500 bg-opacity-75 transition-opacity"></div>
# <div class="inline-block align-bottom bg-white rounded-lg px-4 pt-5 pb-4 text-left overflow-hidden shadow-xl transform transition-all sm:my-8 sm:align-middle sm:max-w-lg sm:w-full sm:p-6">
# <div class="text-center">
# <h3 class="mb-4 text-lg leading-6 font-medium text-gray-900" id="modal-title">
#                 Email
#                 </h3>
# </div>
# <div id="js-form-container">
# <form accept-charset="utf-8" action="https://www.dawn.com/news/email/1877688" class="form-vertical emailer" id="email-story" method="POST" onsubmit="javascript:$.post(this.action, $(this).serialize(), function(data,status,xhr) { $('#js-mailer-success-icon').removeClass('hidden');$('#js-form-container').addClass('hidden');$('#js-form-container').after(data.message);});return false;"><input class="form-control" name="jscheck" type="hidden" value=""/><div class="form-group required"><label class="text-3 control-label" for="sender">Your Name<sup>*</sup></label><input class="py-0.5 px-1 border ml-10 rounded mb-4" id="sender" name="sender" required="" type="text"/></div><div class="form-group required"><input class="py-0.5 px-1 border ml-4 rounded mb-4" id="to" name="to" required="" type="text"/></div><input class="form-control" name="id" type="hidden" value=""/><input class="btn inline-flex justify-center w-full rounded-md border border-transparent shadow-sm px-4 py-2 bg-gray-600 text-base font-medium text-white hover:bg-gray-700 focus:outline-none sm:w-auto sm:text-sm cursor-pointer" type="submit" value="Email"/><button class="btn ml-4 inline-flex justify-center w-full rounded-md border shadow-sm px-4 py-2 text-base font-medium hover:bg-gray-200 focus:outline-none sm:w-auto sm:text-sm cursor-pointer" href="javascript:void(0)" id="js-mailer-close" onclick="$('body').css('overflow', 'initial');$('#js-mailer').addClass('hidden');" type="button">Cancel</button><input class="form-control" name="_token" type="hidden" value=""/></form>
# </div>
# </div>
# </div>
# </div> <div class="social js-social-comment social--comment social--icon social--black social--flat social--count font-normal float-left mr-2">
# <a class="font-normal inline-block uppercase align-middle text-gray-400 text-center" data-comments-status="open" href="#comments"><img class="inline-block float-left mr-0.5" height="19" src="/_img/social/icon-comment-black.png" width="22"/><span class="mt-0.5 text-black text-3 font-arial inline-block align-top">0</span></a>
# </div> </div>
# </div>
# </div>
# <div class="flex">
# </div>
# </div>
# <div class="border-t-3 border-black">
# <h3 class="my-2 font-playfair-display font-bold text-6 leading-tight">
#                     Read more                </h3>
# <div class="flex flex-col sm:flex-row mb-4">
# <!-- SECTION/READ MORE STORIES -->
# <div class="md:w-2/3 w-full">
# <div class="grid grid-cols-1 sm:grid-cols-3 gap-2 mb-4">
# <!-- - - - article - - - -->
# <article class="story relative overflow-hidden box pr-0 sm:pr-2 pb-2 mb-2 sm:border-r sm:border-gray-200 border-b border-solid sm:border-b-0" data-id="1849549" data-layout="story" data-tags="" id="1849549">
# <!-- box/image -->
# <figure class="media media--focus sm:w-full w-1/4 sm:mr-0 mr-2 sm:float-none float-left h-auto mb-0" data-focus-x="72.08%" data-focus-y="43.51%">
# <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1849549/extreme-heat-claims-175000-lives-a-year-in-europe-says-who" target="_self" title="Extreme heat claims 175,000 lives a year in Europe, says WHO"><picture><img alt="Extreme heat claims 175,000 lives a year in Europe, says WHO" class="lazyload" data-src="https://i.dawn.com/medium/2024/08/021116041791a85.jpg?r=112107" src="..." title="Extreme heat claims 175,000 lives a year in Europe, says WHO"/></picture></a></div>
# </figure>
# <!-- box/title text:4-py:sm:2-py:0-playfairdisplay -->
# <h2 class="story__title text-4 font-playfair-display font-bold pt-1 pb-2 text-4 leading-tight sm:py-2 py-0" data-id="1849549" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1849549/extreme-heat-claims-175000-lives-a-year-in-europe-says-who">Extreme heat claims 175,000 lives a year in Europe, says WHO
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="story relative overflow-hidden box pr-0 sm:pr-2 pb-2 mb-2 sm:border-r sm:border-gray-200 border-b border-solid sm:border-b-0" data-id="1775791" data-layout="story" data-tags="" id="1775791">
# <!-- box/title text:4-py:sm:2-py:0-playfairdisplay -->
# <h2 class="story__title text-4 font-playfair-display font-bold pt-1 pb-2 text-4 leading-tight sm:py-2 py-0" data-id="1775791" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1775791/harsh-weather-may-hit-65bn-asian-apparel-exports-study">Harsh weather may hit $65bn Asian apparel exports: study
# </a></h2>
# </article>
# <!-- - - - /article - - - -->
# <!-- - - - article - - - -->
# <article class="story relative overflow-hidden box pr-0 sm:pr-2 pb-2 mb-2 sm:border-r sm:border-gray-200 border-b border-solid sm:border-b-0" data-id="1841993" data-layout="story" data-tags="" id="1841993">
# <!-- box/title text:4-py:sm:2-py:0-playfairdisplay -->
# <h2 class="story__title text-4 font-playfair-display font-bold pt-1 pb-2 text-4 leading-tight sm:py-2 py-0" data-id="1841993" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1841993/relatives-blame-outages-for-deaths-amid-severe-heat">Relatives blame outages for deaths amid severe heat
# </a></h2>
# </article>
# <!-- - - - /article - - - --> </div>
# </div>
# <!-- SPONSORED CONTENT -->
# <div class="md:w-1/3 w-full">
# <article class="story relative overflow-hidden box sponsored-content theme px-1" data-id="1851391" data-layout="story" data-tags="" id="1851391">
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1851391/revolutionising-reproductive-health-viya-launches-viya-telehealth" target="_self" title="Revolutionising reproductive health: Viya launches Viya Telehealth"><picture><img alt="Revolutionising reproductive health: Viya launches Viya Telehealth" class="lazyload" data-src="https://i.dawn.com/medium/2024/08/271548510b8a85d.jpg?r=154855" src="..." title="Revolutionising reproductive health: Viya launches Viya Telehealth"/></picture></a></div>
# </figure>
# <h2 class="badge inline-flex text-2.5 font-normal uppercase text-grey leading-tight align-middle" dir="auto" id="sponsored"><a class="text-2.5 font-normal uppercase text-grey" href="https://www.dawn.com/sponsor-content" title="Sponsored">Sponsored</a></h2>
# <!-- box/title title-text:4-playfairdisplay-bold -->
# <h2 class="story__title text-4 font-bold font-playfair-display leading-tight" data-id="1851391" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1851391/revolutionising-reproductive-health-viya-launches-viya-telehealth">Revolutionising reproductive health: Viya launches Viya Telehealth</a></h2>
# </article> </div>
# </div>
# <div class="w-full flex-column border-t-3 border-black text-right pb-5">
# <div class="align-middle text-3.5 my-3 font-bold font-serif flex">On DawnNews</div>
# ...
# <a class="navstory__arrow opacity-50 bg-gray-400 text-13 absolute pt-0 pb-2 px-1.25 font-georgia text-white rounded-tr-md rounded-br-md navstory__arrow--prev" href="https://www.dawn.com/news/1876913/saudi-arabia-extends-3bn-deposit-in-pakistan-for-another-year">‹</a>
# <div class="navstory__article p-2.5 opacity-0 w-52 -ml-56 bg-gray-200 navstory__article--prev">
# <!-- - - - article - - - -->
# <article class="story relative overflow-hidden box" data-id="1876913" data-layout="story" data-tags="" id="1876913">
# <!-- box/title  -->
# <h2 class="story__title" data-id="1876913" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1876913/saudi-arabia-extends-3bn-deposit-in-pakistan-for-another-year">Saudi Arabia extends $3bn deposit in Pakistan for another year</a></h2>
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1876913/saudi-arabia-extends-3bn-deposit-in-pakistan-for-another-year" target="_self" title="Saudi Arabia extends $3bn deposit in Pakistan for another year"><picture><img alt="Saudi Arabia extends $3bn deposit in Pakistan for another year" src="https://i.dawn.com/thumbnail/2024/12/052031148210117.jpg?r=203433" title="Saudi Arabia extends $3bn deposit in Pakistan for another year"/></picture></a></div>
# </figure>
# </article>
# <!-- - - - /article - - - --> </div>
# </div>
# <div class="navstory fixed z-50 top-2/5 right-0 rounded-t-md rounded-l-md navstory--next" title="You can also use your keyboard ← (left arrow) or → (right arrow) to navigate stories">
# <a class="navstory__arrow opacity-50 bg-gray-400 text-13 absolute right-0 pt-0 pb-2 px-1.25 font-georgia text-white rounded-tl-md rounded-bl-md navstory__arrow--next" href="https://www.dawn.com/news/1877481/ousted-assad-his-family-in-moscow-after-rebel-forces-capture-syrias-capital">›</a>
# <div class="navstory__article p-2.5 opacity-0 w-52 -mr-56 bg-gray-200 navstory__article--next">
# <!-- - - - article - - - -->
# <article class="story relative overflow-hidden box" data-id="1877481" data-layout="story" data-tags="" id="1877481">
# <!-- box/title  -->
# <h2 class="story__title" data-id="1877481" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877481/ousted-assad-his-family-in-moscow-after-rebel-forces-capture-syrias-capital">Ousted Assad, his family in Moscow after rebel forces capture Syria’s capital</a></h2>
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-0">
# <div class="media__item"><a href="https://www.dawn.com/news/1877481/ousted-assad-his-family-in-moscow-after-rebel-forces-capture-syrias-capital" target="_self" title="Ousted Assad, his family in Moscow after rebel forces capture Syria’s capital"><picture><img alt="Ousted Assad, his family in Moscow after rebel forces capture Syria’s capital" src="https://i.dawn.com/thumbnail/2024/12/0823145169ba25b.jpg?r=092117" title="Ousted Assad, his family in Moscow after rebel forces capture Syria’s capital"/></picture></a></div>
# </figure>
# </article>
# <!-- - - - /article - - - --> </div>
# </div>
# </div>
# <footer>
# <div class="flex justify-center p-2">
# <!-- advert:start div-gpt-ad-1693559286339-0 -->
# <div class="ad__wrapper__slot" data-height="250px" data-name="Dawn-Responsive-Footer-Stickable-Leaderboard" data-rendered-classes="" data-width="970px" id="div-gpt-ad-1693559286339-0">
# <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1693559286339-0'); });</script>
# </div>
# <!-- advert:end -->
# </div>
# <div class="w-full bg-black">
# <div class="py-4">
# <div class="container px-2">
# <div class="flex flex-row border-b-2 border-white mb-2 pb-2 justify-between items-center">
# <nav class="order-first">
# <a class="logo" href="https://www.dawn.com/" title="DAWN.COM">
# <img alt="DAWN.COM Logo" class="w-20" src="https://www.dawn.com/_img/logo-white.png"/>
# <span class="hidden">DAWN.COM</span>
# </a> <p class="hidden"> Compunode.com Pvt. Ltd. (<a class="px-0 sm:px-1 font-normal" href="https://www.compunode.com/">www.compunode.com</a>).Designed for <a class="px-0 sm:px-1 font-normal" href="https://www.dawn.com">Dawn</a>.</p>
# </nav>
# <nav class="nav flex mt-2 sm:mt-0 items-end order-last">
# <a class="outline-none" href="https://whatsapp.com/channel/0029VaMc238IiRov8okfYy3n"><img alt="Whatsapp" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2024/02/080925032506f93.png"/></a>
# <a class="outline-none" href="https://twitter.com/dawn_com"><img alt="Twitter" class="align-baseline mt-1 mr-2" src="https://i.dawn.com/large/2024/02/16125537351049d.png" style="height:17px"/></a>
# <a class="outline-none" href="https://www.facebook.com/dawndotcom"><img alt="Facebook" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c42cf5e8.png" width="20"/></a>
# <a class="outline-none" href="https://www.instagram.com/dawn.today/"><img alt="Instagram" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c430f9b2.png" width="20"/></a>
# <a class="outline-none" href="https://itunes.apple.com/pk/app/dawn-official-mobile-app/id935631940"><img alt="Apple" class="align-baseline mt-1 mr-2" height="34" src="https://i.dawn.com/thumbnail/2019/02/5c611c42d5669.png" width="20"/></a>
# <a class="outline-none" href="https://play.google.com/store/apps/details?id=com.mictronicx.dawn"><img alt="Android" class="align-baseline mt-1 mr-2" height="34" src="https://i.dawn.com/thumbnail/2019/02/5c611c42ce48d.png" width="20"/></a>
# <a class="outline-none" href="https://appgallery.huawei.com/#/app/C104007373"><img alt="Huwaei App Gallery" class="align-baseline mt-1" height="30" src="https://i.dawn.com/thumbnail/2021/05/60a360ab86d68.png" width="100"/></a>
# </nav>
# </div>
# <div class="grid grid-cols-2 sm:flex sm:flex-row">
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/contact">Contact</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/terms">Terms of Use</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/reproduction-copyrights">Reproduction Copyrights</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/contribution-guidelines">Contribution Guidelines</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/privacy">Privacy</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/comments-policy">Comment Moderation</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/code-of-ethics">Code of Ethics</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/subscription">Subscribe to Newspaper</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/marketing">Advertise on Dawn.com</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/sponsor-content">Sponsored Content</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://classifieds.dawn.com">Classifieds</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://obituary.dawn.com">Obituaries</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/prayers-timings">Prayer Timings</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/stocks">Stock/Forex/Gold</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/weather">Weather</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/">Dawn</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://herald.dawn.com">Herald</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://aurora.dawn.com">Aurora</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/prism">Prism</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/special-reports">Special Reports</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://www.dawnnews.tv/">Dawn News</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://images.dawn.com">Images</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="/magazines">Eos/Icon/Young World</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://cityfm89.com">Cityfm89</a>
# <a class="font-normal w-full inline-block uppercase mb-2 font-arial text-white outline-none" href="https://www.youtube.com/channel/UCkMdI0K-74jAjOmh5J5H97Q">Teeli</a>
# </nav>
# </div>
# <div class="md:w-1/6 w-full mb-4 sm:mb-0">
# <nav class="text-2.5 text-white">
# <p class="font-normal text-white text-left md:text-right mb-2">Copyright © 2024, Dawn</p>
# <p class="font-normal text-white text-left md:text-right">NewsKit Publishing Platform</p>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </div>
# <link href="https://www.dawn.com/_css/headroom.20241114121412.css" media="all" rel="stylesheet"/>
# <script>window.addEventListener('load', function() { dailymotionSyndicationId(202395) }); </script>
# <!-- - - - - start:ga-events - - - - -->
# <script type="text/javascript">
#
#     function sendInteractiveEvent(category, label) {
#         gtag("event", "custom_click", {
#             'event_category': category,
#             'event_action': "click",
#             'event_label': label
#         });
#     }
#
#     var eventItems = [{"selector":".story__byline a","parent":"author"},{"selector":".story__content a","parent":"links"},{"selector":".js-social-whatsapp","parent":"whatsapp"},{"selector":".js-social-twitter","parent":"twitter"},{"selector":".js-social-fb","parent":"facebook"},{"selector":".js-social-comment","parent":"comment"},{"selector":".js-social-print","parent":"print"},{"selector":".js-social-email","parent":"email"},{"selector":"tts","parent":"audio"},{"selector":".navstory--prev a","parent":"prev"},{"selector":".navstory--next a","parent":"next"}] || [];
#     document.querySelector("html").addEventListener("click", function(e) {
#         // https://github.com/aleemb/dawn.com/issues/1165
#         if (window.Element && Element.prototype.closest) {
#             var target = e.target;
#             var eventLabel =
#                 typeof target.href !== "undefined" &&
#                 !target.href.startsWith("javascript:")
#                     ? target.href
#                     : document.location.href;
#
#             for (i = 0; i < eventItems.length; i++) {
#                 if (target.matches(eventItems[i].selector + ', ' + eventItems[i].selector + ' *')) {
#                     sendInteractiveEvent(eventItems[i].parent, eventLabel);
#                     break;
#                 }
#             }
#         }
#     });
#
#     for (i = 0; i < eventItems.length; i++) {
#         if (eventItems[i].parent == 'audio') {
#             const audioPlayer = document.getElementById(eventItems[i].selector);
#             audioPlayer.addEventListener("play", (e) => sendInteractiveEvent('audio', e.type), false);
#             audioPlayer.addEventListener("pause", (e) => sendInteractiveEvent('audio', e.type), false);
#             audioPlayer.addEventListener("ended", (e) => sendInteractiveEvent('audio', e.type), false);
#         }
#     }
#     </script>
# <!-- - - - - end:ga-events - - - - -->
# <!-- - - - - start:onesignal - - - - -->
# <script async="async" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#             var OneSignal = window.OneSignal || [];
#             OneSignal.push(["init", {
#                 appId: "da41085a-a849-47c0-96e7-4b956b56f35e",
#                 /* Set to true to automatically prompt visitors */
#                 autoRegister: true,
#
#                 // https://documentation.onesignal.com/docs/customize-permission-messages-1
#                 notifyButton: {
#                     text: {
#                         'tip.state.unsubscribed': 'Subscribe to notifications',
#                         'tip.state.subscribed': "You're subscribed to notifications",
#                         'tip.state.blocked': "You've blocked notifications",
#                         'message.prenotify': 'Click to subscribe to notifications',
#                         'message.action.subscribed': "Thanks for subscribing!",
#                         'message.action.resubscribed': "You're subscribed to notifications",
#                         'message.action.unsubscribed': "You won't receive notifications again",
#                         'dialog.main.title': 'Manage Site Notifications',
#                         'dialog.main.button.subscribe': 'SUBSCRIBE',
#                         'dialog.main.button.unsubscribe': 'UNSUBSCRIBE',
#                         'dialog.blocked.title': 'Unblock Notifications',
#                         'dialog.blocked.message': "Follow these instructions to allow notifications:"
#                     },
#                     /* Set to false to hide */
#                     enable: false
#                 },
#
#                 prenotify: true,
#                 persistNotification: false,
#                 showCredit: false,
#                 // Your other init options here
#                 promptOptions: {
#                     /* Change bold title, limited to 30 characters */
#                     siteName: "Dawn.Com",
#                     /* Subtitle, limited to 90 characters */
#                     actionMessage: "We'd like to show you notifications for the latest news and updates.",
#                     /* Example notification title */
#                     exampleNotificationTitle: 'Subscribe for news updates',
#                     /* Example notification message */
#                     exampleNotificationMessage: "",
#                     /* Text below example notification, limited to 50 characters */
#                     exampleNotificationCaption: 'You can unsubscribe anytime',
#                     /* Accept button text, limited to 15 characters */
#                     acceptButtonText: "ALLOW",
#                     /* Cancel button text, limited to 15 characters */
#                     cancelButtonText: "NO THANKS"
#                 }
#             }]);
#             // OneSignal.setSubscription(true);
#             OneSignal.push(function() {
#                 // forcefully popup for notification subscription
#                 // OneSignal.registerForPushNotifications();
#                 // for debugging
#                 // OneSignal.log.setLevel('trace');
#                 /*OneSignal.isPushNotificationsEnabled(function(isEnabled) {
#                     if (isEnabled) {
#                       console.log("Push notifications are enabled!");
#                     }
#                     else {
#                       console.log("Push notifications are not enabled yet.");
#                     }
#                 });*/
#             });
#             </script>
# <!-- - - - - end:onesignal - - - - --></footer>
# </body>
# </html>

# %% [markdown]
# ### Find and print the News title

# %%
new_soup.find("h2",class_="story__title text-7.5 font-bold font-playfair-display mt-1 pb-3 border-b border-gray-300 border-solid")
# Out:
# <h2 class="story__title text-7.5 font-bold font-playfair-display mt-1 pb-3 border-b border-gray-300 border-solid" data-id="1877696" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1877696/may-9-riots-sc-constitutional-bench-rejects-govt-plea-allowing-military-courts-to-announce-verdicts">May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts</a></h2>

# %% [markdown]
# ### Extract and print the News title without unwanted characters

# %%
new_soup.find("h2",class_="story__title text-7.5 font-bold font-playfair-display mt-1 pb-3 border-b border-gray-300 border-solid").text
# Out:
# 'May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts'

# %%
# new_soup.find("h2",class_="story__title text-7.5 font-bold font-playfair-display mt-1 pb-3 border-b border-gray-300 border-solid").text.replace("\n","")

# %% [markdown]
# ### Find and print the Author Name

# %%
new_soup.find("span",class_="story__byline text-3 text-gray-500 font-arial")
# Out:
# <span class="story__byline text-3 text-gray-500 font-arial" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/10094/umer-mehtab">Umer Mehtab</a></span>

# %%
new_soup.find("span",class_="story__byline text-3 text-gray-500 font-arial").text
# Out:
# 'Umer Mehtab'

# %% [markdown]
# ### Extract and print the News Published

# %%
new_soup.find("span",class_="timestamp--date")
# Out:
# <span class="timestamp--date">December 9, 2024</span>

# %%
new_soup.find("span",class_="timestamp--date").text
# Out:
# 'December 9, 2024'

# %%
# Create an empty list to store product URLs
links_list = []

# %%
# Extract product URLs and store them in the list
for link in links:
    links_list.append(link.get("href"))

# %%
links_list
# Out:
# ['https://www.dawn.com/news/1877696/may-9-riots-sc-constitutional-bench-rejects-govt-plea-allowing-military-courts-to-announce-verdic
#  'https://www.dawn.com/news/1876231/squash-legend-jansher-khan-inducted-into-psa-hall-of-fame',
#  'https://www.dawn.com/news/1876199/olympic-champions-hassan-and-tebogo-named-athletes-of-the-year',
#  'https://www.dawn.com/news/1877513',
#  'https://www.dawn.com/news/1877697/alexandrine-parrots-disappearing-from-pakistans-skies',
#  'https://www.dawn.com/news/1877606/al-golani-the-man-who-led-overthrow-of-syrias-president-assad',
#  'https://www.dawn.com/news/1877599',
#  'https://www.dawn.com/news/1877617',
#  'https://www.dawn.com/news/1877206/bcci-accepts-two-way-hybrid-model-to-resolve-champions-trophy-deadlock-with-pcb',
#  'https://www.dawn.com/news/1877481/ousted-assad-his-family-in-moscow-after-rebel-forces-capture-syrias-capital',
#  'https://www.dawn.com/news/1877053/bcci-turns-down-renewed-proposal-by-pcb-as-deadlock-over-champions-trophy-continues',
#  'https://www.dawn.com/news/1877260/threat-perception',
#  'https://www.dawn.com/news/1877307/champions-trophy-deadlock-continues-as-naqvi-confirms-icc-meeting-delayed',
#  'https://www.dawn.com/news/1877308/pia-to-resume-europe-flights-from-january-10',
#  'https://www.dawn.com/news/1877408/us-disappointed-by-bjps-accusation',
#  'https://www.dawn.com/news/1877191/cartoon-7-december-2024',
#  'https://www.dawn.com/news/1877206/bcci-accepts-two-way-hybrid-model-to-resolve-champions-trophy-deadlock-with-pcb',
#  'https://www.dawn.com/news/1877053/bcci-turns-down-renewed-proposal-by-pcb-as-deadlock-over-champions-trophy-continues',
#  'https://www.dawn.com/news/1876916/pti-founder-imran-announces-grand-gathering-in-peshawar-on-dec-13',
#  'https://www.dawn.com/news/1877481/ousted-assad-his-family-in-moscow-after-rebel-forces-capture-syrias-capital',
#  'https://www.dawn.com/news/1877099/bushra-bibi-resurfaces-after-pti-protest-says-she-did-not-run-away',
#  'https://www.dawn.com/news/1877064/cartoon-6-december-2024',
#  'https://www.dawn.com/news/1876926/army-wants-action-against-those-behind-disinfo-on-protesters-deaths',
#  'https://www.dawn.com/news/1877260/threat-perception',
#  'https://www.dawn.com/news/1877443/rethinking-afghan-policy',
#  'https://www.dawn.com/news/1877444/gaza-genocide-degraded-axis',
#  'https://www.dawn.com/news/1877441/free-the-press',
#  'https://www.dawn.com/news/1877442/strategic-dilemma',
#  'https://www.dawn.com/news/1877257/milei-argentina-and-pakistan',
#  'https://www.dawn.com/news/1877254/extra-burden']

# %%
# Create a dictionary to store scraped data
d = {"title":[],"author":[],"published":[]}

# %%
# Define functions to extract news title
def get_title(soup):
    
    try:
        # Extract and clean the product title
        title_value = soup.find("h2",class_="story__title text-7.5 font-bold font-playfair-display mt-1 pb-3 border-b border-gray-300 border-solid").text.replace("\n","")
    except:
        # If the title is not found, set it as an empty string
        title_value = ""
        
    return title_value

# %%
# Define functions to extract author name
def get_author(soup):
    
    try:
        # Extract and clean the product title
        author_value = soup.find("span",class_="story__byline text-3 text-gray-500 font-arial").text
    except:
        # If the title is not found, set it as an empty string
        author_value = ""
        
    return author_value

# %%
# Define functions to extract author name
def get_publish(soup):
    
    try:
        # Extract and clean the product title
        published_value = soup.find("span",class_="timestamp--date").text
    except:
        # If the title is not found, set it as an empty string
        published_value = ""
        
    return published_value

# %%
# Iterate through product URLs and scrape data
for link in links_list:
    
    # Create the full URL for the product page
    new_webpage_URL =  link
    
    # Send an HTTP GET request to the product page and parse the HTML content
    new_response = requests.get(new_webpage_URL,headers=HEADERS)
    new_soup = BeautifulSoup(new_response.content,"html.parser")
    
    # Call the defined functions to extract and append data to the dictionary
    d["title"].append(get_title(new_soup))
    d["author"].append(get_author(new_soup))
    d["published"].append(get_publish(new_soup))

# %%
print(d)
# Out:
# {'title': ['May 9 riots: SC constitutional bench rejects govt plea allowing military courts to announce verdicts', 'KP supervisory committee formed to restore law and order in Kurram', 'Alexandrine parrots disappearing from Pakistan’s skies', 'Pakistan ranked among lowest 12pc globally in mobile, broadband internet speeds in Oct: report', 'Extreme heat endangers garment factory workers in Pakistan and beyond: study', 'SC suspends ECP decision to disqualify PML-N lawmaker Adil Bazai', '', 'South Korea President Yoon banned from foreign travel as leadership crisis deepens', 'Dozens of schools in Delhi get bomb threats: report', 'Damascus is free?', 'CORPORATE WINDOW:  Business in limbo', '', 'Neglecting health and education', '', 'The ongoing internet folly', 'KSE-100 nears 110,000-point mark as shares at PSX trade in green for 9th consecutive session', '', '', 'Beyond personality disorders', 'Syria transition must ensure ‘accountability’ for past crimes: UN', 'Democratic backsliding', 'CPEC slowdown', '', 'Harvesting the sun for industrial growth', 'Explicit and implicit taxation of agriculture', 'Green banking — a path to financial sustainability', 'The cost of a political divide', 'Mass protests force AJK govt to withdraw controversial law', '13 terrorists killed in North Waziristan operation', '', 'Rampant England pummel NZ again to seal series', 'Arsenal drop points in  title chase, Bournemouth  stun Ipswich', 'Bangladesh stun India to retain U-19 Asia Cup', '', 'Israel, US carry out air strikes in Damascus after regime change', 'Parents’ reluctance to immunise children causing deaths in KP: experts', 'Kohistan jirga ends KKH blockade after release  of leader held under 3MPO', 'Fazl says he won’t accept govt’s interference in seminaries', '', '', 'Tahir Ashrafi questions JUI over seminaries bill', '', 'Man twice implicated in false cases for ‘exposing police fuel sale’ in Lahore', 'After meeting Bilawal and Fazl, Vawda reaches out to MQM-P', 'STP stages big rally in Karachi against canals project', '', '', '', 'Al-Golani: The man who led overthrow of Syria’s President Assad', 'Impeachments, coups and deaths: Dark side of Korean presidency', 'Japanese, European automakers losing ground in China', 'AI report highlights climate change’s economic impacts', '', '', '', '', 'Falling turnout from 2013 to 2024 hints at wider voter ‘apathy’', '', '', 'PM Shehbaz seeks Nawaz’s counsel over JUI-F, PTI ‘threats’', '', '', '', 'Coalition partners meet today to bridge rift', '', 'Fazl says he won’t accept govt’s interference in seminaries', '13 terrorists killed in North Waziristan operation', 'Attaullah Tarar slams civil disobedience call as PTI shifts strategy', '', '', '', '', 'Falling turnout from 2013 to 2024 hints at wider voter ‘apathy’', '', 'President Zardari summons NA session tomorrow', '', 'Students suffer as Sindh MDCAT retake begins 2 hours late', '', '', 'Kohistan jirga ends KKH blockade after release  of leader held under 3MPO', '', '', '', 'After meeting Bilawal and Fazl, Vawda reaches out to MQM-P', '', 'PTI to pursue civil disobedience campaign at home and abroad if demands not met: Omar Ayub', 'FM Dar discusses Pakistani nationals stranded in Syria with Turkish counterpart', '', '', '', '', '', 'Pakistan sends first consignment of relief goods to flood-hit Malaysia', 'Justice Shah advocates for child-centred judicial system', '', '', '', '', '', 'BYD gambles on Pakistan’s EV market', 'Explicit and implicit taxation of agriculture', 'Green banking — a path to financial sustainability', '', '', '', 'Trade gap widens with Mideast on rising energy imports', 'Europe’s industry braces for gas price shock', '', '', '', '', 'PBC sees 200bps cut in policy rate', '', 'China urged to expedite ML-1 rail, model special economic zone projects', '', '', 'Banks pump Rs2.2tr into non-govt sector', '', 'Body formed to tax bank profits from govt securities', '', '', '', 'Govt eyes speedy outsourcing of major airports', '', 'PM Shehbaz s ...

# %%
# Create a DataFrame from the scraped data
df = pd.DataFrame(d)

# Replace empty strings in the "title" column with NaN and drop rows with NaN values in the "title" column

# Option 1: Using chained assignment (recommended)
df["title"] = df["title"].replace("", np.nan)

# Drop rows with NaN values in the "title" column
df = df.dropna(subset=["title"])

# %%
df
# Out:
#                                                  title              author  \
# 0    May 9 riots: SC constitutional bench rejects g...         Umer Mehtab
# 1    KP supervisory committee formed to restore law...          Arif Hayat
# 2    Alexandrine parrots disappearing from Pakistan...      Anadolu Agency
# 3    Pakistan ranked among lowest 12pc globally in ...
# 4    Extreme heat endangers garment factory workers...             Reuters
# ..                                                 ...                 ...
# 213  ‘BCCI accepts two-way hybrid model to resolve ...     Mohammad Yaqoob
# 217  Bushra Bibi resurfaces after PTI protest, says...          Arif Hayat
# 221                           Rethinking Afghan policy  Muhammad Amir Rana
# 224                                  Strategic dilemma          Aisha Khan
# 225                      Milei, Argentina and Pakistan      Shahid Mehmood
#
#             published
# 0    December 9, 2024
# 1    December 9, 2024
# 2    December 9, 2024
# 3    December 9, 2024
# 4    December 9, 2024
# ..                ...
# 213  December 7, 2024
# 217  December 6, 2024
# 221  December 8, 2024
# 224  December 8, 2024
# 225  December 7, 2024
#
# [99 rows x 3 columns]

# %%
df.count
# Out:
# <bound method DataFrame.count of                                                  title              author  \
# 0    May 9 riots: SC constitutional bench rejects g...         Umer Mehtab
# 1    KP supervisory committee formed to restore law...          Arif Hayat
# 2    Alexandrine parrots disappearing from Pakistan...      Anadolu Agency
# 3    Pakistan ranked among lowest 12pc globally in ...
# 4    Extreme heat endangers garment factory workers...             Reuters
# ..                                                 ...                 ...
# 213  ‘BCCI accepts two-way hybrid model to resolve ...     Mohammad Yaqoob
# 217  Bushra Bibi resurfaces after PTI protest, says...          Arif Hayat
# 221                           Rethinking Afghan policy  Muhammad Amir Rana
# 224                                  Strategic dilemma          Aisha Khan
# 225                      Milei, Argentina and Pakistan      Shahid Mehmood
#
#             published
# 0    December 9, 2024
# 1    December 9, 2024
# 2    December 9, 2024
# 3    December 9, 2024
# 4    December 9, 2024
# ..                ...
# 213  December 7, 2024
# 217  December 6, 2024
# 221  December 8, 2024
# 224  December 8, 2024
# 225  December 7, 2024
#
# [99 rows x 3 columns]>

# %%
# Save the DataFrame to a CSV file
df.to_csv("DawnNews_data.csv", index=False)
